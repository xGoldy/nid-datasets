# %% [markdown]
# # SIMARGL2022 Dataset Analysis
#
# * **Author:** Patrik Goldschmidt (igoldschmidt@fit.vut.cz)
# * **Project:** Network Intrusion Datasets: A Survey, Limitations, and Recommendations
# * **Date:** 2024
#
# Data source: [https://www.kaggle.com/datasets/h2020simargl/simargl2022](https://www.kaggle.com/datasets/h2020simargl/simargl2022)

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import os

pd.set_option('display.max_columns', None)

# %%
PATH_ROOT = '/data/disk2/simargl2021'

# %%
ALL_CSVS = sorted(os.listdir(PATH_ROOT))
ALL_CSVS
# Out:
# ['dos-03-15-2022-15-44-32.csv',
#  'dos-03-16-2022-13-45-18.csv',
#  'dos-03-17-2022-16-22-53.csv',
#  'dos-03-18-2022-19-27-05.csv',
#  'dos-03-19-2022-20-01-53.csv',
#  'dos-03-20-2022-14-27-54.csv',
#  'malware-03-25-2022-17-57-07.csv',
#  'normal-03-15-2022-15-43-44.csv',
#  'normal-03-16-2022-13-44-27.csv',
#  'normal-03-17-2022-16-21-30.csv',
#  'normal-03-18-2022-19-17-31.csv',
#  'normal-03-18-2022-19-25-48.csv',
#  'normal-03-19-2022-20-01-16.csv',
#  'normal-03-20-2022-14-27-30.csv',
#  'portscanning-03-15-2022-15-44-06.csv',
#  'portscanning-03-16-2022-13-44-50.csv',
#  'portscanning-03-17-2022-16-22-53.csv',
#  'portscanning-03-18-2022-19-27-05.csv',
#  'portscanning-03-19-2022-20-01-45.csv',
#  'portscanning-03-20-2022-14-27-49.csv']

# %% [markdown]
# There are lot of files separated by classes and days. According to their names, there is a high probability their will not be continous already. When we consider one capture 03-25-2022, the file is indeed not continuous. Let's try to load all the file into one DataFrame for analysis since they are not big themselves.

# %%
data_all = pd.DataFrame()

for file in ALL_CSVS:
    filepath = os.path.join(PATH_ROOT, file)

    data_partial = pd.read_csv(filepath)

    data_all = pd.concat([data_all, data_partial])

# %% [markdown]
# ## NaN Values Investigation

# %%
data_all.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30148258 entries, 0 to 291301
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count     Dtype
# ---  ------                      --------------     -----
#  0   FLOW_ID                     30148258 non-null  int64
#  1   PROTOCOL_MAP                30148258 non-null  object
#  2   L4_SRC_PORT                 30148258 non-null  int64
#  3   IPV4_SRC_ADDR               30148258 non-null  object
#  4   L4_DST_PORT                 30148258 non-null  int64
#  5   IPV4_DST_ADDR               30148258 non-null  object
#  6   FIRST_SWITCHED              30148258 non-null  int64
#  7   FLOW_DURATION_MILLISECONDS  30148258 non-null  int64
#  8   LAST_SWITCHED               30148258 non-null  int64
#  9   PROTOCOL                    30148258 non-null  int64
#  10  TCP_FLAGS                   30148258 non-null  int64
#  11  TCP_WIN_MAX_IN              30148258 non-null  int64
#  12  TCP_WIN_MAX_OUT             30148258 non-null  int64
#  13  TCP_WIN_MIN_IN              30148258 non-null  int64
#  14  TCP_WIN_MIN_OUT             30148258 non-null  int64
#  15  TCP_WIN_MSS_IN              30148258 non-null  int64
#  16  TCP_WIN_SCALE_IN            30148258 non-null  int64
#  17  TCP_WIN_SCALE_OUT           30148258 non-null  int64
#  18  SRC_TOS                     30148258 non-null  int64
#  19  DST_TOS                     30148258 non-null  int64
#  20  TOTAL_FLOWS_EXP             30148258 non-null  int64
#  21  MIN_IP_PKT_LEN              30148258 non-null  int64
#  22  MAX_IP_PKT_LEN              30148258 non-null  int64
#  23  TOTAL_PKTS_EXP              30148258 non-null  int64
#  24  TOTAL_BYTES_EXP             30148258 non-null  int64
#  25  IN_BYTES                    30148258 non-null  int64
#  26  IN_PKTS                     30148258 non-null  int64
#  27  OUT_BYTES                   30148258 non-null  int64
#  28  OUT_PKTS                    30148258 non-null  int64
#  29  ALERT                       10596124 non-null  object
#  30  ANALYSIS_TIMESTAMP          30148258 non-null  int64
#  31  ANOMALY                     5942948 non-null   float64
# dtypes: float64(1), int64(27), object(4)
# memory usage: 7.4+ GB

# %%
# As apparent, fields ALERT and ANOMALY are someimes Null. What are their values?
data_all['ANOMALY'].value_counts()
# Out:
# ANOMALY
# 1.0    3036969
# 0.0    2905979
# Name: count, dtype: int64

# %%
data_all['ALERT'].value_counts()
# Out:
# ALERT
# Denial of Service    6425161
# Port Scanning        4170392
# Malware                  571
# Name: count, dtype: int64

# %%
# Is there any correlation between the two? E.g., anomaly is non-NaN, is also alert the non-NaN
data_all[data_all['ANOMALY'].isna() == False]['ALERT'].isna().sum()
# Out:
# 2695645

# %% [markdown]
# Ok, so these two above hypothesis does not stand. Nevertheless, analyze the data.

# %%
# Filter the files separately
DOS_FNAMES = filter(lambda fname: fname.startswith('dos'), ALL_CSVS)
MW_FNAMES = filter(lambda fname: fname.startswith('malware'), ALL_CSVS)
NORMAL_FNAMES = filter(lambda fname: fname.startswith('normal'), ALL_CSVS)
SCAN_FNAMES = filter(lambda fname: fname.startswith('portscanning'), ALL_CSVS)

# %%
for file in ALL_CSVS:
    # Try if pandas can open the file -- if the same file contains the same number of cols
    one_file_data = pd.read_csv(os.path.join(PATH_ROOT, file), nrows=10)

    # Print the number of file's columns
    print(f'{len(one_file_data.columns)} : {file}')
# Out:
# 31 : dos-03-15-2022-15-44-32.csv
# 31 : dos-03-16-2022-13-45-18.csv
# 31 : dos-03-17-2022-16-22-53.csv
# 31 : dos-03-18-2022-19-27-05.csv
# 32 : dos-03-19-2022-20-01-53.csv
# 32 : dos-03-20-2022-14-27-54.csv
# 32 : malware-03-25-2022-17-57-07.csv
# 31 : normal-03-15-2022-15-43-44.csv
# 31 : normal-03-16-2022-13-44-27.csv
# 31 : normal-03-17-2022-16-21-30.csv
# 31 : normal-03-18-2022-19-17-31.csv
# 31 : normal-03-18-2022-19-25-48.csv
# 32 : normal-03-19-2022-20-01-16.csv
# 32 : normal-03-20-2022-14-27-30.csv
# 31 : portscanning-03-15-2022-15-44-06.csv
# 31 : portscanning-03-16-2022-13-44-50.csv
# 31 : portscanning-03-17-2022-16-22-53.csv
# 31 : portscanning-03-18-2022-19-27-05.csv
# 32 : portscanning-03-19-2022-20-01-45.csv
# 32 : portscanning-03-20-2022-14-27-49.csv

# %% [markdown]
# Apparently, the feature extractor was changed on 03-19-22 and produces 1 more feature since.

# %% [markdown]
# ## Actual Data Analysis

# %%
# Keep analyzing the whole dataset for now
data_all.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30148258 entries, 0 to 291301
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count     Dtype
# ---  ------                      --------------     -----
#  0   FLOW_ID                     30148258 non-null  int64
#  1   PROTOCOL_MAP                30148258 non-null  object
#  2   L4_SRC_PORT                 30148258 non-null  int64
#  3   IPV4_SRC_ADDR               30148258 non-null  object
#  4   L4_DST_PORT                 30148258 non-null  int64
#  5   IPV4_DST_ADDR               30148258 non-null  object
#  6   FIRST_SWITCHED              30148258 non-null  int64
#  7   FLOW_DURATION_MILLISECONDS  30148258 non-null  int64
#  8   LAST_SWITCHED               30148258 non-null  int64
#  9   PROTOCOL                    30148258 non-null  int64
#  10  TCP_FLAGS                   30148258 non-null  int64
#  11  TCP_WIN_MAX_IN              30148258 non-null  int64
#  12  TCP_WIN_MAX_OUT             30148258 non-null  int64
#  13  TCP_WIN_MIN_IN              30148258 non-null  int64
#  14  TCP_WIN_MIN_OUT             30148258 non-null  int64
#  15  TCP_WIN_MSS_IN              30148258 non-null  int64
#  16  TCP_WIN_SCALE_IN            30148258 non-null  int64
#  17  TCP_WIN_SCALE_OUT           30148258 non-null  int64
#  18  SRC_TOS                     30148258 non-null  int64
#  19  DST_TOS                     30148258 non-null  int64
#  20  TOTAL_FLOWS_EXP             30148258 non-null  int64
#  21  MIN_IP_PKT_LEN              30148258 non-null  int64
#  22  MAX_IP_PKT_LEN              30148258 non-null  int64
#  23  TOTAL_PKTS_EXP              30148258 non-null  int64
#  24  TOTAL_BYTES_EXP             30148258 non-null  int64
#  25  IN_BYTES                    30148258 non-null  int64
#  26  IN_PKTS                     30148258 non-null  int64
#  27  OUT_BYTES                   30148258 non-null  int64
#  28  OUT_PKTS                    30148258 non-null  int64
#  29  ALERT                       10596124 non-null  object
#  30  ANALYSIS_TIMESTAMP          30148258 non-null  int64
#  31  ANOMALY                     5942948 non-null   float64
# dtypes: float64(1), int64(27), object(4)
# memory usage: 7.4+ GB

# %%
len(data_all)
# Out:
# 30148258

# %%
data_all.head()
# Out:
#      FLOW_ID PROTOCOL_MAP  L4_SRC_PORT   IPV4_SRC_ADDR  L4_DST_PORT  \
# 0  334626451          tcp        50242  10.114.241.191          443
# 1  334626948          tcp        50244  10.114.241.191          443
# 2  334627641          tcp        50246  10.114.241.191          443
# 3  334628195          tcp        50248  10.114.241.191          443
# 4  334628673          tcp        54328  10.114.241.191          443
#
#    IPV4_DST_ADDR  FIRST_SWITCHED  FLOW_DURATION_MILLISECONDS  LAST_SWITCHED  \
# 0  10.114.224.73      1647344604                         105     1647344604
# 1  10.114.224.73      1647344609                           6     1647344609
# 2  10.114.224.73      1647344614                         111     1647344614
# 3  10.114.224.73      1647344619                           6     1647344619
# 4  10.114.224.73      1647344534                      110000     1647344644
#
#    PROTOCOL  TCP_FLAGS  TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  TCP_WIN_MIN_IN  \
# 0         6         31           64240            27960           64240
# 1         6         31           64240            27960           64240
# 2         6         31           64240            27960           64240
# 3         6         31           64240            27960           64240
# 4         6         24             501              122             501
#
#    TCP_WIN_MIN_OUT  TCP_WIN_MSS_IN  TCP_WIN_SCALE_IN  TCP_WIN_SCALE_OUT  \
# 0            27960            1460                 7                  8
# 1            27960            1460                 7                  8
# 2            27960            1460                 7                  8
# 3            27960            1460                 7                  8
# 4              122               0                 0                  0
#
#    SRC_TOS  DST_TOS  TOTAL_FLOWS_EXP  MIN_IP_PKT_LEN  MAX_IP_PKT_LEN  \
# 0        0        0        334626451               0               0
# 1        0        0        334626948               0               0
# 2        0        0        334627641               0               0
# 3        0        0        334628195               0               0
# 4        0        0        334628673               0               0
#
#    TOTAL_PKTS_EXP  TOTAL_BYTES_EXP  IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  \
# 0               0                0       551        5        192         4
# 1               0                0       551        5        192         4
# 2               0                0       551        5        192         4
# 3               0                0       551        5        192         4
# 4               0                0      1309       12        624        12
#
#                ALERT  ANALYSIS_TIMESTAMP  ANOMALY
# 0  Denial of Service          1647344695      NaN
# 1  Denial of Service          1647344695      NaN
# 2  Denial of Service          1647344695      NaN
# 3  Denial of Service          1647344695      NaN
# 4  Denial of Service          1647344695      NaN

# %%
data_all.tail()
# Out:
#           FLOW_ID PROTOCOL_MAP  L4_SRC_PORT   IPV4_SRC_ADDR  L4_DST_PORT  \
# 291297  373409629          tcp        62837  10.114.241.166        44550
# 291298  373409628          tcp        62836  10.114.241.166        38086
# 291299  373409631          tcp        62837  10.114.241.166        48791
# 291300  373409630          tcp        62836  10.114.241.166        26881
# 291301  373409633          tcp        62836  10.114.241.166        47947
#
#          IPV4_DST_ADDR  FIRST_SWITCHED  FLOW_DURATION_MILLISECONDS  \
# 291297   10.114.224.53      1647773700                           0
# 291298  10.114.224.117      1647773700                           1
# 291299  10.114.224.203      1647773700                           0
# 291300   10.114.224.63      1647773700                           0
# 291301  10.114.224.203      1647773700                           0
#
#         LAST_SWITCHED  PROTOCOL  TCP_FLAGS  TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  \
# 291297     1647773700         6          2            1024                0
# 291298     1647773700         6         22            1024                0
# 291299     1647773700         6          2            1024                0
# 291300     1647773700         6          2            1024                0
# 291301     1647773700         6          2            1024                0
#
#         TCP_WIN_MIN_IN  TCP_WIN_MIN_OUT  TCP_WIN_MSS_IN  TCP_WIN_SCALE_IN  \
# 291297            1024                0            1460                 0
# 291298            1024                0            1460                 0
# 291299            1024                0            1460                 0
# 291300            1024                0            1460                 0
# 291301            1024                0            1460                 0
#
#         TCP_WIN_SCALE_OUT  SRC_TOS  DST_TOS  TOTAL_FLOWS_EXP  MIN_IP_PKT_LEN  \
# 291297                  0        0        0        373409629               0
# 291298                  0        0        0        373409628               0
# 291299                  0        0        0        373409631               0
# 291300                  0        0        0        373409630               0
# 291301                  0        0        0        373409633               0
#
#         MAX_IP_PKT_LEN  TOTAL_PKTS_EXP  TOTAL_BYTES_EXP  IN_BYTES  IN_PKTS  \
# 291297               0               0                0        44        1
# 291298               0               0                0        44        1
# 291299               0               0                0        44        1
# 291300               0               0                0        44        1
# 291301               0               0                0        44        1
#
#         OUT_BYTES  OUT_PKTS          ALERT  ANALYSIS_TIMESTAMP  ANOMALY
# 291297          0         0  Port Scanning          1647773781      1.0
# 291298         40         1  Port Scanning          1647773781      1.0
# 291299          0         0  Port Scanning          1647773781      1.0
# 291300          0         0  Port Scanning          1647773781      1.0
# 291301          0         0  Port Scanning          1647773781      1.0

# %%
data_all.describe()
# Out:
#             FLOW_ID   L4_SRC_PORT   L4_DST_PORT  FIRST_SWITCHED  \
# count  3.014826e+07  3.014826e+07  3.014826e+07    3.014826e+07
# mean   3.550248e+08  4.457222e+04  8.029699e+03    1.647537e+09
# std    1.357225e+07  1.698717e+04  1.677861e+04    1.204687e+05
# min    3.000000e+00  0.000000e+00  0.000000e+00    1.647330e+09
# 25%    3.514334e+08  3.792800e+04  5.300000e+01    1.647440e+09
# 50%    3.570896e+08  4.932300e+04  4.430000e+02    1.647518e+09
# 75%    3.638961e+08  5.587600e+04  2.375000e+03    1.647605e+09
# max    3.743763e+08  6.553500e+04  6.553500e+04    1.648226e+09
#
#        FLOW_DURATION_MILLISECONDS  LAST_SWITCHED      PROTOCOL     TCP_FLAGS  \
# count                3.014826e+07   3.014826e+07  3.014826e+07  3.014826e+07
# mean                 5.127937e+03   1.647537e+09  9.269864e+00  9.235459e+00
# std                  1.895497e+04   1.204690e+05  5.424333e+00  1.516865e+01
# min                  0.000000e+00   1.647330e+09  1.000000e+00  0.000000e+00
# 25%                  0.000000e+00   1.647440e+09  6.000000e+00  0.000000e+00
# 50%                  3.200000e+01   1.647518e+09  6.000000e+00  2.000000e+00
# 75%                  3.017000e+03   1.647605e+09  1.700000e+01  2.200000e+01
# max                  1.199990e+05   1.648226e+09  5.800000e+01  2.550000e+02
#
#        TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  TCP_WIN_MIN_IN  TCP_WIN_MIN_OUT  \
# count    3.014826e+07     3.014826e+07    3.014826e+07     3.014826e+07
# mean     2.149439e+04     6.220592e+03    2.143777e+04     6.202765e+03
# std      2.974445e+04     1.818690e+04    2.973978e+04     1.816375e+04
# min      0.000000e+00     0.000000e+00    0.000000e+00     0.000000e+00
# 25%      0.000000e+00     0.000000e+00    0.000000e+00     0.000000e+00
# 50%      1.024000e+03     0.000000e+00    1.024000e+03     0.000000e+00
# 75%      6.424000e+04     0.000000e+00    6.424000e+04     0.000000e+00
# max      6.553500e+04     6.553500e+04    6.553500e+04     6.553500e+04
#
#        TCP_WIN_MSS_IN  TCP_WIN_SCALE_IN  TCP_WIN_SCALE_OUT       SRC_TOS  \
# count    3.014826e+07      3.014826e+07       3.014826e+07  3.014826e+07
# mean     6.908209e+02      2.300147e+00       7.769335e-01  7.831136e+00
# std      7.298235e+02      3.358245e+00       2.428990e+00  3.272519e+01
# min      0.000000e+00      0.000000e+00       0.000000e+00  0.000000e+00
# 25%      0.000000e+00      0.000000e+00       0.000000e+00  0.000000e+00
# 50%      0.000000e+00      0.000000e+00       0.000000e+00  0.000000e+00
# 75%      1.460000e+03      7.000000e+00       0.000000e+00  0.000000e+00
# max      5.816500e+04      1.400000e+01       1.400000e+01  2.550000e+02
#
#             DST_TOS  TOTAL_FLOWS_EXP  MIN_IP_PKT_LEN  MAX_IP_PKT_LEN  \
# count  3.014826e+07     3.014826e+07      30148258.0      30148258.0
# mean   8.686281e+00     3.550248e+08             0.0             0.0
# std    3.484271e+01     1.357225e+07             0.0             0.0
# min    0.000000e+00     3.000000e+00             0.0             0.0
# 25%    0.000000e+00     3.514334e+08             0.0             0.0
# 50%    0.000000e+00     3.570896e+08             0.0             0.0
# 75%    0.000000e+00     3.638961e+08             0.0             0.0
# max    2.520000e+02     3.743763e+08             0.0             0.0
#
#        TOTAL_PKTS_EXP  TOTAL_BYTES_EXP      IN_BYTES       IN_PKTS  \
# count      30148258.0       30148258.0  3.014826e+07  3.014826e+07
# mean              0.0              0.0  1.209768e+04  2.544525e+01
# std               0.0              0.0  1.302045e+06  1.179611e+03
# min               0.0              0.0  2.800000e+01  1.000000e+00
# 25%               0.0              0.0  6.000000e+01  1.000000e+00
# 50%               0.0              0.0  1.200000e+02  2.000000e+00
# 75%               0.0              0.0  2.400000e+02  4.000000e+00
# max               0.0              0.0  1.670406e+09  1.114854e+06
#
#           OUT_BYTES      OUT_PKTS  ANALYSIS_TIMESTAMP       ANOMALY
# count  3.014826e+07  3.014826e+07        3.014826e+07  5.942948e+06
# mean   4.076311e+04  3.466279e+01        1.647537e+09  5.110206e-01
# std    2.669808e+06  1.941030e+03        1.203767e+05  4.998786e-01
# min    0.000000e+00  0.000000e+00        1.647330e+09  0.000000e+00
# 25%    0.000000e+00  0.000000e+00        1.647440e+09  0.000000e+00
# 50%    5.200000e+01  1.000000e+00        1.647518e+09  1.000000e+00
# 75%    2.660000e+02  2.000000e+00        1.647605e+09  1.000000e+00
# max    3.547208e+09  3.004436e+06        1.648226e+09  1.000000e+00

# %%
# Analyze alerts distribution
data_all['ALERT'].value_counts()
# Out:
# ALERT
# Denial of Service    6425161
# Port Scanning        4170392
# Malware                  571
# Name: count, dtype: int64

# %%
# Analyze anomaly distribution
data_all['ANOMALY'].value_counts()
# Out:
# ANOMALY
# 1.0    3036969
# 0.0    2905979
# Name: count, dtype: int64

# %%
# Protocols
data_all['PROTOCOL'].value_counts()
# Out:
# PROTOCOL
# 6     19074545
# 17     9604576
# 1      1463362
# 47        4800
# 58         688
# 57         284
# 41           3
# Name: count, dtype: int64

# %%
# How big is the network? Grasp the number of unique IP addresses
# and their communication volumes
ip_activity = data_all['IPV4_SRC_ADDR'].value_counts()

ip_activity[ip_activity > 100]
# Out:
# IPV4_SRC_ADDR
# 10.114.241.191    6425161
# 10.114.241.166    4170392
# 10.114.225.205    2698888
# 10.114.225.206    2680707
# 10.114.226.5      2427748
#                    ...
# 159.65.51.254         101
# 122.51.149.86         101
# 192.241.157.63        101
# 81.91.233.42          101
# 213.136.79.205        101
# Name: count, Length: 5035, dtype: int64

# %% [markdown]
# Ok, 115k unique IP addresses, 5k with over 100 flows sent. 10.114.241.0/24 seems to be an internal network due to the emount of traffic. Let's filter out those files which communicate above some threshold.

# %%
# How big is the internal network - let's scan the internal address spaces
print(len([key for key in ip_activity.keys() if key.startswith('10.')]))
print(len([key for key in ip_activity.keys() if key.startswith('172.16.')]))
print(len([key for key in ip_activity.keys() if key.startswith('192.168.')]))
# Out:
# 265
# 458
# 105

# %% [markdown]
# Based on these findings, we can conclude that the network is large (+500 hosts), although NATTing can play a big role as well. Nevertheless, for the analysis purpose, the network is classified as large due to the number of IP addresses present nevertheless.

# %% [markdown]
# ## Temporal and Continuity Analysis
#
# Consider `LAST_SWITCHED` as the timestamp of the flow, disregarding its potential duration for this analysis.

# %%
data_all['LAST_SWITCHED'].head()
# Out:
# 0    1647344604
# 1    1647344609
# 2    1647344614
# 3    1647344619
# 4    1647344644
# Name: LAST_SWITCHED, dtype: int64

# %%
# Looks like epoch timestamps in a second precision, convert them to datetime format.
timestamps = pd.to_datetime(data_all['LAST_SWITCHED'], origin='unix', unit='s').sort_values(ascending=False)
timestamps
# Out:
# 570     2022-03-25 16:30:17
# 567     2022-03-25 16:25:17
# 137     2022-03-25 16:25:17
# 566     2022-03-25 16:20:17
# 559     2022-03-25 16:15:17
#                 ...
# 24603   2022-03-15 07:36:57
# 24602   2022-03-15 07:36:57
# 24601   2022-03-15 07:36:57
# 24600   2022-03-15 07:36:57
# 21869   2022-03-15 07:36:57
# Name: LAST_SWITCHED, Length: 30148258, dtype: datetime64[ns]

# %%
# Compute the overall span
total_span = timestamps.iloc[0] - timestamps.iloc[-1]
total_span
# Out:
# Timedelta('10 days 08:53:20')

# %%
# Maximum gap to consider the file as continous - already quite long
total_span * 0.01
# Out:
# Timedelta('0 days 02:29:20')

# %%
# Measure capture duration and continousness
def measure_real_capture_dur(data: pd.Series, gap_max_secs: int = 300) -> float:
    """Computes total timespan of the capture. Expects iterable containing timestamps objects sorted in a descending manner"""
    total_dur = pd.Timedelta(seconds=0)
    current_dur = pd.Timedelta(seconds=0)
    cont_durations = []
    last_tstamp = data.iloc[0]
    contiguous = True

    # Iterate through the dataframe to find out gaps
    for cur_tstamp in data:
        dur_gap = last_tstamp - cur_tstamp

        if dur_gap <= pd.Timedelta(seconds=gap_max_secs):
            total_dur += dur_gap
            current_dur += dur_gap
        else:
            cont_durations.append(current_dur)
            current_dur = pd.Timedelta(seconds=0)

            if contiguous:
                contiguous = False

        last_tstamp = cur_tstamp

    # Log the final continuous block and sort them via their length
    cont_durations.append(current_dur)
    cont_durations.sort(reverse=True)

    return total_dur, contiguous, cont_durations

# %%
# We suspect that the capture will be discontinuous due to several files, let's see the analysis.
measure_real_capture_dur(timestamps, int(total_span.total_seconds() * 0.01))
# Out:
# (Timedelta('5 days 01:36:31'),
#  False,
#  [Timedelta('2 days 08:52:32'),
#   Timedelta('0 days 23:27:01'),
#   Timedelta('0 days 11:31:56'),
#   Timedelta('0 days 09:52:05'),
#   Timedelta('0 days 08:30:12'),
#   Timedelta('0 days 04:06:09'),
#   Timedelta('0 days 03:19:06'),
#   Timedelta('0 days 02:56:52'),
#   Timedelta('0 days 00:43:05'),
#   Timedelta('0 days 00:17:33')])

# %% [markdown]
# Since there are less continuous blocks than the number of files, some files must have their gaps between different attacks less than 2h.

# %%
# Analyze if individual captures are continuous. Set maximum gap as 1% of 10 hours == 360 seconds
for file in sorted(ALL_CSVS):
    filepath = os.path.join(PATH_ROOT, file)
    data_partial = pd.read_csv(filepath)

    timestamps_partial = pd.to_datetime(data_partial['LAST_SWITCHED'], unit='s', origin='unix')
    timestamps_partial = timestamps_partial.sort_values(ascending=False)

    print(f"{file} : {measure_real_capture_dur(timestamps_partial, 360)}")
# Out:
# dos-03-15-2022-15-44-32.csv : (Timedelta('0 days 00:16:38'), True, [Timedelta('0 days 00:16:38')])
# dos-03-16-2022-13-45-18.csv : (Timedelta('0 days 00:04:36'), True, [Timedelta('0 days 00:04:36')])
# dos-03-17-2022-16-22-53.csv : (Timedelta('0 days 01:59:54'), False, [Timedelta('0 days 00:59:57'), Timedelta('0 days 00:59:57')])
# dos-03-18-2022-19-27-05.csv : (Timedelta('0 days 03:59:47'), False, [Timedelta('0 days 00:59:57'), Timedelta('0 days 00:59:57'), Timedelta('0 days 00:59:57'), Timedelta('0 days 00:59:56')])
# dos-03-19-2022-20-01-53.csv : (Timedelta('0 days 01:59:53'), False, [Timedelta('0 days 00:59:57'), Timedelta('0 days 00:59:56')])
# dos-03-20-2022-14-27-54.csv : (Timedelta('0 days 01:50:58'), False, [Timedelta('0 days 00:59:56'), Timedelta('0 days 00:51:02')])
# malware-03-25-2022-17-57-07.csv : (Timedelta('0 days 17:30:33'), False, [Timedelta('0 days 02:15:09'), Timedelta('0 days 01:55:55'), Timedelta('0 days 00:55:00'), Timedelta('0 days 00:24:53'), Timedelta('0 days 00:22:07'), Timedelta('0 days 00:22:06'), Timedelta('0 days 00:22:05'), Timedelta('0 days 00:16:50'), Timedelta('0 days 00:16:13'), Timedelta('0 days 00:16:09'), Timedelta('0 days 00:15:25'), Timedelta('0 days 00:15:10'), Timedelta('0 days 00:15:07'), Timedelta('0 days 00:14:22'), Timedelta('0 days 00:14:20'), Timedelta('0 days 00:14:06'), Timedelta('0 days 00:14:04'), Timedelta('0 days 00:13:59'), Timedelta('0 days 00:13:51'), Timedelta('0 days 00:13:46'), Timedelta('0 days 00:13:32'), Timedelta('0 days 00:13:23'), Timedelta('0 days 00:13:19'), Timedelta('0 days 00:13:15'), Timedelta('0 days 00:13:02'), Timedelta('0 days 00:12:18'), Timedelta('0 days 00:12:13'), Timedelta('0 days 00:12:03'), Timedelta('0 days 00:11:50'), Timedelta('0 days 00:11:15'), Timedelta('0 days 00:11:11'), Timedelta('0 days 00:10:52'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:51'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:50'), Timedelta('0 days 00:10:26'), Timedelta('0 days 00:09:51'), Timedelta('0 days 00:05:41'), Timedelta('0 days 00:05:39'), Timedelta('0 days 00:05:16'), Timedelta('0 days 00:05:10'), Timedelta('0 days 00:04:38'), Timedelta('0 days 00:04:23'), Timedelta('0 days 00:03:57'), Timedelta('0 days 00:03:41'), Timedelta('0 days 00:03:39'), Timedelta('0 days 00:02:42'), Timedelta('0 days 00:02:37'), Timedelta('0 days 00:02:36'), Timedelta('0 days 00:02:34'), Timedelta('0 days 00:01:35'), Timedelta('0 days 00:01:34'), Timedelta('0 days 00:01:32'), Timedelta('0 days 00:01:30'), Timedelta('0 days 00:01:23'), Timedelta('0 days 00:01:01'), Timedelta('0 days 00:01:00'), Timedelta('0 days 00:00:33'), Timedelta('0 days 00:00:32'), Timedelta('0 days 00:00:32'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00' ...
# normal-03-15-2022-15-43-44.csv : (Timedelta('0 days 03:39:57'), False, [Timedelta('0 days 02:56:52'), Timedelta('0 days 00:43:05')])
# normal-03-16-2022-13-44-27.csv : (Timedelta('0 days 03:36:39'), False, [Timedelta('0 days 03:19:06'), Timedelta('0 days 00:17:33')])
# normal-03-17-2022-16-21-30.csv : (Timedelta('0 days 13:38:09'), False, [Timedelta('0 days 09:32:00'), Timedelta('0 days 04:06:09')])
# normal-03-18-2022-19-17-31.csv : (Timedelta('0 days 19:03:07'), False, [Timedelta('0 days 06:33:06'), Timedelta('0 days 04:57:27'), Timedelta('0 days 04:00:30'), Timedelta('0 days 01:30:03'), Timedelta('0 days 01:21:20'), Timedelta('0 days 00:16:02'), Timedelta('0 days 00:14:16'), Timedelta('0 days 00:10:23')])
# normal-03-18-2022-19-25-48.csv : (Timedelta('0 days 18:48:03'), False, [Timedelta('0 days 08:01:22'), Timedelta('0 days 06:53:20'), Timedelta('0 days 01:15:40'), Timedelta('0 days 00:52:01'), Timedelta('0 days 00:45:02'), Timedelta('0 days 00:24:58'), Timedelta('0 days 00:15:22'), Timedelta('0 days 00:12:46'), Timedelta('0 days 00:06:08'), Timedelta('0 days 00:00:44'), Timedelta('0 days 00:00:40')])
# normal-03-19-2022-20-01-16.csv : (Timedelta('0 days 11:21:17'), False, [Timedelta('0 days 08:58:22'), Timedelta('0 days 02:22:55')])
# normal-03-20-2022-14-27-30.csv : (Timedelta('0 days 08:19:55'), False, [Timedelta('0 days 06:04:13'), Timedelta('0 days 02:15:42')])
# portscanning-03-15-2022-15-44-06.csv : (Timedelta('0 days 00:19:32'), True, [Timedelta('0 days 00:19:32')])
# portscanning-03-16-2022-13-44-50.csv : (Timedelta('0 days 00:33:57'), False, [Timedelta('0 days 00:33:57'), Timedelta('0 days 00:00:00')])
# portscanning-03-17-2022-16-22-53.csv : (Timedelta('0 days 00:18:25'), False, [Timedelta('0 days 00:09:13'), Timedelta('0 days 00:09:12'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00')])
# portscanning-03-18-2022-19-27-05.csv : (Timedelta('0 days 00:36:50'), False, [Timedelta('0 days 00:09:13'), Timedelta('0 days 00:09:13'), Timedelta('0 days 00:09:12'), Timedelta('0 days 00:09:12'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00')])
# portscanning-03-19-2022-20-01-45.csv : (Timedelta('0 days 00:48:34'), False, [Timedelta('0 days 00:24:18'), Timedelta('0 days 00:24:16'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00')])
# portscanning-03-20-2022-14-27-49.csv : (Timedelta('0 days 00:48:31'), False, [Timedelta('0 days 00:24:17'), Timedelta('0 days 00:24:14'), Timedelta('0 days 00:00:00'), Timedelta('0 days 00:00:00')])

# %% [markdown]
# Therefore, we consider the dataset as discontinous.
