# %% [markdown]
# # LUFlow Dataset Analysis
#
# * **Author:** Patrik Goldschmidt (igoldschmidt@fit.vut.cz)
# * **Project:** Network Intrusion Datasets: A Survey, Limitations, and Recommendations
# * **Date:** 2024
#
# Data source: [https://www.kaggle.com/datasets/mryanm/luflow-network-intrusion-detection-data-set](https://www.kaggle.com/datasets/mryanm/luflow-network-intrusion-detection-data-set)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

pd.set_option('display.max_columns', None)

# %%
DATA_PATH_BASE = '/data/disk2/luflow'

# %%
# List the paths to data and the number of files
all_paths = []

for path, subdirs, files in os.walk(DATA_PATH_BASE):
    for name in files:
        if name.endswith('.csv'):
            all_paths.append(os.path.join(path, name))

display(all_paths)

display(len(all_paths))
# Out:
# ['/data/disk2/luflow/2021/02/2021.02.09/2021.02.09.csv',
#  '/data/disk2/luflow/2021/02/2021.02.04/2021.02.04.csv',
#  '/data/disk2/luflow/2021/02/2021.02.03/2021.02.03.csv',
#  '/data/disk2/luflow/2021/02/2021.02.14/2021.02.14.csv',
#  '/data/disk2/luflow/2021/02/2021.02.08/2021.02.08.csv',
#  '/data/disk2/luflow/2021/02/2021.02.15/2021.02.15.csv',
#  '/data/disk2/luflow/2021/02/2021.02.05/2021.02.05.csv',
#  '/data/disk2/luflow/2021/02/2021.02.01/2021.02.01.csv',
#  '/data/disk2/luflow/2021/02/2021.02.07/2021.02.07.csv',
#  '/data/disk2/luflow/2021/02/2021.02.13/2021.02.13.csv',
#  '/data/disk2/luflow/2021/02/2021.02.17/2021.02.17.csv',
#  '/data/disk2/luflow/2021/02/2021.02.10/2021.02.10.csv',
#  '/data/disk2/luflow/2021/02/2021.02.06/2021.02.06.csv',
#  '/data/disk2/luflow/2021/02/2021.02.12/2021.02.12.csv',
#  '/data/disk2/luflow/2021/02/2021.02.11/2021.02.11.csv',
#  '/data/disk2/luflow/2021/02/2021.02.16/2021.02.16.csv',
#  '/data/disk2/luflow/2021/02/2021.02.02/2021.02.02.csv',
#  '/data/disk2/luflow/2021/01/2021.01.08/2021.01.08.csv',
#  '/data/disk2/luflow/2021/01/2021.01.15/2021.01.15.csv',
#  '/data/disk2/luflow/2021/01/2021.01.17/2021.01.17.csv',
#  '/data/disk2/luflow/2021/01/2021.01.01/2021.01.01.csv',
#  '/data/disk2/luflow/2021/01/2021.01.24/2021.01.24.csv',
#  '/data/disk2/luflow/2021/01/2021.01.14/2021.01.14.csv',
#  '/data/disk2/luflow/2021/01/2021.01.10/2021.01.10.csv',
#  '/data/disk2/luflow/2021/01/2021.01.02/2021.01.02.csv',
#  '/data/disk2/luflow/2021/01/2021.01.25/2021.01.25.csv',
#  '/data/disk2/luflow/2021/01/2021.01.30/2021.01.30.csv',
#  '/data/disk2/luflow/2021/01/2021.01.28/2021.01.28.csv',
#  '/data/disk2/luflow/2021/01/2021.01.06/2021.01.06.csv',
#  '/data/disk2/luflow/2021/01/2021.01.04/2021.01.04.csv',
#  '/data/disk2/luflow/2021/01/2021.01.07/2021.01.07.csv',
#  '/data/disk2/luflow/2021/01/2021.01.05/2021.01.05.csv',
#  '/data/disk2/luflow/2020/08/2020.08.02/2020.08.02.csv',
#  '/data/disk2/luflow/2020/08/2020.08.16/2020.08.16.csv',
#  '/data/disk2/luflow/2020/08/2020.08.09/2020.08.09.csv',
#  '/data/disk2/luflow/2020/08/2020.08.07/2020.08.07.csv',
#  '/data/disk2/luflow/2020/08/2020.08.08/2020.08.08.csv',
#  '/data/disk2/luflow/2020/08/2020.08.30/2020.08.30.csv',
#  '/data/disk2/luflow/2020/10/2020.10.09/2020.10.09.csv',
#  '/data/disk2/luflow/2020/10/2020.10.01/2020.10.01.csv',
#  '/data/disk2/luflow/2020/10/2020.10.17/2020.10.17.csv',
#  '/data/disk2/luflow/2020/10/2020.10.27/2020.10.27.csv',
#  '/data/disk2/luflow/2020/10/2020.10.26/2020.10.26.csv',
#  '/data/disk2/luflow/2020/10/2020.10.05/2020.10.05.csv',
#  '/data/disk2/luflow/2020/10/2020.10.16/2020.10.16.csv',
#  '/data/disk2/luflow/2020/10/2020.10.14/2020.10.14.csv',
#  '/data/disk2/luflow/2020/10/2020.10.18/2020.10.18.csv',
#  '/data/disk2/luflow/2020/10/2020.10.19/2020.10.19.csv',
#  '/data/disk2/luflow/2020/10/2020.10.06/2020.10.06.csv',
#  '/data/disk2/luflow/2020/10/2020.10.11/2020.10.11.csv',
#  '/data/disk2/luflow/2020/10/2020.10.22/2020.10.22.csv',
#  '/data/disk2/luflow/2020/10/2020.10.02/2020.10.02.csv',
#  '/data/disk2/luflow/2020/10/2020.10.13/2020.10.13.csv',
#  '/data/disk2/luflow/2020/10/2020.10.07/2020.10.07.csv',
#  '/data/disk2/luflow/2020/10/2020.10.10/2020.10.10.csv',
#  '/data/disk2/luflow/2020/10/2020.10.21/2020.10.21.csv',
#  '/data/disk2/luflow/2020/10/2020.10.12/2020.10.12.csv',
#  '/data/disk2/luflow/2020/10/2020.10.04/2020.10.04.csv',
#  '/data/disk2/luflow/2020/10/2020.10.30/2020.10.30.csv',
#  '/data/disk2/luflow/2020/10/2020.10.25/2020.10.25.csv',
#  '/data/disk2/luflow/2020/10/2020.10.08/2020.10.08.csv',
#  '/data/disk2/luflow/2020/10/2020.10.29/2020.10.29.csv',
#  '/data/disk2/luflow/2020/10/2020.10.28/2020.10.28.csv',
#  '/data/disk2/luflow/2020/10/2020.10.23/2020.10.23.csv',
#  '/data/disk2/luflow/2020/10/2020.10.24/2020.10.24.csv',
#  '/data/disk2/luflow/2020/10/2020.10.03/2020.10.03.csv',
#  '/data/disk2/luflow/2020/10/2020.10.20/2020.10.20.csv',
#  '/data/disk2/luflow/2020/10/2020.10.31/2020.10.31.csv',
#  '/data/disk2/luflow/2020/11/2020.11.13/2020.11.13.csv',
#  '/data/disk2/luflow/2020/11/2020.11.09/2020.11.09.csv',
#  '/data/disk2/luflow/2020/11/2020.11.25/2020.11.25.csv',
#  '/data/disk2/luflow/2020/11/2020.11.29/2020.11.29.csv',
#  '/data/disk2/luflow/2020/11/2020.11.03/2020.11.03.csv',
#  '/data/disk2/luflow/2020/11/2020.11.27/2020.11.27.csv',
# 241

# %% [markdown]
# ## Sample Analysis
#
# We choose a few indices in the list as samples to analyze together. Due to the sheer size of the data, we will stick to analyzing these three days instead of the whole capture.

# %%
sample_paths = [all_paths[0], all_paths[50], all_paths[75], all_paths[100], all_paths[125], all_paths[150], all_paths[175], all_paths[200]]
sample_paths
# Out:
# ['/data/disk2/luflow/2021/02/2021.02.09/2021.02.09.csv',
#  '/data/disk2/luflow/2020/08/2020.08.13/2020.08.13.csv',
#  '/data/disk2/luflow/2020/08/2020.08.16/2020.08.16.csv',
#  '/data/disk2/luflow/2020/10/2020.10.30/2020.10.30.csv',
#  '/data/disk2/luflow/2020/11/2020.11.04/2020.11.04.csv',
#  '/data/disk2/luflow/2020/09/2020.09.23/2020.09.23.csv',
#  '/data/disk2/luflow/2020/06/2020.06.19/2020.06.19.csv',
#  '/data/disk2/luflow/2020/12/2020.12.05/2020.12.05.csv']

# %%
data_sample = pd.DataFrame()

for filepath in sample_paths:
    data_sample = pd.concat([data_sample, pd.read_csv(filepath)])

# %%
data_sample.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7053658 entries, 0 to 861472
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   avg_ipt        7053658 non-null  float64
#  1   bytes_in       7053658 non-null  int64
#  2   bytes_out      7053658 non-null  int64
#  3   dest_ip        7053658 non-null  int64
#  4   dest_port      6929209 non-null  float64
#  5   entropy        7053658 non-null  float64
#  6   num_pkts_out   7053658 non-null  int64
#  7   num_pkts_in    7053658 non-null  int64
#  8   proto          7053658 non-null  int64
#  9   src_ip         7053658 non-null  int64
#  10  src_port       6929209 non-null  float64
#  11  time_end       7053658 non-null  int64
#  12  time_start     7053658 non-null  int64
#  13  total_entropy  7053658 non-null  float64
#  14  label          7053658 non-null  object
#  15  duration       7053658 non-null  float64
# dtypes: float64(6), int64(9), object(1)
# memory usage: 914.9+ MB

# %%
data_sample.describe()
# Out:
#             avg_ipt      bytes_in     bytes_out       dest_ip     dest_port  \
# count  7.053658e+06  7.053658e+06  7.053658e+06  7.053658e+06  6.929209e+06
# mean   2.465881e+06  5.759836e+02  2.670398e+03  3.441887e+03  1.327555e+04
# std    5.594121e+07  3.037122e+03  6.568602e+03  1.649473e+04  1.801170e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  3.000000e+00  1.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  7.860000e+02  4.450000e+02
# 50%    0.000000e+00  0.000000e+00  1.910000e+02  7.860000e+02  9.200000e+03
# 75%    1.300000e+01  2.700000e+02  2.021000e+03  7.860000e+02  9.200000e+03
# max    4.294967e+09  6.551200e+04  6.553500e+04  3.987220e+05  6.553500e+04
#
#             entropy  num_pkts_out   num_pkts_in         proto        src_ip  \
# count  7.053658e+06  7.053658e+06  7.053658e+06  7.053658e+06  7.053658e+06
# mean   3.232973e+00  5.884168e+00  3.596375e+00  6.349410e+00  2.185647e+04
# std    2.389113e+00  1.930359e+01  1.347172e+01  2.273362e+00  4.833059e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  3.000000e+00
# 25%    0.000000e+00  1.000000e+00  0.000000e+00  6.000000e+00  7.860000e+02
# 50%    3.832851e+00  2.000000e+00  1.000000e+00  6.000000e+00  7.860000e+02
# 75%    4.952367e+00  6.000000e+00  3.000000e+00  6.000000e+00  1.918200e+04
# max    9.393070e+01  2.550000e+02  2.550000e+02  1.320000e+02  3.987220e+05
#
#            src_port      time_end    time_start  total_entropy      duration
# count  6.929209e+06  7.053658e+06  7.053658e+06   7.053658e+06  7.053658e+06
# mean   4.057975e+04  1.455979e+15  1.455487e+15   1.132008e+04  1.028600e+00
# std    1.999321e+04  4.364175e+14  4.370664e+14   4.939051e+04  7.000111e+00
# min    1.000000e+00  1.592536e+10  1.592537e+10   0.000000e+00  0.000000e+00
# 25%    2.964400e+04  1.597293e+15  1.597292e+15   0.000000e+00  0.000000e+00
# 50%    5.003200e+04  1.600829e+15  1.600829e+15   2.109405e+03  1.670000e-04
# 75%    5.443800e+04  1.604463e+15  1.604463e+15   1.478296e+04  1.270980e-01
# max    6.553500e+04  1.612912e+15  1.612912e+15   5.413978e+06  1.007032e+04

# %%
data_sample.head()
# Out:
#       avg_ipt  bytes_in  bytes_out  dest_ip  dest_port    entropy  \
# 0  329.366667     19920      43375      786     9200.0  14.011390
# 1  354.571429       120         81      786       23.0   4.920487
# 2    0.000000         0          0      786       80.0   0.000000
# 3    0.000000        56         56      786        NaN   1.020244
# 4  301.240000       257         81      786       23.0   5.232285
#
#    num_pkts_out  num_pkts_in  proto  src_ip  src_port          time_end  \
# 0           224          134      6     786   42850.0  1612879933536483
# 1            20           27      6     786    6453.0  1612879927566457
# 2             1            5      6     786   34024.0  1612879912432857
# 3             1            1      1     786       NaN  1612879927204083
# 4            22           28      6     786    6441.0   161287992767784
#
#          time_start  total_entropy      label   duration
# 0  1612879903869536  886850.940000     benign  29.666946
# 1  1612879918705133     989.017940    outlier   8.861324
# 2  1612879912432857       0.000000  malicious   0.000000
# 3  1612879927203971     114.267365  malicious   0.000112
# 4  1612879918491693    1768.512300    outlier   9.186147

# %%
# Labels distribution
data_sample['label'].value_counts()
# Out:
# label
# benign       3535169
# malicious    2754751
# outlier       763738
# Name: count, dtype: int64

# %%
# IP addresses are anonymized via ordinal numbers
data_sample['src_ip'].value_counts()
# Out:
# src_ip
# 786       4061188
# 45899      181531
# 49877      131096
# 8048       112803
# 7552       111349
#            ...
# 32934           1
# 41682           1
# 49544           1
# 265862          1
# 34038           1
# Name: count, Length: 2101, dtype: int64

# %%
data_sample['dest_ip'].value_counts()
# Out:
# dest_ip
# 786       6592136
# 18403       54180
# 49877       32097
# 45090       27489
# 15169       26692
#            ...
# 40065           1
# 265887          1
# 15879           1
# 28591           1
# 34038           1
# Name: count, Length: 1022, dtype: int64

# %%
# Port distribution
data_sample['dest_port'].value_counts()
# Out:
# dest_port
# 9200.0     2561746
# 445.0      1918403
# 22.0        310432
# 5900.0      167620
# 5060.0      133589
#             ...
# 37240.0          1
# 33729.0          1
# 33542.0          1
# 31234.0          1
# 20373.0          1
# Name: count, Length: 59313, dtype: int64

# %% [markdown]
# Ports does not look anonymized, but most common - like 443 would be expected to be at the top ranks.
# What are these ports:
#
# | Port | Service |
# -------| --------|
# | 9200 | elasticsearch |
# | 445  | microsoft-ds |
# | 22   | ssh |
# | 5900 | vnc |
# | 5060 | sip |
#
# These ports look realistic, although their distribution is rather specific to the capture network and might not represent other network types, where these services would not be such predominant.

# %%
# How much does HTTP(S) cover - Only 0.003% ...
len(data_sample[data_sample['dest_port'] == 443]) / len(data_sample)
# Out:
# 0.003663914524917426

# %% [markdown]
# ### Prepare Paths for Every File Based on Their Month

# %%
# Split them by months
paths_bymonth = {}

for path in sorted(all_paths):
    year_month = os.path.split(path)[1].rsplit('.', maxsplit=2)[0]

    if year_month not in paths_bymonth:
        paths_bymonth[year_month] = []

    paths_bymonth[year_month].append(path)

paths_bymonth
# Out:
# {'2020.06': ['/data/disk2/luflow/2020/06/2020.06.19/2020.06.19.csv',
#   '/data/disk2/luflow/2020/06/2020.06.20/2020.06.20.csv',
#   '/data/disk2/luflow/2020/06/2020.06.21/2020.06.21.csv',
#   '/data/disk2/luflow/2020/06/2020.06.22/2020.06.22.csv',
#   '/data/disk2/luflow/2020/06/2020.06.23/2020.06.23.csv',
#   '/data/disk2/luflow/2020/06/2020.06.24/2020.06.24.csv',
#   '/data/disk2/luflow/2020/06/2020.06.25/2020.06.25.csv',
#   '/data/disk2/luflow/2020/06/2020.06.26/2020.06.26.csv',
#   '/data/disk2/luflow/2020/06/2020.06.27/2020.06.27.csv',
#   '/data/disk2/luflow/2020/06/2020.06.28/2020.06.28.csv',
#   '/data/disk2/luflow/2020/06/2020.06.29/2020.06.29.csv',
#   '/data/disk2/luflow/2020/06/2020.06.30/2020.06.30.csv'],
#  '2020.07': ['/data/disk2/luflow/2020/07/2020.07.01/2020.07.01.csv',
#   '/data/disk2/luflow/2020/07/2020.07.02/2020.07.02.csv',
#   '/data/disk2/luflow/2020/07/2020.07.03/2020.07.03.csv',
#   '/data/disk2/luflow/2020/07/2020.07.04/2020.07.04.csv',
#   '/data/disk2/luflow/2020/07/2020.07.05/2020.07.05.csv',
#   '/data/disk2/luflow/2020/07/2020.07.06/2020.07.06.csv',
#   '/data/disk2/luflow/2020/07/2020.07.07/2020.07.07.csv',
#   '/data/disk2/luflow/2020/07/2020.07.08/2020.07.08.csv',
#   '/data/disk2/luflow/2020/07/2020.07.09/2020.07.09.csv',
#   '/data/disk2/luflow/2020/07/2020.07.10/2020.07.10.csv',
#   '/data/disk2/luflow/2020/07/2020.07.11/2020.07.11.csv',
#   '/data/disk2/luflow/2020/07/2020.07.12/2020.07.12.csv',
#   '/data/disk2/luflow/2020/07/2020.07.13/2020.07.13.csv',
#   '/data/disk2/luflow/2020/07/2020.07.14/2020.07.14.csv',
#   '/data/disk2/luflow/2020/07/2020.07.15/2020.07.15.csv',
#   '/data/disk2/luflow/2020/07/2020.07.16/2020.07.16.csv',
#   '/data/disk2/luflow/2020/07/2020.07.17/2020.07.17.csv',
#   '/data/disk2/luflow/2020/07/2020.07.18/2020.07.18.csv',
#   '/data/disk2/luflow/2020/07/2020.07.19/2020.07.19.csv',
#   '/data/disk2/luflow/2020/07/2020.07.20/2020.07.20.csv',
#   '/data/disk2/luflow/2022/06/2022.06.13/2022.06.13.csv',
#   '/data/disk2/luflow/2022/06/2022.06.14/2022.06.14.csv']}

# %% [markdown]
# Based on this direct analysis, we see that the capture was ongoing from 2020-06-19 to 2021-02-17 continually and then 3 more days from 06-2022 are included. We will focus on analyzing 2020 and 2021 data for their continuity.

# %% [markdown]
# ### 2022 Captures Brief Analysis
#
# Analyze capture files from 2022 separately.

# %%
# Try to open 3 at once
display(paths_bymonth['2022.06'])

data2022 = pd.DataFrame()

for flowfile in paths_bymonth['2022.06']:
    data2022 = pd.concat([data2022, pd.read_csv(flowfile)])
# Out:
# ['/data/disk2/luflow/2022/06/2022.06.12/2022.06.12.csv',
#  '/data/disk2/luflow/2022/06/2022.06.13/2022.06.13.csv',
#  '/data/disk2/luflow/2022/06/2022.06.14/2022.06.14.csv']

# %%
data2022.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1068376 entries, 0 to 590085
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   avg_ipt        1068376 non-null  float64
#  1   bytes_in       1068376 non-null  int64
#  2   bytes_out      1068376 non-null  int64
#  3   dest_ip        1068376 non-null  int64
#  4   dest_port      964168 non-null   float64
#  5   entropy        1068376 non-null  float64
#  6   num_pkts_out   1068376 non-null  int64
#  7   num_pkts_in    1068376 non-null  int64
#  8   proto          1068376 non-null  int64
#  9   src_ip         1068376 non-null  int64
#  10  src_port       964168 non-null   float64
#  11  time_end       1068376 non-null  int64
#  12  time_start     1068376 non-null  int64
#  13  total_entropy  1068376 non-null  float64
#  14  label          1068376 non-null  object
#  15  duration       1068376 non-null  float64
# dtypes: float64(6), int64(9), object(1)
# memory usage: 138.6+ MB

# %%
data2022['src_ip'].value_counts()
# Out:
# src_ip
# 786    1068376
# Name: count, dtype: int64

# %%
data2022['dest_ip'].value_counts()
# Out:
# dest_ip
# 786    1068376
# Name: count, dtype: int64

# %%
data2022['label'].value_counts()
# Out:
# label
# benign       517210
# outlier      440178
# malicious    110988
# Name: count, dtype: int64

# %% [markdown]
# ## Timestamp and Other Analyses

# %%
# Timestamp format
data_sample['time_start'].head()
# Out:
# 0    1612879903869536
# 1    1612879918705133
# 2    1612879912432857
# 3    1612879927203971
# 4    1612879918491693
# Name: time_start, dtype: int64

# %%
# When we sort the timestamps, we observe that some are in microsecond and some in second precision...
data_sample['time_start'].sort_values()
# Out:
# 510977         15925366400
# 464890         15925373126
# 296203         15925397203
# 332537         15925398899
# 155338         15925403809
#                 ...
# 274391    1612912374009122
# 275284    1612912374009685
# 275285    1612912374009685
# 275679    1612912374009685
# 275283    1612912374009685
# Name: time_start, Length: 7053658, dtype: int64

# %% [markdown]
# We need to reformat these timestamps before any meaningful analysis can be made.

# %%
# Based on manual analysis, we need to fix the timestamps as follows:
# We want the timestamp to be in a millisecond precision, needing to add 00 or remove 000 from existing tstamps
def unify_timestamp_length(timestamp):
  """Unifies the length of a timestamp to 13 decimal digits.

  Args:
      timestamp: An integer representing the timestamp.

  Returns:
      A string representation of the timestamp with 13 decimal digits,
      right-padded with zeros if necessary. Truncates if longer than 13 digits.
  """
  timestamp_str = str(timestamp)

  if len(timestamp_str) > 13:
    return timestamp_str[:13]  # Truncate if longer than 13 digits
  else:
    return timestamp_str.ljust(13, '0')  # Right-pad with zeros if necessary

# %%
# Verify the function works
data_sample['time_start'].apply(unify_timestamp_length).sort_values()
# Out:
# 37435     1592524759061
# 37153     1592524764730
# 37413     1592524766901
# 37167     1592524766951
# 37412     1592524767904
#               ...
# 274388    1612912374009
# 274395    1612912374009
# 274392    1612912374009
# 274390    1612912374009
# 275288    1612912374009
# Name: time_start, Length: 7053658, dtype: object

# %%
# Function for measuring capture duration
def measure_real_capture_dur(data: pd.Series, gap_max_secs: int = 300) -> float:
    """Computes total timespan of the capture. Expects iterable containing timestamps objects sorted in a descending manner"""
    total_dur = pd.Timedelta(seconds=0)
    current_dur = pd.Timedelta(seconds=0)
    cont_durations = []
    last_tstamp = data.iloc[0]
    contiguous = True

    # Iterate through the dataframe to find out gaps
    for cur_tstamp in data:
        dur_gap = last_tstamp - cur_tstamp

        if dur_gap <= pd.Timedelta(seconds=gap_max_secs):
            total_dur += dur_gap
            current_dur += dur_gap
        else:
            cont_durations.append(current_dur)
            current_dur = pd.Timedelta(seconds=0)

            if contiguous:
                contiguous = False

        last_tstamp = cur_tstamp

    # Log the final continuous block and sort them via their length
    cont_durations.append(current_dur)
    cont_durations.sort(reverse=True)

    return total_dur, contiguous, cont_durations

# %% [markdown]
# Now, Go day-by-day and search for capture gaps.

# %%
# Iterate every other entry and determine continuity
for month, paths in paths_bymonth.items():
    for datapath in paths:
        file = os.path.splitext(os.path.basename('/data/disk2/luflow/2020/07/2020.07.23/2020.07.23.csv'))[0]
        # Load the file
        data = pd.read_csv(datapath)

        # Normalize timestamps, sort in a descending manner and covert to relevent structure
        timestamps = data['time_start'].apply(unify_timestamp_length).astype(np.int64)
        timestamps = timestamps.sort_values(ascending=False)
        timestamps = pd.to_datetime(timestamps, origin='unix', unit='ms')

        # Print the result of capture duration/continuity analysis, 1% of 24h seconds = 864s (14.4m)
        print(f"{file} : {measure_real_capture_dur(timestamps)}")
# Out:
# 2020.07.23 : (Timedelta('1 days 00:00:24.009000'), True, [Timedelta('1 days 00:00:24.009000')])
# 2020.07.23 : (Timedelta('1 days 00:00:23.967000'), True, [Timedelta('1 days 00:00:23.967000')])
# 2020.07.23 : (Timedelta('1 days 00:00:23.387000'), True, [Timedelta('1 days 00:00:23.387000')])
# 2020.07.23 : (Timedelta('1 days 00:00:31.926000'), True, [Timedelta('1 days 00:00:31.926000')])
# 2020.07.23 : (Timedelta('1 days 00:00:43.610000'), False, [Timedelta('1 days 00:00:25.975000'), Timedelta('0 days 00:00:17.635000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.838000'), True, [Timedelta('1 days 00:00:15.838000')])
# 2020.07.23 : (Timedelta('1 days 00:00:37.176000'), True, [Timedelta('1 days 00:00:37.176000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.213000'), True, [Timedelta('1 days 00:00:16.213000')])
# 2020.07.23 : (Timedelta('1 days 00:00:11.298000'), True, [Timedelta('1 days 00:00:11.298000')])
# 2020.07.23 : (Timedelta('1 days 00:00:19.160000'), True, [Timedelta('1 days 00:00:19.160000')])
# 2020.07.23 : (Timedelta('1 days 00:00:25.026000'), True, [Timedelta('1 days 00:00:25.026000')])
# 2020.07.23 : (Timedelta('1 days 00:00:18.439000'), True, [Timedelta('1 days 00:00:18.439000')])
# 2020.07.23 : (Timedelta('1 days 00:00:28.804000'), True, [Timedelta('1 days 00:00:28.804000')])
# 2020.07.23 : (Timedelta('1 days 00:00:11.625000'), True, [Timedelta('1 days 00:00:11.625000')])
# 2020.07.23 : (Timedelta('1 days 00:00:14.737000'), True, [Timedelta('1 days 00:00:14.737000')])
# 2020.07.23 : (Timedelta('1 days 00:00:25.763000'), True, [Timedelta('1 days 00:00:25.763000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.441000'), True, [Timedelta('1 days 00:00:16.441000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.364000'), True, [Timedelta('1 days 00:00:26.364000')])
# 2020.07.23 : (Timedelta('1 days 00:15:31.728000'), True, [Timedelta('1 days 00:15:31.728000')])
# 2020.07.23 : (Timedelta('1 days 00:00:43.978000'), True, [Timedelta('1 days 00:00:43.978000')])
# 2020.07.23 : (Timedelta('1 days 00:00:20.952000'), True, [Timedelta('1 days 00:00:20.952000')])
# 2020.07.23 : (Timedelta('1 days 00:00:25.659000'), True, [Timedelta('1 days 00:00:25.659000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.464000'), True, [Timedelta('1 days 00:00:16.464000')])
# 2020.07.23 : (Timedelta('1 days 00:00:32.316000'), True, [Timedelta('1 days 00:00:32.316000')])
# 2020.07.23 : (Timedelta('1 days 00:00:28.742000'), True, [Timedelta('1 days 00:00:28.742000')])
# 2020.07.23 : (Timedelta('1 days 00:00:39.146000'), True, [Timedelta('1 days 00:00:39.146000')])
# 2020.07.23 : (Timedelta('1 days 00:00:24.448000'), True, [Timedelta('1 days 00:00:24.448000')])
# 2020.07.23 : (Timedelta('1 days 00:00:32.366000'), True, [Timedelta('1 days 00:00:32.366000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.333000'), True, [Timedelta('1 days 00:00:15.333000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.294000'), True, [Timedelta('1 days 00:00:22.294000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.803000'), True, [Timedelta('1 days 00:00:15.803000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.841000'), True, [Timedelta('1 days 00:00:16.841000')])
# 2020.07.23 : (Timedelta('1 days 00:00:44.374000'), True, [Timedelta('1 days 00:00:44.374000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.078000'), True, [Timedelta('1 days 00:00:15.078000')])
# 2020.07.23 : (Timedelta('1 days 00:37:33.734000'), True, [Timedelta('1 days 00:37:33.734000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.244000'), True, [Timedelta('1 days 00:00:26.244000')])
# 2020.07.23 : (Timedelta('1 days 00:00:09.287000'), True, [Timedelta('1 days 00:00:09.287000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.414000'), True, [Timedelta('1 days 00:00:26.414000')])
# 2020.07.23 : (Timedelta('1 days 00:00:33.566000'), True, [Timedelta('1 days 00:00:33.566000')])
# 2020.07.23 : (Timedelta('1 days 00:00:35.101000'), True, [Timedelta('1 days 00:00:35.101000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.224000'), True, [Timedelta('1 days 00:00:21.224000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.061000'), True, [Timedelta('1 days 00:00:22.061000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.444000'), True, [Timedelta('1 days 00:00:26.444000')])
# 2020.07.23 : (Timedelta('1 days 00:00:29.847000'), True, [Timedelta('1 days 00:00:29.847000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.340000'), True, [Timedelta('1 days 00:00:26.340000')])
# 2020.07.23 : (Timedelta('0 days 23:55:50.827000'), True, [Timedelta('0 days 23:55:50.827000')])
# 2020.07.23 : (Timedelta('1 days 00:04:25.096000'), True, [Timedelta('1 days 00:04:25.096000')])
# 2020.07.23 : (Timedelta('3 days 02:41:44.811000'), True, [Timedelta('3 days 02:41:44.811000')])
# 2020.07.23 : (Timedelta('1 days 00:00:19.917000'), True, [Timedelta('1 days 00:00:19.917000')])
# 2020.07.23 : (Timedelta('1 days 00:00:29.432000'), True, [Timedelta('1 days 00:00:29.432000')])
# 2020.07.23 : (Timedelta('1 days 00:00:29.905000'), True, [Timedelta('1 days 00:00:29.905000')])
# 2020.07.23 : (Timedelta('1 days 00:00:25.169000'), True, [Timedelta('1 days 00:00:25.169000')])
# 2020.07.23 : (Timedelta('1 days 00:00:46.277000'), True, [Timedelta('1 days 00:00:46.277000')])
# 2020.07.23 : (Timedelta('0 days 22:55:07.078000'), True, [Timedelta('0 days 22:55:07.078000')])
# 2020.07.23 : (Timedelta('1 days 01:04:59.293000'), True, [Timedelta('1 days 01:04:59.293000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.406000'), True, [Timedelta('1 days 00:00:22.406000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.830000'), True, [Timedelta('1 days 00:00:15.830000')])
# 2020.07.23 : (Timedelta('0 days 23:43:47.182000'), False, [Timedelta('0 days 21:16:25.985000'), Timedelta('0 days 02:27:21.197000')])
# 2020.07.23 : (Timedelta('0 days 23:40:04.469000'), False, [Timedelta('0 days 12:51:58.149000'), Timedelta('0 days 08:19:29.504000'), Timedelta('0 days 02:28:36.816000')])
# 2020.07.23 : (Timedelta('0 days 23:53:23.319000'), False, [Timedelta('0 days 21:25:56.496000'), Timedelta('0 days 02:27:26.823000')])
# 2020.07.23 : (Timedelta('0 days 23:44:22.079000'), False, [Timedelta('0 days 21:17:03.158000'), Timedelta('0 days 02:27:18.921000')])
# 2020.07.23 : (Timedelta('0 days 23:45:38.987000'), False, [Timedelta('0 days 21:18:06.866000'), Timedelta('0 days 02:27:32.121000')])
# 2020.07.23 : (Timedelta('0 days 23:45:10.106000'), False, [Timedelta('0 days 21:17:48.449000'), Timedelta('0 days 02:27:21.657000')])
# 2020.07.23 : (Timedelta('0 days 23:40:39.465000'), False, [Timedelta('0 days 21:12:08.794000'), Timedelta('0 days 02:28:30.671000')])
# 2020.07.23 : (Timedelta('0 days 21:12:30.416000'), False, [Timedelta('0 days 15:32:59.801000'), Timedelta('0 days 05:39:30.615000')])
# 2020.07.23 : (Timedelta('0 days 23:55:06.810000'), False, [Timedelta('0 days 15:28:05.320000'), Timedelta('0 days 08:27:01.490000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.058000'), True, [Timedelta('1 days 00:00:16.058000')])
# 2020.07.23 : (Timedelta('0 days 23:43:21.150000'), False, [Timedelta('0 days 21:16:12.528000'), Timedelta('0 days 02:27:08.622000')])
# 2020.07.23 : (Timedelta('1 days 01:34:33.193000'), True, [Timedelta('1 days 01:34:33.193000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.133000'), True, [Timedelta('1 days 00:00:22.133000')])
# 2020.07.23 : (Timedelta('0 days 23:43:16.335000'), False, [Timedelta('0 days 21:16:03.808000'), Timedelta('0 days 02:27:12.527000')])
# 2020.07.23 : (Timedelta('0 days 23:54:42.212000'), False, [Timedelta('0 days 21:27:31.048000'), Timedelta('0 days 02:27:11.164000')])
# 2020.07.23 : (Timedelta('0 days 23:42:02.903000'), False, [Timedelta('0 days 12:47:54.123000'), Timedelta('0 days 08:26:46.650000'), Timedelta('0 days 02:27:22.130000')])
# 2020.07.23 : (Timedelta('0 days 23:54:55.411000'), False, [Timedelta('0 days 21:27:26.903000'), Timedelta('0 days 02:27:28.508000')])
# 2020.07.23 : (Timedelta('0 days 23:43:14.273000'), False, [Timedelta('0 days 21:15:02.578000'), Timedelta('0 days 02:28:11.695000')])
# 2020.07.23 : (Timedelta('8 days 01:34:28.569000'), True, [Timedelta('8 days 01:34:28.569000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.523000'), True, [Timedelta('1 days 00:00:21.523000')])
# 2020.07.23 : (Timedelta('0 days 23:46:44.457000'), False, [Timedelta('0 days 21:19:19.498000'), Timedelta('0 days 02:27:24.959000')])
# 2020.07.23 : (Timedelta('0 days 16:36:11.714000'), True, [Timedelta('0 days 16:36:11.714000')])
# 2020.07.23 : (Timedelta('0 days 20:40:51.970000'), True, [Timedelta('0 days 20:40:51.970000')])
# 2020.07.23 : (Timedelta('1 days 00:00:06.272000'), True, [Timedelta('1 days 00:00:06.272000')])
# 2020.07.23 : (Timedelta('0 days 23:45:26.046000'), False, [Timedelta('0 days 21:18:04.085000'), Timedelta('0 days 02:27:21.961000')])
# 2020.07.23 : (Timedelta('0 days 01:00:26.349000'), True, [Timedelta('0 days 01:00:26.349000')])
# 2020.07.23 : (Timedelta('0 days 21:19:03.605000'), True, [Timedelta('0 days 21:19:03.605000')])
# 2020.07.23 : (Timedelta('0 days 23:44:43.004000'), False, [Timedelta('0 days 21:17:28.829000'), Timedelta('0 days 02:27:14.175000')])
# 2020.07.23 : (Timedelta('0 days 23:41:41.847000'), False, [Timedelta('0 days 21:14:16.501000'), Timedelta('0 days 02:27:25.346000')])
# 2020.07.23 : (Timedelta('0 days 23:38:03.007000'), False, [Timedelta('0 days 12:47:14.033000'), Timedelta('0 days 08:23:34.163000'), Timedelta('0 days 02:27:14.811000')])
# 2020.07.23 : (Timedelta('0 days 23:38:32.116000'), False, [Timedelta('0 days 21:10:56.725000'), Timedelta('0 days 02:27:35.391000')])
# 2020.07.23 : (Timedelta('0 days 21:06:34.387000'), False, [Timedelta('0 days 09:37:28.749000'), Timedelta('0 days 09:01:54.475000'), Timedelta('0 days 02:27:11.163000')])
# 2020.07.23 : (Timedelta('1 days 00:00:06.474000'), True, [Timedelta('1 days 00:00:06.474000')])
# 2020.07.23 : (Timedelta('6 days 23:57:38.174000'), False, [Timedelta('6 days 00:45:57.128000'), Timedelta('0 days 20:44:09.187000'), Timedelta('0 days 02:27:31.859000')])
# 2020.07.23 : (Timedelta('0 days 14:51:56.862000'), True, [Timedelta('0 days 14:51:56.862000')])
# 2020.07.23 : (Timedelta('0 days 21:10:50.703000'), True, [Timedelta('0 days 21:10:50.703000')])
# 2020.07.23 : (Timedelta('0 days 23:38:18.735000'), False, [Timedelta('0 days 12:46:33.681000'), Timedelta('0 days 08:24:16.284000'), Timedelta('0 days 02:27:28.770000')])
# 2020.07.23 : (Timedelta('0 days 23:53:04.989000'), False, [Timedelta('0 days 21:25:41.988000'), Timedelta('0 days 02:27:23.001000')])
# 2020.07.23 : (Timedelta('0 days 20:53:53.634000'), False, [Timedelta('0 days 14:00:59.143000'), Timedelta('0 days 04:25:36.021000'), Timedelta('0 days 02:27:18.470000')])
# 2020.07.23 : (Timedelta('0 days 23:54:49.273000'), False, [Timedelta('0 days 21:27:06.233000'), Timedelta('0 days 02:27:43.040000')])
# 2020.07.23 : (Timedelta('1 days 00:00:14.940000'), True, [Timedelta('1 days 00:00:14.940000')])
# 2020.07.23 : (Timedelta('0 days 23:59:58.543000'), True, [Timedelta('0 days 23:59:58.543000')])
# 2020.07.23 : (Timedelta('1 days 00:02:41.386000'), False, [Timedelta('1 days 00:00:24.016000'), Timedelta('0 days 00:02:17.370000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.602000'), True, [Timedelta('1 days 00:00:22.602000')])
# 2020.07.23 : (Timedelta('1 days 00:00:13.679000'), True, [Timedelta('1 days 00:00:13.679000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.700000'), True, [Timedelta('1 days 00:00:15.700000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.295000'), True, [Timedelta('1 days 00:00:16.295000')])
# 2020.07.23 : (Timedelta('1 days 00:00:09.190000'), True, [Timedelta('1 days 00:00:09.190000')])
# 2020.07.23 : (Timedelta('1 days 00:00:19.116000'), True, [Timedelta('1 days 00:00:19.116000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.413000'), True, [Timedelta('1 days 00:00:26.413000')])
# 2020.07.23 : (Timedelta('1 days 00:00:18.725000'), True, [Timedelta('1 days 00:00:18.725000')])
# 2020.07.23 : (Timedelta('1 days 00:00:05.753000'), True, [Timedelta('1 days 00:00:05.753000')])
# 2020.07.23 : (Timedelta('1 days 00:07:57.919000'), True, [Timedelta('1 days 00:07:57.919000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.015000'), True, [Timedelta('1 days 00:00:22.015000')])
# 2020.07.23 : (Timedelta('1 days 00:00:17.392000'), True, [Timedelta('1 days 00:00:17.392000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.049000'), True, [Timedelta('1 days 00:00:22.049000')])
# 2020.07.23 : (Timedelta('1 days 00:00:19.420000'), True, [Timedelta('1 days 00:00:19.420000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.497000'), True, [Timedelta('1 days 00:00:21.497000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.435000'), True, [Timedelta('1 days 00:00:26.435000')])
# 2020.07.23 : (Timedelta('1 days 08:16:44.940000'), True, [Timedelta('1 days 08:16:44.940000')])
# 2020.07.23 : (Timedelta('0 days 21:21:45.502000'), False, [Timedelta('0 days 11:10:26.042000'), Timedelta('0 days 10:11:19.460000')])
# 2020.07.23 : (Timedelta('0 days 20:13:07.733000'), True, [Timedelta('0 days 20:13:07.733000')])
# 2020.07.23 : (Timedelta('1 days 00:00:17.945000'), True, [Timedelta('1 days 00:00:17.945000')])
# 2020.07.23 : (Timedelta('0 days 23:36:04.962000'), False, [Timedelta('0 days 12:44:22.928000'), Timedelta('0 days 08:24:12.691000'), Timedelta('0 days 02:27:29.343000')])
# 2020.07.23 : (Timedelta('1 days 00:00:20.019000'), True, [Timedelta('1 days 00:00:20.019000')])
# 2020.07.23 : (Timedelta('0 days 23:42:35.495000'), False, [Timedelta('0 days 21:15:13.922000'), Timedelta('0 days 02:27:21.573000')])
# 2020.07.23 : (Timedelta('0 days 21:56:58.050000'), False, [Timedelta('0 days 19:29:28.137000'), Timedelta('0 days 02:27:29.913000')])
# 2020.07.23 : (Timedelta('0 days 23:41:33.989000'), False, [Timedelta('0 days 21:14:12.885000'), Timedelta('0 days 02:27:21.104000')])
# 2020.07.23 : (Timedelta('0 days 23:43:06.133000'), False, [Timedelta('0 days 21:15:42.835000'), Timedelta('0 days 02:27:23.298000')])
# 2020.07.23 : (Timedelta('0 days 23:43:10.580000'), False, [Timedelta('0 days 21:15:46.426000'), Timedelta('0 days 02:27:24.154000')])
# 2020.07.23 : (Timedelta('0 days 23:34:06.710000'), False, [Timedelta('0 days 12:43:31.988000'), Timedelta('0 days 07:23:14.484000'), Timedelta('0 days 03:27:20.238000')])
# 2020.07.23 : (Timedelta('0 days 21:14:53.852000'), False, [Timedelta('0 days 14:21:04.831000'), Timedelta('0 days 03:27:15.928000'), Timedelta('0 days 03:26:33.093000')])
# 2020.07.23 : (Timedelta('1 days 00:00:17.011000'), True, [Timedelta('1 days 00:00:17.011000')])
# 2020.07.23 : (Timedelta('0 days 23:41:41.123000'), False, [Timedelta('0 days 20:14:15.900000'), Timedelta('0 days 03:27:25.223000')])
# 2020.07.23 : (Timedelta('0 days 23:42:01.364000'), False, [Timedelta('0 days 20:14:36.542000'), Timedelta('0 days 03:27:24.822000')])
# 2020.07.23 : (Timedelta('0 days 23:39:48.982000'), False, [Timedelta('0 days 20:12:27.183000'), Timedelta('0 days 03:27:21.799000')])
# 2020.07.23 : (Timedelta('0 days 23:44:51.059000'), False, [Timedelta('0 days 20:17:36.985000'), Timedelta('0 days 03:27:14.074000')])
# 2020.07.23 : (Timedelta('0 days 23:35:01.352000'), False, [Timedelta('0 days 12:45:03.928000'), Timedelta('0 days 07:22:38.734000'), Timedelta('0 days 03:27:18.690000')])
# 2020.07.23 : (Timedelta('0 days 23:53:18.910000'), False, [Timedelta('0 days 20:25:02.776000'), Timedelta('0 days 03:28:16.134000')])
# 2020.07.23 : (Timedelta('0 days 23:44:18.913000'), False, [Timedelta('0 days 20:17:06.876000'), Timedelta('0 days 03:27:12.037000')])
# 2020.07.23 : (Timedelta('0 days 23:42:48.432000'), False, [Timedelta('0 days 20:15:25.960000'), Timedelta('0 days 03:27:22.472000')])
# 2020.07.23 : (Timedelta('0 days 23:42:49.763000'), False, [Timedelta('0 days 20:15:22.604000'), Timedelta('0 days 03:27:27.159000')])
# 2020.07.23 : (Timedelta('0 days 23:45:06.311000'), False, [Timedelta('0 days 20:17:43.104000'), Timedelta('0 days 03:27:23.207000')])
# 2020.07.23 : (Timedelta('0 days 23:46:21.851000'), False, [Timedelta('0 days 20:18:04.150000'), Timedelta('0 days 03:28:17.701000')])
# 2020.07.23 : (Timedelta('0 days 23:35:01.748000'), False, [Timedelta('0 days 12:48:08.003000'), Timedelta('0 days 07:19:32.563000'), Timedelta('0 days 03:27:21.182000')])
# 2020.07.23 : (Timedelta('0 days 23:52:43.879000'), False, [Timedelta('0 days 20:25:31.937000'), Timedelta('0 days 03:27:11.942000')])
# 2020.07.23 : (Timedelta('0 days 23:45:20.461000'), False, [Timedelta('0 days 20:17:58.784000'), Timedelta('0 days 03:27:21.677000')])
# 2020.07.23 : (Timedelta('0 days 23:40:16.731000'), False, [Timedelta('0 days 20:12:52.645000'), Timedelta('0 days 03:27:24.086000')])
# 2020.07.23 : (Timedelta('0 days 20:35:55.378000'), False, [Timedelta('0 days 17:08:32.390000'), Timedelta('0 days 03:27:22.988000')])
# 2020.07.23 : (Timedelta('0 days 19:42:16.218000'), True, [Timedelta('0 days 19:42:16.218000')])
# 2020.07.23 : (Timedelta('0 days 23:43:59.212000'), False, [Timedelta('0 days 20:16:44.826000'), Timedelta('0 days 03:27:14.386000')])
# 2020.07.23 : (Timedelta('0 days 23:38:16.556000'), False, [Timedelta('0 days 12:48:31.581000'), Timedelta('0 days 07:22:24.194000'), Timedelta('0 days 03:27:20.781000')])
# 2020.07.23 : (Timedelta('0 days 23:53:34.271000'), False, [Timedelta('0 days 20:26:16.628000'), Timedelta('0 days 03:27:17.643000')])
# 2020.07.23 : (Timedelta('0 days 23:46:28.147000'), False, [Timedelta('0 days 20:18:59.199000'), Timedelta('0 days 03:27:28.948000')])
# 2020.07.23 : (Timedelta('0 days 23:44:55.564000'), False, [Timedelta('0 days 20:17:29.803000'), Timedelta('0 days 03:27:25.761000')])
# 2020.07.23 : (Timedelta('1 days 00:00:35.159000'), True, [Timedelta('1 days 00:00:35.159000')])
# 2020.07.23 : (Timedelta('1 days 00:00:11.198000'), True, [Timedelta('1 days 00:00:11.198000')])
# 2020.07.23 : (Timedelta('1 days 00:00:20.024000'), True, [Timedelta('1 days 00:00:20.024000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.634000'), True, [Timedelta('1 days 00:00:22.634000')])
# 2020.07.23 : (Timedelta('1 days 00:00:24.403000'), True, [Timedelta('1 days 00:00:24.403000')])
# 2020.07.23 : (Timedelta('1 days 00:00:18.275000'), True, [Timedelta('1 days 00:00:18.275000')])
# 2020.07.23 : (Timedelta('1 days 00:00:15.138000'), True, [Timedelta('1 days 00:00:15.138000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.918000'), True, [Timedelta('1 days 00:00:21.918000')])
# 2020.07.23 : (Timedelta('1 days 00:00:10.424000'), True, [Timedelta('1 days 00:00:10.424000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.949000'), True, [Timedelta('1 days 00:00:21.949000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.144000'), True, [Timedelta('1 days 00:00:21.144000')])
# 2020.07.23 : (Timedelta('1 days 00:00:24.777000'), True, [Timedelta('1 days 00:00:24.777000')])
# 2020.07.23 : (Timedelta('1 days 00:00:32.100000'), True, [Timedelta('1 days 00:00:32.100000')])
# 2020.07.23 : (Timedelta('1 days 00:00:27.084000'), True, [Timedelta('1 days 00:00:27.084000')])
# 2020.07.23 : (Timedelta('1 days 00:00:14.353000'), True, [Timedelta('1 days 00:00:14.353000')])
# 2020.07.23 : (Timedelta('1 days 00:00:17.711000'), True, [Timedelta('1 days 00:00:17.711000')])
# 2020.07.23 : (Timedelta('1 days 00:00:16.911000'), True, [Timedelta('1 days 00:00:16.911000')])
# 2020.07.23 : (Timedelta('1 days 00:00:13.246000'), True, [Timedelta('1 days 00:00:13.246000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.336000'), True, [Timedelta('1 days 00:00:21.336000')])
# 2020.07.23 : (Timedelta('1 days 00:00:38.274000'), True, [Timedelta('1 days 00:00:38.274000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.338000'), True, [Timedelta('1 days 00:00:21.338000')])
# 2020.07.23 : (Timedelta('1 days 00:00:09.339000'), True, [Timedelta('1 days 00:00:09.339000')])
# 2020.07.23 : (Timedelta('1 days 00:00:26.361000'), True, [Timedelta('1 days 00:00:26.361000')])
# 2020.07.23 : (Timedelta('1 days 00:00:28.720000'), True, [Timedelta('1 days 00:00:28.720000')])
# 2020.07.23 : (Timedelta('1 days 00:00:20.851000'), True, [Timedelta('1 days 00:00:20.851000')])
# 2020.07.23 : (Timedelta('1 days 00:00:21.192000'), True, [Timedelta('1 days 00:00:21.192000')])
# 2020.07.23 : (Timedelta('1 days 00:00:32.984000'), True, [Timedelta('1 days 00:00:32.984000')])
# 2020.07.23 : (Timedelta('1 days 00:00:06.905000'), True, [Timedelta('1 days 00:00:06.905000')])
# 2020.07.23 : (Timedelta('1 days 00:00:07.171000'), True, [Timedelta('1 days 00:00:07.171000')])
# 2020.07.23 : (Timedelta('1 days 00:00:02.905000'), True, [Timedelta('1 days 00:00:02.905000')])
# 2020.07.23 : (Timedelta('1 days 00:00:19.283000'), True, [Timedelta('1 days 00:00:19.283000')])
# 2020.07.23 : (Timedelta('0 days 23:59:51.887000'), True, [Timedelta('0 days 23:59:51.887000')])
# 2020.07.23 : (Timedelta('1 days 00:00:13.343000'), True, [Timedelta('1 days 00:00:13.343000')])
# 2020.07.23 : (Timedelta('1 days 00:00:05.647000'), True, [Timedelta('1 days 00:00:05.647000')])
# 2020.07.23 : (Timedelta('1 days 00:00:01.833000'), True, [Timedelta('1 days 00:00:01.833000')])
# 2020.07.23 : (Timedelta('1 days 00:00:03.940000'), True, [Timedelta('1 days 00:00:03.940000')])
# 2020.07.23 : (Timedelta('1 days 00:00:00.865000'), True, [Timedelta('1 days 00:00:00.865000')])
# 2020.07.23 : (Timedelta('1 days 00:00:22.143000'), True, [Timedelta('1 days 00:00:22.143000')])
# 2020.07.23 : (Timedelta('1 days 00:00:10.015000'), True, [Timedelta('1 days 00:00:10.015000')])
# 2020.07.23 : (Timedelta('1 days 00:00:09.902000'), True, [Timedelta('1 days 00:00:09.902000')])
# 2020.07.23 : (Timedelta('1 days 00:00:17.463000'), True, [Timedelta('1 days 00:00:17.463000')])
# 2020.07.23 : (Timedelta('1 days 00:00:03.796000'), True, [Timedelta('1 days 00:00:03.796000')])
# 2020.07.23 : (Timedelta('1 days 00:00:14.779000'), True, [Timedelta('1 days 00:00:14.779000')])
# 2020.07.23 : (Timedelta('1 days 00:00:19.334000'), True, [Timedelta('1 days 00:00:19.334000')])
# 2020.07.23 : (Timedelta('1 days 00:00:09.432000'), True, [Timedelta('1 days 00:00:09.432000')])
# 2020.07.23 : (Timedelta('1 days 00:00:08.214000'), True, [Timedelta('1 days 00:00:08.214000')])
# 2020.07.23 : (Timedelta('2 days 04:08:15.300000'), False, [Timedelta('1 days 04:07:48.985000'), Timedelta('1 days 00:00:26.315000')])
# 2020.07.23 : (Timedelta('0 days 23:26:43.643000'), False, [Timedelta('0 days 19:59:14.458000'), Timedelta('0 days 03:27:29.185000')])
# 2020.07.23 : (Timedelta('0 days 22:14:47.636000'), False, [Timedelta('0 days 18:47:15.882000'), Timedelta('0 days 03:27:31.754000')])
# 2020.07.23 : (Timedelta('0 days 23:36:01.083000'), False, [Timedelta('0 days 12:43:48.348000'), Timedelta('0 days 07:24:49.418000'), Timedelta('0 days 03:27:23.317000')])
# 2020.07.23 : (Timedelta('0 days 20:54:23.168000'), False, [Timedelta('0 days 14:37:19.185000'), Timedelta('0 days 03:27:24.622000'), Timedelta('0 days 02:49:39.361000')])
# 2020.07.23 : (Timedelta('0 days 23:54:38.172000'), False, [Timedelta('0 days 20:26:59.063000'), Timedelta('0 days 03:27:39.109000')])
# 2020.07.23 : (Timedelta('0 days 23:33:13.290000'), False, [Timedelta('0 days 20:05:50.075000'), Timedelta('0 days 03:27:23.215000')])
# 2020.07.23 : (Timedelta('0 days 23:33:42.908000'), False, [Timedelta('0 days 20:06:23.298000'), Timedelta('0 days 03:27:19.610000')])
# 2020.07.23 : (Timedelta('0 days 23:09:06.015000'), False, [Timedelta('0 days 19:41:42.631000'), Timedelta('0 days 03:27:23.384000')])
# 2020.07.23 : (Timedelta('0 days 23:04:39.016000'), False, [Timedelta('0 days 19:57:47.870000'), Timedelta('0 days 03:06:51.146000')])
# 2020.07.23 : (Timedelta('0 days 23:34:56.977000'), False, [Timedelta('0 days 20:07:24.805000'), Timedelta('0 days 03:27:32.172000')])
# 2020.07.23 : (Timedelta('0 days 23:40:40.902000'), False, [Timedelta('0 days 20:13:12.721000'), Timedelta('0 days 03:27:28.181000')])
# 2020.07.23 : (Timedelta('2 days 03:11:29.704000'), False, [Timedelta('1 days 03:30:45.061000'), Timedelta('0 days 20:12:18.469000'), Timedelta('0 days 03:28:26.174000')])
# 2020.07.23 : (Timedelta('0 days 23:06:23.106000'), False, [Timedelta('0 days 19:38:49.664000'), Timedelta('0 days 03:27:33.442000')])
# 2020.07.23 : (Timedelta('0 days 23:34:42.073000'), False, [Timedelta('0 days 20:07:12.461000'), Timedelta('0 days 03:27:29.612000')])
# 2020.07.23 : (Timedelta('0 days 23:28:41.455000'), False, [Timedelta('0 days 12:42:52.948000'), Timedelta('0 days 07:18:22.589000'), Timedelta('0 days 03:27:25.918000')])
# 2020.07.23 : (Timedelta('0 days 23:59:03.621000'), False, [Timedelta('0 days 20:23:11.029000'), Timedelta('0 days 03:35:52.592000')])
# 2020.07.23 : (Timedelta('0 days 23:54:19.263000'), False, [Timedelta('0 days 20:26:37.746000'), Timedelta('0 days 03:27:41.517000')])
# 2020.07.23 : (Timedelta('0 days 09:17:02.605000'), False, [Timedelta('0 days 06:00:12.078000'), Timedelta('0 days 03:16:50.527000')])
# 2020.07.23 : (Timedelta('0 days 19:12:20.731000'), True, [Timedelta('0 days 19:12:20.731000')])
# 2020.07.23 : (Timedelta('0 days 23:20:25.615000'), False, [Timedelta('0 days 19:53:11.171000'), Timedelta('0 days 03:27:14.444000')])
# 2020.07.23 : (Timedelta('0 days 23:41:04.189000'), False, [Timedelta('0 days 20:13:38.977000'), Timedelta('0 days 03:27:25.212000')])
# 2020.07.23 : (Timedelta('0 days 07:57:30.562000'), False, [Timedelta('0 days 04:30:24.583000'), Timedelta('0 days 03:27:05.979000')])
# 2020.07.23 : (Timedelta('0 days 20:23:49.816000'), True, [Timedelta('0 days 20:23:49.816000')])
# 2020.07.23 : (Timedelta('0 days 23:38:25.063000'), False, [Timedelta('0 days 20:10:58.294000'), Timedelta('0 days 03:27:26.769000')])
# 2020.07.23 : (Timedelta('0 days 23:39:24.942000'), False, [Timedelta('0 days 20:12:01.477000'), Timedelta('0 days 03:27:23.465000')])
# 2020.07.23 : (Timedelta('0 days 23:38:29.268000'), False, [Timedelta('0 days 20:11:06.078000'), Timedelta('0 days 03:27:23.190000')])
# 2020.07.23 : (Timedelta('0 days 23:53:48.880000'), False, [Timedelta('0 days 20:26:29.251000'), Timedelta('0 days 03:27:19.629000')])
# 2020.07.23 : (Timedelta('0 days 23:38:11.836000'), False, [Timedelta('0 days 20:10:51.660000'), Timedelta('0 days 03:27:20.176000')])
# 2020.07.23 : (Timedelta('0 days 23:01:57.970000'), False, [Timedelta('0 days 12:44:48.272000'), Timedelta('0 days 06:49:45.203000'), Timedelta('0 days 03:27:24.495000')])
# 2020.07.23 : (Timedelta('0 days 23:49:16.960000'), False, [Timedelta('0 days 20:21:44.818000'), Timedelta('0 days 03:27:32.142000')])
# 2020.07.23 : (Timedelta('0 days 22:49:52.774000'), False, [Timedelta('0 days 19:22:28.855000'), Timedelta('0 days 03:27:23.919000')])
# 2020.07.23 : (Timedelta('0 days 19:25:07.508000'), False, [Timedelta('0 days 15:11:14.627000'), Timedelta('0 days 04:13:52.881000')])
# 2020.07.23 : (Timedelta('0 days 20:00:42.851000'), True, [Timedelta('0 days 20:00:42.851000')])
# 2020.07.23 : (Timedelta('0 days 22:17:37.232000'), False, [Timedelta('0 days 20:31:16.914000'), Timedelta('0 days 01:46:20.318000')])
# 2020.07.23 : (Timedelta('0 days 09:17:56.039000'), False, [Timedelta('0 days 05:50:28.992000'), Timedelta('0 days 03:27:27.047000')])
# 2020.07.23 : (Timedelta('0 days 17:58:36.710000'), True, [Timedelta('0 days 17:58:36.710000')])
# 2020.07.23 : (Timedelta('0 days 23:52:45.476000'), False, [Timedelta('0 days 20:25:15.616000'), Timedelta('0 days 03:27:29.860000')])
# 2020.07.23 : (Timedelta('0 days 23:28:14.219000'), False, [Timedelta('0 days 20:07:04.775000'), Timedelta('0 days 03:21:09.444000')])
# 2020.07.23 : (Timedelta('0 days 10:35:58.038000'), False, [Timedelta('0 days 07:08:34.879000'), Timedelta('0 days 03:27:23.159000')])
# 2020.07.23 : (Timedelta('0 days 02:56:17.715000'), True, [Timedelta('0 days 02:56:17.715000')])
# 2020.07.23 : (Timedelta('0 days 23:41:53.727000'), False, [Timedelta('0 days 21:14:53.328000'), Timedelta('0 days 02:27:00.399000')])
# 2020.07.23 : (Timedelta('1 days 00:00:13.521000'), True, [Timedelta('1 days 00:00:13.521000')])

# %% [markdown]
# Looks like these daily captures are more-less continuous.

# %% [markdown]
# ### General Information About Each Month

# %%
UNIQ_IPS_THRESHOLD = 25


# Based on manual analysis, we need to fix the timestamps as follows:
# We want the timestamp to be in a millisecond precision, needing to add 00 or remove 000 from existing tstamps
def unify_timestamp_length(timestamp):
  """Unifies the length of a timestamp to 13 decimal digits.

  Args:
      timestamp: An integer representing the timestamp.

  Returns:
      A string representation of the timestamp with 13 decimal digits,
      right-padded with zeros if necessary. Truncates if longer than 13 digits.
  """
  timestamp_str = str(timestamp)

  if len(timestamp_str) > 13:
    return timestamp_str[:13]  # Truncate if longer than 13 digits
  else:
    return timestamp_str.ljust(13, '0')  # Right-pad with zeros if necessary


def provide_capture_info(paths: list) -> None:
    uniq_ips    = set()
    files_cnt    = 0
    flows_total = 0
    dur_total   = 0

    for flows_path in paths:
        flows_df = pd.read_csv(flows_path)

        # Update unique IP set
        ips_activity = flows_df['src_ip'].value_counts()
        uniq_ips = uniq_ips.union(set(ips_activity[ips_activity > 100].keys()))

        ips_activity = flows_df['dest_ip'].value_counts()
        uniq_ips = uniq_ips.union(set(ips_activity[ips_activity > 100].keys()))

        # Determine duration
        start_stamp = flows_df['time_start'].apply(unify_timestamp_length).sort_values().iloc[0]
        end_stamp   = flows_df['time_end'].apply(unify_timestamp_length).sort_values().iloc[-1]

        dur_total += (int(end_stamp) - int(start_stamp)) // 1000

        # Update counters
        files_cnt   += 1
        flows_total += len(flows_df)

    return {'uniq_ips': uniq_ips, 'files_cnt': files_cnt, 'flows_total': flows_total, 'dur_total': dur_total}

# %%
# Provide capture info for all months and summary as well
total_stats = {
    'uniq_ips':  set(),
    'files_cnt': 0,
    'flows_total': 0,
    'dur_total': 0
}

for month, month_data in paths_bymonth.items():
    month_stats = provide_capture_info(month_data)
    total_stats['uniq_ips'] = total_stats['uniq_ips'].union(month_stats['uniq_ips'])
    total_stats['files_cnt'] += month_stats['files_cnt']
    total_stats['flows_total'] += month_stats['flows_total']
    total_stats['dur_total'] += month_stats['dur_total']

    month_stats['uniq_ips'] = len(month_stats['uniq_ips'])

    print(month)
    print(f'{month_stats}\n')
# Out:
# 2020.06
# {'uniq_ips': 870, 'files_cnt': 12, 'flows_total': 12594630, 'dur_total': 1045956}
#
# 2020.07
# {'uniq_ips': 1403, 'files_cnt': 31, 'flows_total': 25056405, 'dur_total': 2682483}
#
# 2020.08
# {'uniq_ips': 1534, 'files_cnt': 31, 'flows_total': 24652019, 'dur_total': 2867225}
#
# 2020.09
# {'uniq_ips': 1668, 'files_cnt': 30, 'flows_total': 26206532, 'dur_total': 5912330}
#
# 2020.10
# {'uniq_ips': 1760, 'files_cnt': 30, 'flows_total': 26948169, 'dur_total': 2609290}
#
# 2020.11
# {'uniq_ips': 1676, 'files_cnt': 30, 'flows_total': 27679773, 'dur_total': 2566000}
#
# 2020.12
# {'uniq_ips': 1122, 'files_cnt': 28, 'flows_total': 20689199, 'dur_total': 2419855}
#
# 2021.01
# {'uniq_ips': 1083, 'files_cnt': 29, 'flows_total': 26986466, 'dur_total': 18422712}
#
# 2021.02
# {'uniq_ips': 1, 'files_cnt': 17, 'flows_total': 14674978, 'dur_total': 1304073}
#
# 2022.06
# {'uniq_ips': 1, 'files_cnt': 3, 'flows_total': 1068376, 'dur_total': 183398}

# %%
# Total number of unique IPs above 25 flows per day"
print(len(total_stats['uniq_ips']))
print(total_stats['files_cnt'])
print(total_stats['flows_total'])
print(total_stats['dur_total'])
# Out:
# 4489
# 241
# 206556547
# 40013322

# %% [markdown]
# ### Investigation of Broken Files With Timestamps

# %%
# Find out which file in the set is broken
def find_faulty_captures(month_files_list: list):
    for file_path in month_files_list:
        file_pd = pd.read_csv(file_path)

        start = int(file_pd['time_start'].apply(unify_timestamp_length).sort_values().iloc[0])
        end   = int(file_pd['time_end'].apply(unify_timestamp_length).sort_values().iloc[-1])

        diff = (end - start) / 1000 / 3600

        if diff > 24.25:
            print(f'{file_path} : {diff}')

# %%
# Files from 2021.01 and 2020.09 look sketchy
find_faulty_captures(paths_bymonth['2021.01'])
# Out:
# /data/disk2/luflow/2021/01/2021.01.07/2021.01.07.csv : 2095.9662933333334
# /data/disk2/luflow/2021/01/2021.01.20/2021.01.20.csv : 2407.9639880555555

# %%
find_faulty_captures(paths_bymonth['2020.09'])
# Out:
# /data/disk2/luflow/2020/09/2020.09.02/2020.09.02.csv : 193.5781397222222
# /data/disk2/luflow/2020/09/2020.09.17/2020.09.17.csv : 823.4335019444444
# /data/disk2/luflow/2020/09/2020.09.26/2020.09.26.csv : 25.534390277777774

# %%
# Let us analyze some of these faulty captures
faulty_sample = pd.read_csv(os.path.join(DATA_PATH_BASE, '2021/01/2021.01.07/2021.01.07.csv'))
faulty_sample_sort_start = faulty_sample['time_start'].apply(unify_timestamp_length).sort_values()
faulty_sample_sort_end   = faulty_sample['time_end'].apply(unify_timestamp_length).sort_values()

# %%
faulty_sample_sort_start
# Out:
# 2186590    1602518516255
# 2186593    1602518517878
# 2186591    1602518518261
# 2186592    1602518518811
# 2186594    1602518519048
#                ...
# 2730253    1610063987267
# 2730255    1610063987527
# 2730256    1610063987799
# 2730257    1610063988008
# 2730258    1610063988066
# Name: time_start, Length: 2730274, dtype: object

# %% [markdown]
# Apparently, there are some old feature vectors - see it before unification.

# %%
# Before unification
faulty_sample['time_start'].sort_values().head()
# Out:
# 893572     16099906359
# 902157     16099917048
# 1155085    16099923453
# 985410     16099923639
# 1185359    16099924370
# Name: time_start, dtype: int64

# %%
# After unification - are the timestamps 1602* really there or just unification fks them up somehow?
faulty_sample['time_start'].apply(unify_timestamp_length).sort_values().head()
# Out:
# 2186590    1602518516255
# 2186593    1602518517878
# 2186591    1602518518261
# 2186592    1602518518811
# 2186594    1602518519048
# Name: time_start, dtype: object

# %%
# Select indices with '11' legth and discard them
length_11 = faulty_sample[faulty_sample['time_start'] > 200000000000]
length_11['time_start'].sort_values()
# Out:
# 2184362       1602520007326
# 2184364       1602520007328
# 2656086       1602524705624
# 2183128       1602525677093
# 2180790       1602529483742
#                  ...
# 2730245    1610063986922806
# 2730253    1610063987267019
# 2730255    1610063987527807
# 2730256    1610063987799245
# 2730258    1610063988066807
# Name: time_start, Length: 2729977, dtype: int64

# %% [markdown]
# As apparent, several flows contain timestamps from October 2020, therefore significantly breaking the duration measurement.

# %%
# Leave only relevant timestamped flows in from January 2021 to see whether other captures are fine
after_jan = faulty_sample[faulty_sample['time_start'] > 1609459200000]

# %%
after_jan['time_start'].sort_values()
# Out:
# 887528        1609979427388
# 887634        1609979609239
# 887914        1609980734992
# 887993        1609981297904
# 889075        1609981459439
#                  ...
# 2730245    1610063986922806
# 2730253    1610063987267019
# 2730255    1610063987527807
# 2730256    1610063987799245
# 2730258    1610063988066807
# Name: time_start, Length: 2729945, dtype: int64

# %% [markdown]
# In this case, it is rather correct. Consider full day captures for the purpose of duration reporting, although these timestamps are relatively buggy after all.
