# %% [markdown]
# # CIDDS-001 Dataset Analysis
#
# * **Author:** Patrik Goldschmidt (igoldschmidt@fit.vut.cz)
# * **Project:** Network Intrusion Datasets: A Survey, Limitations, and Recommendations
# * **Date:** 2024

# %%
import pandas as pd
import numpy as np
import os

pd.set_option('display.max_columns', None)

# %%
FOLDER_INTERNAL = 'CIDDS-001/traffic/OpenStack'
FOLDER_EXTERNAL = 'CIDDS-001/traffic/ExternalServer'

# %% [markdown]
# ## Internal Traffic Analysis

# %%
internal_files = os.listdir(FOLDER_INTERNAL)
internal_files
# Out:
# ['CIDDS-001-internal-week2.csv',
#  'CIDDS-001-internal-week1.csv',
#  'CIDDS-001-internal-week3.csv',
#  'CIDDS-001-internal-week4.csv']

# %%
data = pd.DataFrame()

for data_path in internal_files:
    fullpath = os.path.join(FOLDER_INTERNAL, data_path)

    data = pd.concat([data, pd.read_csv(fullpath)])
# Out:
# /tmp/ipykernel_233052/4023927870.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.concat([data, pd.read_csv(fullpath)])
# /tmp/ipykernel_233052/4023927870.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.concat([data, pd.read_csv(fullpath)])
# /tmp/ipykernel_233052/4023927870.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.concat([data, pd.read_csv(fullpath)])
# /tmp/ipykernel_233052/4023927870.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.concat([data, pd.read_csv(fullpath)])

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31287933 entries, 0 to 6175896
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Date first seen    object
#  1   Duration           float64
#  2   Proto              object
#  3   Src IP Addr        object
#  4   Src Pt             int64
#  5   Dst IP Addr        object
#  6   Dst Pt             float64
#  7   Packets            int64
#  8   Bytes              object
#  9   Flows              int64
#  10  Flags              object
#  11  Tos                int64
#  12  class              object
#  13  attackType         object
#  14  attackID           object
#  15  attackDescription  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 4.0+ GB

# %%
data.describe()
# Out:
#            Duration        Src Pt        Dst Pt       Packets       Flows  \
# count  3.128793e+07  3.128793e+07  3.128793e+07  3.128793e+07  31287933.0
# mean   1.232569e-01  2.463138e+04  2.441451e+04  1.535089e+01         1.0
# std    8.024699e-01  2.509684e+04  2.509105e+04  9.847063e+02         0.0
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00         1.0
# 25%    0.000000e+00  8.000000e+01  8.000000e+01  1.000000e+00         1.0
# 50%    0.000000e+00  8.082000e+03  8.082000e+03  2.000000e+00         1.0
# 75%    3.100000e-02  5.008000e+04  4.999600e+04  3.000000e+00         1.0
# max    2.380080e+02  6.553500e+04  6.553500e+04  2.087680e+05         1.0
#
#                 Tos
# count  3.128793e+07
# mean   9.817501e+00
# std    1.504512e+01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    3.200000e+01
# max    1.920000e+02

# %%
data.head(5)
# Out:
#            Date first seen  Duration  Proto     Src IP Addr  Src Pt  \
# 0  2017-03-22 00:00:00.071     0.000  TCP     192.168.100.5     445
# 1  2017-03-22 00:00:00.070     0.002  TCP    192.168.220.14   42718
# 2  2017-03-22 00:00:05.953     0.002  TCP    192.168.220.10   59594
# 3  2017-03-22 00:00:05.955     0.000  TCP     192.168.100.5     445
# 4  2017-03-22 00:00:06.468     0.000  TCP         10022_204      80
#
#       Dst IP Addr   Dst Pt  Packets Bytes  Flows   Flags  Tos   class  \
# 0  192.168.220.14  42718.0        1   108      1  .AP...    0  normal
# 1   192.168.100.5    445.0        2   174      1  .AP...    0  normal
# 2   192.168.100.5    445.0        2   174      1  .AP...    0  normal
# 3  192.168.220.10  59594.0        1   108      1  .AP...    0  normal
# 4   192.168.210.5  61252.0        1    66      1  .A....   32  normal
#
#   attackType attackID attackDescription
# 0        ---      ---               ---
# 1        ---      ---               ---
# 2        ---      ---               ---
# 3        ---      ---               ---
# 4        ---      ---               ---

# %%
data['class'].value_counts()
# Out:
# class
# normal      28051906
# attacker     1656605
# victim       1579422
# Name: count, dtype: int64

# %%
data['attackType'].value_counts()
# Out:
# attackType
# ---           28051906
# dos            2959027
# portScan        265918
# pingScan          6090
# bruteForce        4992
# Name: count, dtype: int64

# %%
data['attackID'].value_counts()
# Out:
# attackID
# ---    28051906
# 53       516299
# 60       333627
# 18       295302
# 44       261169
#          ...
# 70          240
# 25          201
# 54          183
# 15           64
# 30           46
# Name: count, Length: 71, dtype: int64

# %%
data['attackDescription'].value_counts()
# Out:
# attackDescription
# ---                                      28235324
# 10000 connections on 192.168.100.6:80     2775655
# nmap args: -sS -T 2                        103470
# nmap args: -sS -T 3                         95361
# nmap args: -sS -T 1                         67087
# nmap args: -n -sP -PE -T 2                   2804
# nmap args: -n -sP -PE -T 1                   2449
# 192.168.210.4                                1811
# nmap args: -n -sP -PE -T 3                    837
# 192.168.210.5                                 705
# 192.168.200.8                                 680
# 192.168.200.4                                 565
# 192.168.210.3                                 427
# 192.168.100.4                                 335
# 192.168.100.2                                 240
# 192.168.210.2                                 183
# Name: count, dtype: int64

# %% [markdown]
# ### Time Continuity Determination

# %%
data['timestamp'] = pd.to_datetime(data['Date first seen'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
data_sorted = data.sort_values(by='timestamp', ascending=False).reset_index(drop=True)
data_sorted
# Out:
#                   Date first seen  Duration  Proto     Src IP Addr  Src Pt  \
# 0         2017-04-18 23:59:30.203     0.083  TCP          10068_66     443
# 1         2017-04-18 23:59:30.183     0.083  TCP     192.168.200.8   58432
# 2         2017-04-18 23:59:30.175     0.000  UDP               DNS      53
# 3         2017-04-18 23:59:30.175     0.000  UDP               DNS      53
# 4         2017-04-18 23:59:30.173     0.000  UDP     192.168.200.8   54577
# ...                           ...       ...    ...             ...     ...
# 31287928  2017-03-15 00:01:16.631     0.004  TCP    192.168.220.16   58844
# 31287929  2017-03-15 00:01:16.631     0.004  TCP    192.168.220.16   58844
# 31287930  2017-03-15 00:01:16.552     0.000  TCP     192.168.100.5     445
# 31287931  2017-03-15 00:01:16.552     0.000  TCP     192.168.100.5     445
# 31287932  2017-03-15 00:01:16.551     0.004  TCP    192.168.220.15   48888
#
#              Dst IP Addr   Dst Pt  Packets     Bytes  Flows   Flags  Tos  \
# 0          192.168.200.8  58432.0       13      2304      1  .AP.S.   32
# 1               10068_66    443.0       13      2168      1  .AP.S.    0
# 2          192.168.200.8  54577.0        1       128      1  ......    0
# 3          192.168.200.8  62120.0        1       128      1  ......    0
# 4                    DNS     53.0        1        87      1  ......    0
# ...                  ...      ...      ...       ...    ...     ...  ...
# 31287928   192.168.100.5    445.0        2       174      1  .AP...    0
# 31287929   192.168.100.5    445.0        2       174      1  .AP...    0
# 31287930  192.168.220.15  48888.0        1       108      1  .AP...    0
# 31287931  192.168.220.15  48888.0        1       108      1  .AP...    0
# 31287932   192.168.100.5    445.0        2       174      1  .AP...    0
#
#            class attackType attackID attackDescription               timestamp
# 0         normal        ---      ---               --- 2017-04-18 23:59:30.203
# 1         normal        ---      ---               --- 2017-04-18 23:59:30.183
# 2         normal        ---      ---               --- 2017-04-18 23:59:30.175
# 3         normal        ---      ---               --- 2017-04-18 23:59:30.175
# 4         normal        ---      ---               --- 2017-04-18 23:59:30.173
# ...          ...        ...      ...               ...                     ...
# 31287928  normal        ---      ---               --- 2017-03-15 00:01:16.631
# 31287929  normal        ---      ---               --- 2017-03-15 00:01:16.631
# 31287930  normal        ---      ---               --- 2017-03-15 00:01:16.552
# 31287931  normal        ---      ---               --- 2017-03-15 00:01:16.552
# 31287932  normal        ---      ---               --- 2017-03-15 00:01:16.551
#
# [31287933 rows x 17 columns]

# %%
time_span = data_sorted['timestamp'].iloc[0] - data_sorted['timestamp'].iloc[-1]
time_span
# Out:
# Timedelta('34 days 23:58:13.652000')

# %%
# Span is 35 days -> convert to secs.
time_span.total_seconds()
# Out:
# 3023893.652

# %%
# Are there gaps in the data (was the capture interrupted?)
def measure_real_capture_dur(data: pd.Series, gap_max_secs: int = 300) -> float:
    """Computes total timespan of the capture. Expects iterable containing timestamps objects sorted in a descending manner"""
    total_dur = pd.Timedelta(seconds=0)
    current_dur = pd.Timedelta(seconds=0)
    cont_durations = []
    last_tstamp = data.iloc[0]
    contiguous = True

    # Iterate through the dataframe to find out gaps
    for cur_tstamp in data:
        dur_gap = last_tstamp - cur_tstamp

        if dur_gap <= pd.Timedelta(seconds=gap_max_secs):
            total_dur += dur_gap
            current_dur += dur_gap
        else:
            cont_durations.append(current_dur)
            current_dur = pd.Timedelta(seconds=0)

            if contiguous:
                contiguous = False

        last_tstamp = cur_tstamp

    # Log the final continuous block and sort them via their length
    cont_durations.append(current_dur)
    cont_durations.sort(reverse=True)

    return total_dur, contiguous, cont_durations

# %%
measure_real_capture_dur(data_sorted['timestamp'], int(time_span.total_seconds() * 0.01))
# Out:
# (Timedelta('27 days 23:56:34.524000'),
#  False,
#  [Timedelta('13 days 23:59:29.937000'), Timedelta('13 days 23:57:04.587000')])

# %% [markdown]
# Only one discontinuous block directly at the middle. This can definitely be considered as continuous.

# %% [markdown]
# ## External Traffic Analysis

# %%
external_files = os.listdir(FOLDER_EXTERNAL)
external_files
# Out:
# ['CIDDS-001-external-week2.csv',
#  'CIDDS-001-external-week1.csv',
#  'CIDDS-001-external-week4.csv',
#  'CIDDS-001-external-week3.csv']

# %%
data = pd.DataFrame()

for data_path in external_files:
    fullpath = os.path.join(FOLDER_EXTERNAL, data_path)

    data = pd.concat([data, pd.read_csv(fullpath)])
# Out:
# /tmp/ipykernel_233052/3236146686.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.concat([data, pd.read_csv(fullpath)])

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 671241 entries, 0 to 153025
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date first seen    671241 non-null  object
#  1   Duration           671241 non-null  float64
#  2   Proto              671241 non-null  object
#  3   Src IP Addr        671241 non-null  object
#  4   Src Pt             671241 non-null  int64
#  5   Dst IP Addr        671241 non-null  object
#  6   Dst Pt             671241 non-null  float64
#  7   Packets            671241 non-null  int64
#  8   Bytes              671241 non-null  object
#  9   Flows              671241 non-null  int64
#  10  Flags              671241 non-null  object
#  11  Tos                671241 non-null  int64
#  12  class              671241 non-null  object
#  13  attackType         671241 non-null  object
#  14  attackID           671241 non-null  object
#  15  attackDescription  671241 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 87.1+ MB

# %%
data.describe()
# Out:
#             Duration         Src Pt         Dst Pt        Packets     Flows  \
# count  671241.000000  671241.000000  671241.000000  671241.000000  671241.0
# mean      109.457693   22546.259770   22280.267540      24.010060       1.0
# std      5091.732802   23975.273445   23942.463329    1044.981629       0.0
# min         0.000000       0.000000       0.000000       1.000000       1.0
# 25%         0.062000      22.000000      22.000000       5.000000       1.0
# 50%         7.018000    8000.000000    8000.000000       8.000000       1.0
# 75%        11.692000   49302.000000   49075.000000      19.000000       1.0
# max    604817.074000   65535.000000   65535.000000  176609.000000       1.0
#
#             Tos
# count  671241.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data.head(5)
# Out:
#            Date first seen  Duration  Proto Src IP Addr  Src Pt Dst IP Addr  \
# 0  2017-03-22 00:00:14.461       0.0  TCP      19394_40   54719  EXT_SERVER
# 1  2017-03-22 00:00:14.461       0.0  TCP    EXT_SERVER      23    19394_40
# 2  2017-03-22 00:00:33.525       0.0  TCP      19395_18    4622  EXT_SERVER
# 3  2017-03-22 00:00:33.525       0.0  TCP    EXT_SERVER    7547    19395_18
# 4  2017-03-22 00:00:40.205       0.0  TCP     11246_253    6000  EXT_SERVER
#
#     Dst Pt  Packets     Bytes  Flows   Flags  Tos       class attackType  \
# 0     23.0        1        46      1  ....S.    0  suspicious        ---
# 1  54719.0        1        40      1  .A.R..    0  suspicious        ---
# 2   7547.0        1        46      1  ....S.    0  suspicious        ---
# 3   4622.0        1        40      1  .A.R..    0  suspicious        ---
# 4   3306.0        1        46      1  ....S.    0  suspicious        ---
#
#   attackID attackDescription
# 0      ---               ---
# 1      ---               ---
# 2      ---               ---
# 3      ---               ---
# 4      ---               ---

# %%
data['class'].value_counts()
# Out:
# class
# suspicious    437911
# normal        134240
# unknown        77923
# attacker       12260
# victim          8907
# Name: count, dtype: int64

# %%
data['attackType'].value_counts()
# Out:
# attackType
# ---           650074
# portScan       18719
# bruteForce      2448
# Name: count, dtype: int64

# %%
data['attackID'].value_counts()
# Out:
# attackID
# ---    650074
# 7        6410
# 1        2008
# 2        2002
# 16       2002
# 10       1991
# 15       1984
# 12       1370
# 19        952
# 17        200
# 14        200
# 13        200
# 11        200
# 8         200
# 9         200
# 3         200
# 20        200
# 5         200
# 4         200
# 18        200
# 6         168
# 22         40
# 21         40
# Name: count, dtype: int64

# %%
data['attackDescription'].value_counts()
# Out:
# attackDescription
# ---                    654852
# nmap args: -sS -T 2     11348
# nmap args: -sU -T 2      3361
# 100 passwords            1600
# 20 passwords               80
# Name: count, dtype: int64

# %% [markdown]
# ### Duration and Continuity Analysis

# %%
data['timestamp'] = pd.to_datetime(data['Date first seen'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
data_sorted = data.sort_values(by='timestamp', ascending=False).reset_index(drop=True)
data_sorted
# Out:
#                 Date first seen    Duration  Proto    Src IP Addr  Src Pt  \
# 0       2017-04-18 23:59:55.951      11.320  TCP       EXT_SERVER      22
# 1       2017-04-18 23:59:55.951      11.320  TCP         32955_33   30190
# 2       2017-04-18 23:59:50.947      33.003  TCP       EXT_SERVER      22
# 3       2017-04-18 23:59:50.947      33.003  TCP         32955_33   36255
# 4       2017-04-18 23:59:40.840       0.062  TCP    OPENSTACK_NET   54379
# ...                         ...         ...    ...            ...     ...
# 671236  2017-03-14 17:43:57.172   81412.697  TCP       EXT_SERVER    8082
# 671237  2017-03-14 17:43:39.011  183418.493  TCP       EXT_SERVER    8082
# 671238  2017-03-14 17:43:39.011  183418.493  TCP    OPENSTACK_NET   60802
# 671239  2017-03-14 17:43:26.135   81504.787  TCP    OPENSTACK_NET   56979
# 671240  2017-03-14 17:43:26.135   81504.787  TCP       EXT_SERVER    8082
#
#           Dst IP Addr   Dst Pt  Packets     Bytes  Flows   Flags  Tos  \
# 0            32955_33  30190.0       21      3493      1  .AP.S.    0
# 1          EXT_SERVER     22.0       17      2267      1  .APRSF    0
# 2            32955_33  36255.0        8       480      1  .A..S.    0
# 3          EXT_SERVER     22.0        3       180      1  ....S.    0
# 4          EXT_SERVER   8000.0        6       515      1  .AP.SF    0
# ...               ...      ...      ...       ...    ...     ...  ...
# 671236  OPENSTACK_NET  56978.0     3057     2.1 M      1  .AP...    0
# 671237  OPENSTACK_NET  60802.0    13266    33.0 M      1  .AP...    0
# 671238     EXT_SERVER   8082.0    20751     5.8 M      1  .AP...    0
# 671239     EXT_SERVER   8082.0    12024    10.3 M      1  .AP...    0
# 671240  OPENSTACK_NET  56979.0     8639     9.1 M      1  .AP...    0
#
#              class attackType attackID attackDescription  \
# 0       suspicious        ---      ---               ---
# 1       suspicious        ---      ---               ---
# 2       suspicious        ---      ---               ---
# 3       suspicious        ---      ---               ---
# 4           normal        ---      ---               ---
# ...            ...        ...      ...               ...
# 671236      normal        ---      ---               ---
# 671237      normal        ---      ---               ---
# 671238      normal        ---      ---               ---
# 671239      normal        ---      ---               ---
# 671240      normal        ---      ---               ---
#
#                      timestamp
# 0      2017-04-18 23:59:55.951
# 1      2017-04-18 23:59:55.951
# 2      2017-04-18 23:59:50.947
# 3      2017-04-18 23:59:50.947
# 4      2017-04-18 23:59:40.840
# ...                        ...
# 671236 2017-03-14 17:43:57.172
# 671237 2017-03-14 17:43:39.011
# 671238 2017-03-14 17:43:39.011
# 671239 2017-03-14 17:43:26.135
# 671240 2017-03-14 17:43:26.135
#
# [671241 rows x 17 columns]

# %%
time_span = data_sorted['timestamp'].iloc[0] - data_sorted['timestamp'].iloc[-1]
time_span
# Out:
# Timedelta('35 days 06:16:29.816000')

# %%
# Span is 35 days -> convert to secs.
time_span.total_seconds()
# Out:
# 3046589.816

# %%
measure_real_capture_dur(data_sorted['timestamp'], int(time_span.total_seconds() * 0.01))
# Out:
# (Timedelta('28 days 06:16:06.029000'),
#  False,
#  [Timedelta('14 days 06:16:19.269000'), Timedelta('13 days 23:59:46.760000')])

# %% [markdown]
# Again - one gap appeared. However, at different time - so - if we put the data together, the capture itself is continuous.
