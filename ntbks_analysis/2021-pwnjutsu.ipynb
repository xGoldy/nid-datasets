# %% [markdown]
# # PWNJUTSU Dataset Analysis
#
# * **Author:** Patrik Goldschmidt (igoldschmidt@fit.vut.cz)
# * **Project:** Network Intrusion Datasets: A Survey, Limitations, and Recommendations
# * **Date:** 2024

# %%
import pandas as pd
import numpy as np
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# We will focus on a brief analysis of network and system logs via the JSON format
PATH_NETWORK = '/data/hypermnt/pwnjutsu/network/json/'
PATH_SYSTEM = '/data/hypermnt/pwnjutsu/system/json'

# %%
# List IDs players whose data are available
PLAYER_IDS = ["11", "12", "13", "15", "16", "18", "19", "21", "22", "23", "24", "26", "27", "28", "32", "33", "34", "35", "36", "37", "38", "39"]

# %%
# Read All JSON Files from player 11 as a sample
p11_data = pd.DataFrame()

for file in os.scandir(PATH_NETWORK):
    if f'player_{PLAYER_IDS[0]}_' in file.name:
        p11_data = pd.concat([p11_data, pd.read_json(file.path, lines=True)])

# %%
p11_data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 794175 entries, 0 to 1
# Data columns (total 133 columns):
#  #    Column                    Non-Null Count   Dtype
# ---   ------                    --------------   -----
#  0    ts                        794175 non-null  float64
#  1    uid                       715829 non-null  object
#  2    id.orig_h                 715829 non-null  object
#  3    id.orig_p                 715829 non-null  float64
#  4    id.resp_h                 715829 non-null  object
#  5    id.resp_p                 715829 non-null  float64
#  6    path                      12 non-null      object
#  7    service                   23373 non-null   object
#  8    share_type                12 non-null      object
#  9    fuid                      78346 non-null   object
#  10   tx_hosts                  78346 non-null   object
#  11   rx_hosts                  78346 non-null   object
#  12   conn_uids                 78346 non-null   object
#  13   source                    78594 non-null   object
#  14   depth                     78346 non-null   float64
#  15   analyzers                 78346 non-null   object
#  16   mime_type                 78336 non-null   object
#  17   duration                  673025 non-null  float64
#  18   is_orig                   78346 non-null   object
#  19   seen_bytes                78346 non-null   float64
#  20   total_bytes               60540 non-null   float64
#  21   missing_bytes             78346 non-null   float64
#  22   overflow_bytes            78346 non-null   float64
#  23   timedout                  78346 non-null   object
#  24   filename                  2 non-null       object
#  25   name                      302 non-null     object
#  26   addl                      276 non-null     object
#  27   notice                    302 non-null     object
#  28   peer                      302 non-null     object
#  29   proto                     635051 non-null  object
#  30   trans_id                  5688 non-null    float64
#  31   query                     5688 non-null    object
#  32   qclass                    5686 non-null    float64
#  33   qclass_name               5686 non-null    object
#  34   qtype                     5686 non-null    float64
#  35   qtype_name                5686 non-null    object
#  36   AA                        5688 non-null    object
#  37   TC                        5688 non-null    object
#  38   RD                        5688 non-null    object
#  39   RA                        5688 non-null    object
#  40   Z                         5688 non-null    float64
#  41   rejected                  5688 non-null    object
#  42   client_major_version      2 non-null       float64
#  43   client_minor_version      2 non-null       float64
#  44   server_major_version      2 non-null       float64
#  45   server_minor_version      2 non-null       float64
#  46   authentication_method     2 non-null       object
#  47   conn_state                629351 non-null  object
#  48   missed_bytes              629351 non-null  float64
#  49   history                   629237 non-null  object
#  50   orig_pkts                 629351 non-null  float64
#  51   orig_ip_bytes             629351 non-null  float64
#  52   resp_pkts                 629351 non-null  float64
#  53   resp_ip_bytes             629351 non-null  float64
#  54   orig_bytes                594679 non-null  float64
#  55   resp_bytes                594679 non-null  float64
#  56   version                   79672 non-null   object
#  57   cipher                    4 non-null       object
#  58   server_name               4 non-null       object
#  59   resumed                   4 non-null       object
#  60   established               4 non-null       object
#  61   ssl_history               4 non-null       object
#  62   cert_chain_fps            4 non-null       object
#  63   client_cert_chain_fps     4 non-null       object
#  64   sni_matches_cert          4 non-null       object
#  65   trans_depth               79788 non-null   float64
#  66   method                    79784 non-null   object
#  67   host                      79622 non-null   object
#  68   uri                       79784 non-null   object
#  69   user_agent                79594 non-null   object
#  70   request_body_len          79788 non-null   float64
#  71   response_body_len         79788 non-null   float64
#  72   status_code               79566 non-null   float64
#  73   status_msg                79566 non-null   object
#  74   tags                      79788 non-null   object
#  75   resp_fuids                78250 non-null   object
#  76   resp_mime_types           78240 non-null   object
#  77   proxied                   14 non-null      object
#  78   origin                    212 non-null     object
#  79   referrer                  19222 non-null   object
#  80   username                  80 non-null      object
#  81   orig_fuids                96 non-null      object
#  82   orig_filenames            2 non-null       object
#  83   orig_mime_types           96 non-null      object
#  84   rtt                       4 non-null       float64
#  85   named_pipe                4 non-null       object
#  86   endpoint                  4 non-null       object
#  87   operation                 4 non-null       object
#  88   analyzer                  12 non-null      object
#  89   failure_reason            12 non-null      object
#  90   command                   500 non-null     object
#  91   value                     500 non-null     object
#  92   user                      4 non-null       object
#  93   nick                      246 non-null     object
#  94   request_type              22 non-null      object
#  95   client                    118 non-null     object
#  96   till                      22 non-null      float64
#  97   forwardable               22 non-null      object
#  98   renewable                 22 non-null      object
#  99   auth_attempts             108 non-null     float64
#  100  server                    108 non-null     object
#  101  cipher_alg                84 non-null      object
#  102  mac_alg                   84 non-null      object
#  103  compression_alg           84 non-null      object
#  104  kex_alg                   84 non-null      object
#  105  host_key_alg              84 non-null      object
#  106  host_key                  64 non-null      object
#  107  auth_success              56 non-null      float64
#  108  rcode                     6 non-null       float64
#  109  rcode_name                6 non-null       object
#  110  hostname                  14 non-null      object
#  111  domainname                14 non-null      object
#  112  server_nb_computer_name   14 non-null      object
#  113  server_dns_computer_name  14 non-null      object
#  114  success                   12 non-null      float64
#  115  answers                   2 non-null       object
#  116  TTLs                      2 non-null       object
#  117  mode                      18 non-null      float64
#  118  stratum                   18 non-null      float64
#  119  poll                      18 non-null      float64
#  120  precision                 18 non-null      float64
#  121  root_delay                18 non-null      float64
#  122  root_disp                 18 non-null      float64
#  123  ref_id                    18 non-null      object
#  124  ref_time                  18 non-null      float64
#  125  org_time                  18 non-null      float64
#  126  rec_time                  18 non-null      float64
#  127  xmt_time                  18 non-null      float64
#  128  num_exts                  18 non-null      float64
#  129  cookie                    4 non-null       object
#  130  result                    4 non-null       object
#  131  security_protocol         4 non-null       object
#  132  cert_count                4 non-null       float64
# dtypes: float64(46), object(87)
# memory usage: 811.9+ MB

# %%
p11_data.head()
# Out:
#              ts                 uid  id.orig_h  id.orig_p  id.resp_h  \
# 0  1.620591e+09  C0xi3k36oBXMXiTvBl  10.11.1.1    43138.0  10.11.1.2
# 1  1.620591e+09  C24VwD1f6cVtEmtgm3  10.11.1.1    43139.0  10.11.1.2
# 2  1.620591e+09  ClYNHo1nIh4Dk3udcg  10.11.1.1    43140.0  10.11.1.2
# 3  1.620635e+09   CSbVAPIX3qaZqxt82  10.11.1.1    43185.0  10.11.1.2
# 4  1.620635e+09   CWqKuxigpxkF2sbci  10.11.1.1    43186.0  10.11.1.2
#
#    id.resp_p              path service share_type fuid tx_hosts rx_hosts  \
# 0      445.0              IPC$     IPC       PIPE  NaN      NaN      NaN
# 1      445.0              IPC$     IPC       PIPE  NaN      NaN      NaN
# 2      445.0              IPC$     IPC       PIPE  NaN      NaN      NaN
# 3      445.0  \\10.11.1.2\IPC$     NaN       PIPE  NaN      NaN      NaN
# 4      445.0  \\10.11.1.2\IPC$     NaN       PIPE  NaN      NaN      NaN
#
#   conn_uids source  depth analyzers mime_type  duration is_orig  seen_bytes  \
# 0       NaN    NaN    NaN       NaN       NaN       NaN     NaN         NaN
# 1       NaN    NaN    NaN       NaN       NaN       NaN     NaN         NaN
# 2       NaN    NaN    NaN       NaN       NaN       NaN     NaN         NaN
# 3       NaN    NaN    NaN       NaN       NaN       NaN     NaN         NaN
# 4       NaN    NaN    NaN       NaN       NaN       NaN     NaN         NaN
#
#    total_bytes  missing_bytes  overflow_bytes timedout filename name addl  \
# 0          NaN            NaN             NaN      NaN      NaN  NaN  NaN
# 1          NaN            NaN             NaN      NaN      NaN  NaN  NaN
# 2          NaN            NaN             NaN      NaN      NaN  NaN  NaN
# 3          NaN            NaN             NaN      NaN      NaN  NaN  NaN
# 4          NaN            NaN             NaN      NaN      NaN  NaN  NaN
#
#   notice peer proto  trans_id query  qclass qclass_name  qtype qtype_name  \
# 0    NaN  NaN   NaN       NaN   NaN     NaN         NaN    NaN        NaN
# 1    NaN  NaN   NaN       NaN   NaN     NaN         NaN    NaN        NaN
# 2    NaN  NaN   NaN       NaN   NaN     NaN         NaN    NaN        NaN
# 3    NaN  NaN   NaN       NaN   NaN     NaN         NaN    NaN        NaN
# 4    NaN  NaN   NaN       NaN   NaN     NaN         NaN    NaN        NaN
#
#     AA   TC   RD   RA   Z rejected  client_major_version  \
# 0  NaN  NaN  NaN  NaN NaN      NaN                   NaN
# 1  NaN  NaN  NaN  NaN NaN      NaN                   NaN
# 2  NaN  NaN  NaN  NaN NaN      NaN                   NaN
# 3  NaN  NaN  NaN  NaN NaN      NaN                   NaN
# 4  NaN  NaN  NaN  NaN NaN      NaN                   NaN
#
#    client_minor_version  server_major_version  server_minor_version  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   authentication_method conn_state  missed_bytes history  orig_pkts  \
# 0                   NaN        NaN           NaN     NaN        NaN
# 1                   NaN        NaN           NaN     NaN        NaN
# 2                   NaN        NaN           NaN     NaN        NaN
# 3                   NaN        NaN           NaN     NaN        NaN
# 4                   NaN        NaN           NaN     NaN        NaN
#
#    orig_ip_bytes  resp_pkts  resp_ip_bytes  orig_bytes  resp_bytes version  \
# 0            NaN        NaN            NaN         NaN         NaN     NaN
# 1            NaN        NaN            NaN         NaN         NaN     NaN
# 2            NaN        NaN            NaN         NaN         NaN     NaN
# 3            NaN        NaN            NaN         NaN         NaN     NaN
# 4            NaN        NaN            NaN         NaN         NaN     NaN
#
#   cipher server_name resumed established ssl_history cert_chain_fps  \
# 0    NaN         NaN     NaN         NaN         NaN            NaN
# 1    NaN         NaN     NaN         NaN         NaN            NaN
# 2    NaN         NaN     NaN         NaN         NaN            NaN
# 3    NaN         NaN     NaN         NaN         NaN            NaN
# 4    NaN         NaN     NaN         NaN         NaN            NaN
#
#   client_cert_chain_fps sni_matches_cert  trans_depth method host  uri  \
# 0                   NaN              NaN          NaN    NaN  NaN  NaN
# 1                   NaN              NaN          NaN    NaN  NaN  NaN
# 2                   NaN              NaN          NaN    NaN  NaN  NaN
# 3                   NaN              NaN          NaN    NaN  NaN  NaN
# 4                   NaN              NaN          NaN    NaN  NaN  NaN
#
#   user_agent  request_body_len  response_body_len  status_code status_msg  \
# 0        NaN               NaN                NaN          NaN        NaN
# 1        NaN               NaN                NaN          NaN        NaN
# 2        NaN               NaN                NaN          NaN        NaN
# 3        NaN               NaN                NaN          NaN        NaN
# 4        NaN               NaN                NaN          NaN        NaN
#
#   tags resp_fuids resp_mime_types proxied origin referrer username orig_fuids  \
# 0  NaN        NaN             NaN     NaN    NaN      NaN      NaN        NaN
# 1  NaN        NaN             NaN     NaN    NaN      NaN      NaN        NaN
# 2  NaN        NaN             NaN     NaN    NaN      NaN      NaN        NaN
# 3  NaN        NaN             NaN     NaN    NaN      NaN      NaN        NaN
# 4  NaN        NaN             NaN     NaN    NaN      NaN      NaN        NaN
#
#   orig_filenames orig_mime_types  rtt named_pipe endpoint operation analyzer  \
# 0            NaN             NaN  NaN        NaN      NaN       NaN      NaN
# 1            NaN             NaN  NaN        NaN      NaN       NaN      NaN
# 2            NaN             NaN  NaN        NaN      NaN       NaN      NaN
# 3            NaN             NaN  NaN        NaN      NaN       NaN      NaN
# 4            NaN             NaN  NaN        NaN      NaN       NaN      NaN
#
#   failure_reason command value user nick request_type client  till  \
# 0            NaN     NaN   NaN  NaN  NaN          NaN    NaN   NaN
# 1            NaN     NaN   NaN  NaN  NaN          NaN    NaN   NaN
# 2            NaN     NaN   NaN  NaN  NaN          NaN    NaN   NaN
# 3            NaN     NaN   NaN  NaN  NaN          NaN    NaN   NaN
# 4            NaN     NaN   NaN  NaN  NaN          NaN    NaN   NaN
#
#   forwardable renewable  auth_attempts server cipher_alg mac_alg  \
# 0         NaN       NaN            NaN    NaN        NaN     NaN
# 1         NaN       NaN            NaN    NaN        NaN     NaN
# 2         NaN       NaN            NaN    NaN        NaN     NaN
# 3         NaN       NaN            NaN    NaN        NaN     NaN
# 4         NaN       NaN            NaN    NaN        NaN     NaN
#
#   compression_alg kex_alg host_key_alg host_key  auth_success  rcode  \
# 0             NaN     NaN          NaN      NaN           NaN    NaN
# 1             NaN     NaN          NaN      NaN           NaN    NaN
# 2             NaN     NaN          NaN      NaN           NaN    NaN
# 3             NaN     NaN          NaN      NaN           NaN    NaN
# 4             NaN     NaN          NaN      NaN           NaN    NaN
#
#   rcode_name hostname domainname server_nb_computer_name  \
# 0        NaN      NaN        NaN                     NaN
# 1        NaN      NaN        NaN                     NaN
# 2        NaN      NaN        NaN                     NaN
# 3        NaN      NaN        NaN                     NaN
# 4        NaN      NaN        NaN                     NaN
#
#   server_dns_computer_name  success answers TTLs  mode  stratum  poll  \
# 0                      NaN      NaN     NaN  NaN   NaN      NaN   NaN
# 1                      NaN      NaN     NaN  NaN   NaN      NaN   NaN
# 2                      NaN      NaN     NaN  NaN   NaN      NaN   NaN
# 3                      NaN      NaN     NaN  NaN   NaN      NaN   NaN
# 4                      NaN      NaN     NaN  NaN   NaN      NaN   NaN
#
#    precision  root_delay  root_disp ref_id  ref_time  org_time  rec_time  \
# 0        NaN         NaN        NaN    NaN       NaN       NaN       NaN
# 1        NaN         NaN        NaN    NaN       NaN       NaN       NaN
# 2        NaN         NaN        NaN    NaN       NaN       NaN       NaN
# 3        NaN         NaN        NaN    NaN       NaN       NaN       NaN
# 4        NaN         NaN        NaN    NaN       NaN       NaN       NaN
#
#    xmt_time  num_exts cookie result security_protocol  cert_count
# 0       NaN       NaN    NaN    NaN               NaN         NaN
# 1       NaN       NaN    NaN    NaN               NaN         NaN
# 2       NaN       NaN    NaN    NaN               NaN         NaN
# 3       NaN       NaN    NaN    NaN               NaN         NaN
# 4       NaN       NaN    NaN    NaN               NaN         NaN

# %%
# !cat $PATH_NETWORK/* | wc -l
# Out:
# 45120244

# %%
# Apparently, we cannot load all data at once due to memory restrictions, let's do it by players
data = {}   # dictionary of player_id : pd.DataFrame

for player in PLAYER_IDS:
    print(f"Processing #{player}")

    net_data = pd.DataFrame()

    for file in os.scandir(PATH_NETWORK):
        if f'player_{player}_' in file.name:
            net_data = pd.concat([net_data, pd.read_json(file.path, lines=True)])

    data[player] = net_data
# Out:
# Processing #11
# Processing #12
# Processing #13
# Processing #15
# Processing #16
# Processing #18
# Processing #19
# Processing #21
# Processing #22
# Processing #23
# Processing #24
# Processing #26
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Apparently, in order to determine the final number of features and non NaNs, we have to code our own algo
# Remove player 26 from features analysis because it is too big to fit into the memory
cols_nonans_tot = {}   # dictionary of col_name : non_nan_count

for player in [player for player in PLAYER_IDS if player != '26']:
    print(f"Processing #{player}")

    net_data = pd.DataFrame()

    for file in os.scandir(PATH_NETWORK):
        if f'player_{player}_' in file.name:
            net_data = pd.concat([net_data, pd.read_json(file.path, lines=True)])

    cols_nonans_cur = net_data.count().to_dict()

    cols_nonans_tot = {k : cols_nonans_tot.get(k, 0) + cols_nonans_cur.get(k, 0)
                       for k in set(cols_nonans_tot) | set(cols_nonans_cur)}
# Out:
# Processing #11
# Processing #12
# Processing #13
# Processing #15
# Processing #16
# Processing #18
# Processing #19
# Processing #21
# Processing #22
# Processing #23
# Processing #24
# Processing #27
# Processing #28
# Processing #32
# Processing #33
# Processing #34
# Processing #35
# Processing #36
# Processing #37
# Processing #38
# Processing #39

# %%
nonans_total = pd.Series(cols_nonans_tot).sort_index()
nonans_total
# Out:
# AA                            446187
# RA                            446187
# RD                            446187
# TC                            446187
# TTLs                              68
# Z                             446187
# action                           124
# addl                             908
# analyzer                         632
# analyzers                    4022394
# answers                           68
# arg                               92
# auth                              90
# auth_attempts                   4260
# auth_success                    2068
# authentication_method            330
# call_id                           24
# cert_chain_fps                   110
# cert_count                       104
# cipher                           110
# cipher_alg                      3528
# client                          4092
# client_cert_chain_fps            110
# client_major_version             616
# client_minor_version             616
# cmd                               92
# command                          856
# compression_alg                 3528
# conn_state                  11312242
# conn_uids                    4022394
# cookie                            84
# depth                        4022394
# desktop_name                      30
# domainname                       262
# duration                    12773718
# endpoint                         554
# established                      126
# failure_reason                   632
# filename                         180
# forwardable                      210
# fuid                         4022394
# get_bulk_requests                 24
# get_requests                      24
# get_responses                     24
# height                            30
# history                     11301974
# host                         5446892
# host_key                        3150
# host_key_alg                    3528
# hostname                         322
# id.orig_h                   17225628
# id.orig_p                   17225628
# id.resp_h                   17225628
# id.resp_p                   17225628
# info_code                         34
# info_msg                          34
# is_orig                      4022394
# kex_alg                         3528
# mac_alg                         3528
# method                       5449104
# mime_type                    4009672
# missed_bytes                11312242
# missing_bytes                4022394
# mode                              74
# name                            7253
# named_pipe                       554
# native_file_system                16
# nick                             398
# notice                          7137
# num_exts                          74
# operation                        554
# org_time                          62
# orig_bytes                   8751300
# orig_filenames                   170
# orig_fuids                     29814
# orig_ip_bytes               11312242
# orig_mime_types                25758
# orig_pkts                   11312242
# origin                          4710
# overflow_bytes               4022394
# path                             304
# peer                            7137
# poll                              62
# precision                         62
# proto                       11759061
# proxied                         2678
# qclass                        446113
# qclass_name                   446113
# qtype                         446113
# qtype_name                    446113
# query                         446163
# rcode                            104
# rcode_name                       104
# rec_time                          62
# ref_id                            62
# ref_time                          62
# referrer                       66748
# rejected                      446187
# renewable                        210
# request_body_len             5451755
# request_from                      24
# request_path                      24
# request_to                        24
# request_type                     210
# resp_bytes                   8751300
# resp_fuids                   3992050
# resp_ip_bytes               11312242
# resp_mime_types              3983578
# resp_pkts                   11312242
# response_body_len            5451731
# response_path                     24
# result                           142
# resumed                          126
# root_delay                        62
# root_disp                         62
# rtt                              564
# rx_hosts                     4022394
# security_protocol                104
# seen_bytes                   4022394
# seq                               24
# server                          4256
# server_dns_computer_name         334
# server_major_version             616
# server_minor_version             616
# server_name                       32
# server_nb_computer_name          334
# service                       785650
# set_requests                      24
# share_flag                        66
# share_type                       274
# size                             116
# sni_matches_cert                  32
# source                       4028400
# ssl_history                      126
# status_code                  5448626
# status_msg                   5448626
# stratum                           62
# success                          318
# tags                         5451731
# till                             210
# timedout                     4022394
# times.accessed                    30
# times.changed                     30
# times.created                     30
# times.modified                    30
# total_bytes                  3927192
# trans_depth                  5451755
# trans_id                      446187
# ts                          21248033
# tunnel_type                        8
# tx_hosts                     4022394
# uid                         17225612
# uri                          5449104
# user                              30
# user_agent                   5342748
# username                       11720
# value                            856
# version                      5452382
# width                             30
# xmt_time                          62
# dtype: int64

# %%
len(nonans_total.index)
# Out:
# 160

# %% [markdown]
# So 160 total features, but very sparse...

# %%
# According to analysis, each red team player is comprised of 4 PCAP files (probably captured at different sensors)
# So, we selected 1 file from each actor to analyze their duration. Only 1 was needed, as all 4 had approximately
# the same durations for all the actors
SELECTED_PCAPS = '/data/hypermnt/pwnjutsu/network/pcap_dur_selection'

# !capinfos -a -e $SELECTED_PCAPS/*
# Out:
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_11_503317411.pcap
# First packet time:   2021-05-09 11:56:12.148505
# Last packet time:    2021-05-10 14:18:34.367668
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_12_536871850.pcap
# First packet time:   2021-05-09 12:30:19.322607
# Last packet time:    2021-05-10 21:29:12.672149
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_13_570426287.pcap
# First packet time:   2021-05-09 13:24:33.129385
# Last packet time:    2021-05-10 19:14:28.760362
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_15_637535169.pcap
# First packet time:   2021-05-10 07:09:08.484604
# Last packet time:    2021-05-12 16:17:43.398603
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_16_671089606.pcap
# First packet time:   2021-05-10 21:58:40.004643
# Last packet time:    2021-05-13 21:28:54.039336
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_18_738198480.pcap
# First packet time:   2021-05-11 19:08:58.554439
# Last packet time:    2021-05-12 22:30:28.150997
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_19_771752917.pcap
# First packet time:   2021-05-12 09:18:47.722249
# Last packet time:    2021-05-13 15:35:33.763175
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_21_838861791.pcap
# First packet time:   2021-05-12 23:38:15.789917
# Last packet time:    2021-05-16 00:16:24.715482
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_22_872416228.pcap
# First packet time:   2021-05-13 00:08:46.027014
# Last packet time:    2021-05-17 19:34:57.792868
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_23_905970677.pcap
# First packet time:   2021-05-14 21:25:34.211583
# Last packet time:    2021-05-17 19:41:02.529967
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_24_939525110.pcap
# First packet time:   2021-05-14 21:51:46.158055
# Last packet time:    2021-05-28 22:25:56.220088
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_26_1040188425.pcap
# First packet time:   2021-05-15 18:45:10.925311
# Last packet time:    2021-05-25 23:00:41.164075
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_27_1006633996.pcap
# First packet time:   2021-05-17 21:59:45.197873
# Last packet time:    2021-05-22 17:01:26.577217
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_28_1073742865.pcap
# First packet time:   2021-05-19 14:14:10.493032
# Last packet time:    2021-05-20 22:44:36.185051
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_32_1241515056.pcap
# First packet time:   2021-05-26 18:03:21.440673
# Last packet time:    2021-05-29 15:29:23.584192
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_33_1275069493.pcap
# First packet time:   2021-05-26 22:57:58.106556
# Last packet time:    2021-06-04 17:13:44.137166
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_34_1308623928.pcap
# First packet time:   2021-05-28 08:28:13.207351
# Last packet time:    2021-06-06 10:19:42.361820
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_35_1342178369.pcap
# First packet time:   2021-05-31 00:04:57.679396
# Last packet time:    2021-06-09 14:03:10.000976
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_36_1375732806.pcap
# First packet time:   2021-06-02 16:47:41.962689
# Last packet time:    2021-06-09 14:30:55.144759
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_37_1409287248.pcap
# First packet time:   2021-06-02 18:14:43.011042
# Last packet time:    2021-06-09 09:25:21.651736
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_38_1442841683.pcap
# First packet time:   2021-06-05 09:41:22.042158
# Last packet time:    2021-06-12 23:57:50.598646
#
# File name:           /data/hypermnt/pwnjutsu/network/pcap_dur_selection/player_39_1476396120.pcap
# First packet time:   2021-06-08 10:35:24.717519
# Last packet time:    2021-06-20 19:39:16.298602

# %%
# Compute the total time of the cptures
# !/data/AAAA_SCRIPTS/countdur.sh $SELECTED_PCAPS
# Out:
# 10058133.778334

# %%
# Print the selected value as days and hours
import math

TOTAL_SECS  = 10058133.778334
TOTAL_DAYS  = TOTAL_SECS / 60 / 60 / 24
TOTAL_HOURS = (TOTAL_DAYS % math.floor(TOTAL_DAYS)) * 24

display(TOTAL_DAYS)
display(TOTAL_HOURS)
# Out:
# 116.41358539738424
# 9.92604953722173
