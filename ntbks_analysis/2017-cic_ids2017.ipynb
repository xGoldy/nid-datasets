# %% [markdown]
# # CIC-IDS2017 Dataset Analysis
#
# * **Author:** Patrik Goldschmidt (igoldschmidt@fit.vut.cz)
# * **Project:** Network Intrusion Datasets: A Survey, Limitations, and Recommendations
# * **Date:** 2024

# %%
import pandas as pd
import numpy as np
import os

pd.set_option('display.max_columns', None)

# %%
FOLDER_CSV = '/data/surv/cic-ids2017/csvs_labeled_flows'
FOLDER_PCAPS = '/data/surv/cic-ids2017/pcaps'

# %% [markdown]
# ## CSVs Analysis

# %%
labeled_flows_fullpaths = [os.path.join(FOLDER_CSV, file) for file in os.listdir(FOLDER_CSV) if file.endswith('.csv')]
labeled_flows_fullpaths
# Out:
# ['/data/surv/cic-ids2017/csvs_labeled_flows/.Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv.swp',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Friday-WorkingHours-Morning.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Tuesday-WorkingHours.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Monday-WorkingHours.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Wednesday-workingHours.pcap_ISCX.csv',
#  '/data/surv/cic-ids2017/csvs_labeled_flows/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv']

# %%
# Load all the files
data = pd.DataFrame()

for flowfile in labeled_flows_fullpaths:
    print(flowfile)
    data = pd.concat([data, pd.read_csv(flowfile, encoding ='latin1')])

# %%
data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3119345 entries, 0 to 286466
# Data columns (total 85 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   Flow ID                       2830743 non-null  object
#  1    Source IP                    2830743 non-null  object
#  2    Source Port                  2830743 non-null  float64
#  3    Destination IP               2830743 non-null  object
#  4    Destination Port             2830743 non-null  float64
#  5    Protocol                     2830743 non-null  float64
#  6    Timestamp                    2830743 non-null  object
#  7    Flow Duration                2830743 non-null  float64
#  8    Total Fwd Packets            2830743 non-null  float64
#  9    Total Backward Packets       2830743 non-null  float64
#  10  Total Length of Fwd Packets   2830743 non-null  float64
#  11   Total Length of Bwd Packets  2830743 non-null  float64
#  12   Fwd Packet Length Max        2830743 non-null  float64
#  13   Fwd Packet Length Min        2830743 non-null  float64
#  14   Fwd Packet Length Mean       2830743 non-null  float64
#  15   Fwd Packet Length Std        2830743 non-null  float64
#  16  Bwd Packet Length Max         2830743 non-null  float64
#  17   Bwd Packet Length Min        2830743 non-null  float64
#  18   Bwd Packet Length Mean       2830743 non-null  float64
#  19   Bwd Packet Length Std        2830743 non-null  float64
#  20  Flow Bytes/s                  2829385 non-null  float64
#  21   Flow Packets/s               2830743 non-null  float64
#  22   Flow IAT Mean                2830743 non-null  float64
#  23   Flow IAT Std                 2830743 non-null  float64
#  24   Flow IAT Max                 2830743 non-null  float64
#  25   Flow IAT Min                 2830743 non-null  float64
#  26  Fwd IAT Total                 2830743 non-null  float64
#  27   Fwd IAT Mean                 2830743 non-null  float64
#  28   Fwd IAT Std                  2830743 non-null  float64
#  29   Fwd IAT Max                  2830743 non-null  float64
#  30   Fwd IAT Min                  2830743 non-null  float64
#  31  Bwd IAT Total                 2830743 non-null  float64
#  32   Bwd IAT Mean                 2830743 non-null  float64
#  33   Bwd IAT Std                  2830743 non-null  float64
#  34   Bwd IAT Max                  2830743 non-null  float64
#  35   Bwd IAT Min                  2830743 non-null  float64
#  36  Fwd PSH Flags                 2830743 non-null  float64
#  37   Bwd PSH Flags                2830743 non-null  float64
#  38   Fwd URG Flags                2830743 non-null  float64
#  39   Bwd URG Flags                2830743 non-null  float64
#  40   Fwd Header Length            2830743 non-null  float64
#  41   Bwd Header Length            2830743 non-null  float64
#  42  Fwd Packets/s                 2830743 non-null  float64
#  43   Bwd Packets/s                2830743 non-null  float64
#  44   Min Packet Length            2830743 non-null  float64
#  45   Max Packet Length            2830743 non-null  float64
#  46   Packet Length Mean           2830743 non-null  float64
#  47   Packet Length Std            2830743 non-null  float64
#  48   Packet Length Variance       2830743 non-null  float64
#  49  FIN Flag Count                2830743 non-null  float64
#  50   SYN Flag Count               2830743 non-null  float64
#  51   RST Flag Count               2830743 non-null  float64
#  52   PSH Flag Count               2830743 non-null  float64
#  53   ACK Flag Count               2830743 non-null  float64
#  54   URG Flag Count               2830743 non-null  float64
#  55   CWE Flag Count               2830743 non-null  float64
#  56   ECE Flag Count               2830743 non-null  float64
#  57   Down/Up Ratio                2830743 non-null  float64
#  58   Average Packet Size          2830743 non-null  float64
#  59   Avg Fwd Segment Size         2830743 non-null  float64
#  60   Avg Bwd Segment Size         2830743 non-null  float64
#  61   Fwd Header Length.1          2830743 non-null  float64
#  62  Fwd Avg Bytes/Bulk            2830743 non-null  float64
#  63   Fwd Avg Packets/Bulk         2830743 non-null  float64
#  64   Fwd Avg Bulk Rate            2830743 non-null  float64
#  65   Bwd Avg Bytes/Bulk           2830743 non-null  float64
#  66   Bwd Avg Packets/Bulk         2830743 non-null  float64
#  67  Bwd Avg Bulk Rate             2830743 non-null  float64
#  68  Subflow Fwd Packets           2830743 non-null  float64
#  69   Subflow Fwd Bytes            2830743 non-null  float64
#  70   Subflow Bwd Packets          2830743 non-null  float64
#  71   Subflow Bwd Bytes            2830743 non-null  float64
#  72  Init_Win_bytes_forward        2830743 non-null  float64
#  73   Init_Win_bytes_backward      2830743 non-null  float64
#  74   act_data_pkt_fwd             2830743 non-null  float64
#  75   min_seg_size_forward         2830743 non-null  float64
#  76  Active Mean                   2830743 non-null  float64
#  77   Active Std                   2830743 non-null  float64
#  78   Active Max                   2830743 non-null  float64
#  79   Active Min                   2830743 non-null  float64
#  80  Idle Mean                     2830743 non-null  float64
#  81   Idle Std                     2830743 non-null  float64
#  82   Idle Max                     2830743 non-null  float64
#  83   Idle Min                     2830743 non-null  float64
#  84   Label                        2830743 non-null  object
# dtypes: float64(80), object(5)
# memory usage: 2.0+ GB

# %%
len(data)
# Out:
# 3119345

# %%
data[' Label'].value_counts()
# Out:
#  Label
# BENIGN                        2273097
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack  Brute Force         1507
# Web Attack  XSS                  652
# Infiltration                       36
# Web Attack  Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %% [markdown]
# There is a space in a feature name, there are unprintable characters as the labels... Data misses IP addresses and the source port... Says a lot about the quality of the data.

# %%
data.describe()
# Out:
# /home/goldy/env/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/goldy/env/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#         Source Port   Destination Port      Protocol   Flow Duration  \
# count  2.830743e+06       2.830743e+06  2.830743e+06    2.830743e+06
# mean   4.112886e+04       8.071483e+03  9.880341e+00    1.478566e+07
# std    2.229494e+04       1.828363e+04  5.261922e+00    3.365374e+07
# min    0.000000e+00       0.000000e+00  0.000000e+00   -1.300000e+01
# 25%    3.277400e+04       5.300000e+01  6.000000e+00    1.550000e+02
# 50%    5.094400e+04       8.000000e+01  6.000000e+00    3.131600e+04
# 75%    5.841300e+04       4.430000e+02  1.700000e+01    3.204828e+06
# max    6.553500e+04       6.553500e+04  1.700000e+01    1.200000e+08
#
#         Total Fwd Packets   Total Backward Packets  \
# count        2.830743e+06             2.830743e+06
# mean         9.361160e+00             1.039377e+01
# std          7.496728e+02             9.973883e+02
# min          1.000000e+00             0.000000e+00
# 25%          2.000000e+00             1.000000e+00
# 50%          2.000000e+00             2.000000e+00
# 75%          5.000000e+00             4.000000e+00
# max          2.197590e+05             2.919220e+05
#
#        Total Length of Fwd Packets   Total Length of Bwd Packets  \
# count                 2.830743e+06                  2.830743e+06
# mean                  5.493024e+02                  1.616264e+04
# std                   9.993589e+03                  2.263088e+06
# min                   0.000000e+00                  0.000000e+00
# 25%                   1.200000e+01                  0.000000e+00
# 50%                   6.200000e+01                  1.230000e+02
# 75%                   1.870000e+02                  4.820000e+02
# max                   1.290000e+07                  6.554530e+08
#
#         Fwd Packet Length Max   Fwd Packet Length Min  \
# count            2.830743e+06            2.830743e+06
# mean             2.075999e+02            1.871366e+01
# std              7.171848e+02            6.033935e+01
# min              0.000000e+00            0.000000e+00
# 25%              6.000000e+00            0.000000e+00
# 50%              3.700000e+01            2.000000e+00
# 75%              8.100000e+01            3.600000e+01
# max              2.482000e+04            2.325000e+03
#
#         Fwd Packet Length Mean   Fwd Packet Length Std  Bwd Packet Length Max  \
# count             2.830743e+06            2.830743e+06           2.830743e+06
# mean              5.820194e+01            6.891013e+01           8.708495e+02
# std               1.860912e+02            2.811871e+02           1.946367e+03
# min               0.000000e+00            0.000000e+00           0.000000e+00
# 25%               6.000000e+00            0.000000e+00           0.000000e+00
# 50%               3.400000e+01            0.000000e+00           7.900000e+01
# 75%               5.000000e+01            2.616295e+01           2.800000e+02
# max               5.940857e+03            7.125597e+03           1.953000e+04
#
#         Bwd Packet Length Min   Bwd Packet Length Mean  \
# count            2.830743e+06             2.830743e+06
# mean             4.104958e+01             3.059493e+02
# std              6.886260e+01             6.052568e+02
# min              0.000000e+00             0.000000e+00
# 25%              0.000000e+00             0.000000e+00
# 50%              0.000000e+00             7.200000e+01
# 75%              7.700000e+01             1.810000e+02
# max              2.896000e+03             5.800500e+03
#
#         Bwd Packet Length Std  Flow Bytes/s   Flow Packets/s   Flow IAT Mean  \
# count            2.830743e+06  2.829385e+06     2.830743e+06    2.830743e+06
# mean             3.353257e+02           inf              inf    1.298449e+06
# std              8.396932e+02           NaN              NaN    4.507944e+06
# min              0.000000e+00 -2.610000e+08    -2.000000e+06   -1.300000e+01
# 25%              0.000000e+00  1.193197e+02     3.446226e+00    6.366667e+01
# 50%              0.000000e+00  4.595549e+03     1.106684e+02    1.143884e+04
# 75%              7.794054e+01  1.666667e+05     2.325581e+04    3.374266e+05
# max              8.194660e+03           inf              inf    1.200000e+08
#
#         Flow IAT Std   Flow IAT Max   Flow IAT Min  Fwd IAT Total  \
# count   2.830743e+06   2.830743e+06   2.830743e+06   2.830743e+06
# mean    2.919271e+06   9.182475e+06   1.623796e+05   1.448296e+07
# std     8.045870e+06   2.445954e+07   2.950282e+06   3.357581e+07
# min     0.000000e+00  -1.300000e+01  -1.400000e+01   0.000000e+00
# 25%     0.000000e+00   1.230000e+02   3.000000e+00   0.000000e+00
# 50%     1.371787e+02   3.086500e+04   4.000000e+00   4.300000e+01
# 75%     6.912663e+05   2.440145e+06   6.400000e+01   1.242844e+06
# max     8.480026e+07   1.200000e+08   1.200000e+08   1.200000e+08
#
#         Fwd IAT Mean   Fwd IAT Std   Fwd IAT Max   Fwd IAT Min  Bwd IAT Total  \
# count   2.830743e+06  2.830743e+06  2.830743e+06  2.830743e+06   2.830743e+06
# mean    2.610193e+06  3.266957e+06  9.042939e+06  1.021893e+06   9.893830e+06
# std     9.525722e+06  9.639055e+06  2.452916e+07  8.591436e+06   2.873661e+07
# min     0.000000e+00  0.000000e+00  0.000000e+00 -1.200000e+01   0.000000e+00
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%     2.600000e+01  0.000000e+00  4.300000e+01  3.000000e+00   3.000000e+00
# 75%     2.063064e+05  6.598982e+04  9.310060e+05  4.800000e+01   9.858050e+04
# max     1.200000e+08  8.460293e+07  1.200000e+08  1.200000e+08   1.200000e+08
#
#         Bwd IAT Mean   Bwd IAT Std   Bwd IAT Max   Bwd IAT Min  Fwd PSH Flags  \
# count   2.830743e+06  2.830743e+06  2.830743e+06  2.830743e+06   2.830743e+06
# mean    1.805784e+06  1.485973e+06  4.684692e+06  9.672614e+05   4.644646e-02
# std     8.887197e+06  6.278469e+06  1.716095e+07  8.308983e+06   2.104500e-01
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%     3.000000e+00  0.000000e+00  3.000000e+00  1.000000e+00   0.000000e+00
# 75%     1.824857e+04  1.572409e+04  6.021000e+04  4.500000e+01   0.000000e+00
# max     1.200000e+08  8.441801e+07  1.200000e+08  1.200000e+08   1.000000e+00
#
#         Bwd PSH Flags   Fwd URG Flags   Bwd URG Flags   Fwd Header Length  \
# count       2830743.0    2.830743e+06       2830743.0        2.830743e+06
# mean              0.0    1.112782e-04             0.0       -2.599739e+04
# std               0.0    1.054826e-02             0.0        2.105286e+07
# min               0.0    0.000000e+00             0.0       -3.221223e+10
# 25%               0.0    0.000000e+00             0.0        4.000000e+01
# 50%               0.0    0.000000e+00             0.0        6.400000e+01
# 75%               0.0    0.000000e+00             0.0        1.200000e+02
# max               0.0    1.000000e+00             0.0        4.644908e+06
#
#         Bwd Header Length  Fwd Packets/s   Bwd Packets/s   Min Packet Length  \
# count        2.830743e+06   2.830743e+06    2.830743e+06        2.830743e+06
# mean        -2.273275e+03   6.386535e+04    6.995192e+03        1.643450e+01
# std          1.452209e+06   2.475371e+05    3.815170e+04        2.523772e+01
# min         -1.073741e+09   0.000000e+00    0.000000e+00        0.000000e+00
# 25%          2.000000e+01   1.749446e+00    1.229197e-01        0.000000e+00
# 50%          4.000000e+01   6.132524e+01    1.982789e+01        2.000000e+00
# 75%          1.040000e+02   1.204819e+04    7.352941e+03        3.600000e+01
# max          5.838440e+06   3.000000e+06    2.000000e+06        1.448000e+03
#
#         Max Packet Length   Packet Length Mean   Packet Length Std  \
# count        2.830743e+06         2.830743e+06        2.830743e+06
# mean         9.504024e+02         1.719444e+02        2.949756e+02
# std          2.028229e+03         3.054915e+02        6.318001e+02
# min          0.000000e+00         0.000000e+00        0.000000e+00
# 25%          6.000000e+00         6.000000e+00        0.000000e+00
# 50%          8.700000e+01         5.720000e+01        2.598076e+01
# 75%          5.250000e+02         1.198000e+02        1.743239e+02
# max          2.482000e+04         3.337143e+03        4.731522e+03
#
#         Packet Length Variance  FIN Flag Count   SYN Flag Count  \
# count             2.830743e+06    2.830743e+06     2.830743e+06
# mean              4.861548e+05    3.537976e-02     4.644646e-02
# std               1.647490e+06    1.847378e-01     2.104500e-01
# min               0.000000e+00    0.000000e+00     0.000000e+00
# 25%               0.000000e+00    0.000000e+00     0.000000e+00
# 50%               6.750000e+02    0.000000e+00     0.000000e+00
# 75%               3.038884e+04    0.000000e+00     0.000000e+00
# max               2.240000e+07    1.000000e+00     1.000000e+00
#
#         RST Flag Count   PSH Flag Count   ACK Flag Count   URG Flag Count  \
# count     2.830743e+06     2.830743e+06     2.830743e+06     2.830743e+06
# mean      2.423392e-04     2.980705e-01     3.158443e-01     9.482316e-02
# std       1.556536e-02     4.574107e-01     4.648513e-01     2.929706e-01
# min       0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%       0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 50%       0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 75%       0.000000e+00     1.000000e+00     1.000000e+00     0.000000e+00
# max       1.000000e+00     1.000000e+00     1.000000e+00     1.000000e+00
#
#         CWE Flag Count   ECE Flag Count   Down/Up Ratio   Average Packet Size  \
# count     2.830743e+06     2.830743e+06    2.830743e+06          2.830743e+06
# mean      1.112782e-04     2.433990e-04    6.835004e-01          1.919837e+02
# std       1.054826e-02     1.559935e-02    6.804920e-01          3.318603e+02
# min       0.000000e+00     0.000000e+00    0.000000e+00          0.000000e+00
# 25%       0.000000e+00     0.000000e+00    0.000000e+00          7.500000e+00
# 50%       0.000000e+00     0.000000e+00    1.000000e+00          7.225000e+01
# 75%       0.000000e+00     0.000000e+00    1.000000e+00          1.492639e+02
# max       1.000000e+00     1.000000e+00    1.560000e+02          3.893333e+03
#
#         Avg Fwd Segment Size   Avg Bwd Segment Size   Fwd Header Length.1  \
# count           2.830743e+06           2.830743e+06          2.830743e+06
# mean            5.820194e+01           3.059493e+02         -2.599739e+04
# std             1.860912e+02           6.052568e+02          2.105286e+07
# min             0.000000e+00           0.000000e+00         -3.221223e+10
# 25%             6.000000e+00           0.000000e+00          4.000000e+01
# 50%             3.400000e+01           7.200000e+01          6.400000e+01
# 75%             5.000000e+01           1.810000e+02          1.200000e+02
# max             5.940857e+03           5.800500e+03          4.644908e+06
#
#        Fwd Avg Bytes/Bulk   Fwd Avg Packets/Bulk   Fwd Avg Bulk Rate  \
# count           2830743.0              2830743.0           2830743.0
# mean                  0.0                    0.0                 0.0
# std                   0.0                    0.0                 0.0
# min                   0.0                    0.0                 0.0
# 25%                   0.0                    0.0                 0.0
# 50%                   0.0                    0.0                 0.0
# 75%                   0.0                    0.0                 0.0
# max                   0.0                    0.0                 0.0
#
#         Bwd Avg Bytes/Bulk   Bwd Avg Packets/Bulk  Bwd Avg Bulk Rate  \
# count            2830743.0              2830743.0          2830743.0
# mean                   0.0                    0.0                0.0
# std                    0.0                    0.0                0.0
# min                    0.0                    0.0                0.0
# 25%                    0.0                    0.0                0.0
# 50%                    0.0                    0.0                0.0
# 75%                    0.0                    0.0                0.0
# max                    0.0                    0.0                0.0
#
#        Subflow Fwd Packets   Subflow Fwd Bytes   Subflow Bwd Packets  \
# count         2.830743e+06        2.830743e+06          2.830743e+06
# mean          9.361160e+00        5.492919e+02          1.039377e+01
# std           7.496728e+02        9.980070e+03          9.973883e+02
# min           1.000000e+00        0.000000e+00          0.000000e+00
# 25%           2.000000e+00        1.200000e+01          1.000000e+00
# 50%           2.000000e+00        6.200000e+01          2.000000e+00
# 75%           5.000000e+00        1.870000e+02          4.000000e+00
# max           2.197590e+05        1.287034e+07          2.919220e+05
#
#         Subflow Bwd Bytes  Init_Win_bytes_forward   Init_Win_bytes_backward  \
# count        2.830743e+06            2.830743e+06              2.830743e+06
# mean         1.616230e+04            6.989837e+03              1.989433e+03
# std          2.263057e+06            1.433873e+04              8.456883e+03
# min          0.000000e+00           -1.000000e+00             -1.000000e+00
# 25%          0.000000e+00           -1.000000e+00             -1.000000e+00
# 50%          1.230000e+02            2.510000e+02             -1.000000e+00
# 75%          4.820000e+02            8.192000e+03              2.350000e+02
# max          6.554530e+08            6.553500e+04              6.553500e+04
#
#         act_data_pkt_fwd   min_seg_size_forward   Active Mean    Active Std  \
# count       2.830743e+06           2.830743e+06  2.830743e+06  2.830743e+06
# mean        5.418218e+00          -2.741688e+03  8.155132e+04  4.113412e+04
# std         6.364257e+02           1.084989e+06  6.485999e+05  3.933815e+05
# min         0.000000e+00          -5.368707e+08  0.000000e+00  0.000000e+00
# 25%         0.000000e+00           2.000000e+01  0.000000e+00  0.000000e+00
# 50%         1.000000e+00           2.400000e+01  0.000000e+00  0.000000e+00
# 75%         2.000000e+00           3.200000e+01  0.000000e+00  0.000000e+00
# max         2.135570e+05           1.380000e+02  1.100000e+08  7.420000e+07
#
#          Active Max    Active Min     Idle Mean      Idle Std      Idle Max  \
# count  2.830743e+06  2.830743e+06  2.830743e+06  2.830743e+06  2.830743e+06
# mean   1.531825e+05  5.829582e+04  8.316037e+06  5.038439e+05  8.695752e+06
# std    1.025825e+06  5.770923e+05  2.363008e+07  4.602984e+06  2.436689e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.100000e+08  1.100000e+08  1.200000e+08  7.690000e+07  1.200000e+08
#
#            Idle Min
# count  2.830743e+06
# mean   7.920031e+06
# std    2.336342e+07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.200000e+08

# %% [markdown]
# ## PCAP Analysis

# %%
pcap_fullpahts = [os.path.join(FOLDER_PCAPS, file) for file in os.listdir(FOLDER_PCAPS)]
pcap_fullpahts
# Out:
# ['/data/surv/cic-ids2017/pcaps/Wednesday-workingHours.pcap',
#  '/data/surv/cic-ids2017/pcaps/Monday-WorkingHours.pcap',
#  '/data/surv/cic-ids2017/pcaps/Thursday-WorkingHours.pcap',
#  '/data/surv/cic-ids2017/pcaps/Tuesday-WorkingHours.pcap',
#  '/data/surv/cic-ids2017/pcaps/Friday-WorkingHours.pcap']

# %%
# Get general capinfos data for each file
for pcap_filepath in pcap_fullpahts:
    # !capinfos $pcap_filepath
    # !echo ""
# Out:
# File name:           /data/surv/cic-ids2017/pcaps/Wednesday-workingHours.pcap
# File type:           Wireshark/... - pcapng
# File encapsulation:  Ethernet
# File timestamp precision:  microseconds (6)
# Packet size limit:   file hdr: (not set)
# Number of packets:   13 M
# File size:           13 GB
# Data size:           12 GB
# Capture duration:    30457.696353 seconds
# First packet time:   2017-07-05 13:42:42.084372
# Last packet time:    2017-07-05 22:10:19.780725
# Data byte rate:      425 kBps
# Data bit rate:       3,404 kbps
# Average packet size: 939.95 bytes
# Average packet rate: 452 packets/s
# SHA256:              cd2674db7559a53f24bc03be3239b315700174ccaef72d10f5edc4c1a08f6186
# RIPEMD160:           aff58953d580dfc856f9fafa3d62993310e93dce
# SHA1:                bc36902fc69f4f79e8d6ae1f2ff8751ea93d495b
# Strict time order:   False
# Capture oper-sys:    Linux 4.8.0-22-generic
# Capture application: mergecap
# Number of interfaces in file: 1
# Interface #0 info:
#                      Encapsulation = Ethernet (1 - ether)
#                      Capture length = 262144
#                      Time precision = microseconds (6)
#                      Time ticks per second = 1000000
#                      Number of stat entries = 0
#                      Number of packets = 13788878
# File name:           /data/surv/cic-ids2017/pcaps/Monday-WorkingHours.pcap
# File type:           Wireshark/... - pcapng
# File encapsulation:  Ethernet
# File timestamp precision:  microseconds (6)
# Packet size limit:   file hdr: (not set)
# Number of packets:   11 M
# File size:           10 GB
# Data size:           10 GB
# Capture duration:    29135.874581 seconds
# First packet time:   2017-07-03 13:55:58.598308
# Last packet time:    2017-07-03 22:01:34.472889
# Data byte rate:      358 kBps
# Data bit rate:       2,864 kbps
# Average packet size: 890.96 bytes
# Average packet rate: 401 packets/s
# SHA256:              f6eac599358f216b074338813a1cf7be3cc4e91d116e13efc0dc71f2cca11972
# RIPEMD160:           591c6c97bb0e3fc508b3d3fa557f9b5bab91466d
# SHA1:                6d944cdbb01b3b1838272db123e6cfe3ed5f6dcb
# Strict time order:   False
# Capture oper-sys:    Linux 4.8.0-22-generic
# Capture application: mergecap
# Number of interfaces in file: 1
# Interface #0 info:
#                      Encapsulation = Ethernet (1 - ether)
#                      Capture length = 262144
#                      Time precision = microseconds (6)
#                      Time ticks per second = 1000000
#                      Number of stat entries = 0
#                      Number of packets = 11709971
# File name:           /data/surv/cic-ids2017/pcaps/Thursday-WorkingHours.pcap
# File type:           Wireshark/... - pcapng
# File encapsulation:  Ethernet
# File timestamp precision:  microseconds (6)
# Packet size limit:   file hdr: (not set)
# Number of packets:   9,322 k
# File size:           8,302 MB
# Data size:           7,992 MB
# Capture duration:    29145.871747 seconds
# First packet time:   2017-07-06 13:58:58.492265
# Last packet time:    2017-07-06 22:04:44.364012
# Data byte rate:      274 kBps
# Data bit rate:       2,193 kbps
# Average packet size: 857.39 bytes
# Average packet rate: 319 packets/s
# SHA256:              38f8b1bb276849bf1721f7c4de22bebfa7f59a74e52286d4c0a37edbb118fe01
# RIPEMD160:           e34ba9cf32ee15838585564d881ff1415fb8beb6
# SHA1:                21450a49b206d60107d16e0918f26e4b74afadad
# Strict time order:   False
# Capture oper-sys:    Linux 4.8.0-22-generic
# Capture application: mergecap
# Number of interfaces in file: 1
# Interface #0 info:
#                      Encapsulation = Ethernet (1 - ether)
#                      Capture length = 262144
#                      Time precision = microseconds (6)
#                      Time ticks per second = 1000000
#                      Number of stat entries = 0
#                      Number of packets = 9322025
# File name:           /data/surv/cic-ids2017/pcaps/Tuesday-WorkingHours.pcap
# File type:           Wireshark/... - pcapng
# File encapsulation:  Ethernet
# File timestamp precision:  microseconds (6)
# Packet size limit:   file hdr: (not set)
# Number of packets:   11 M
# File size:           11 GB
# Data size:           10 GB
# Capture duration:    29218.712676 seconds
# First packet time:   2017-07-04 13:53:32.364079
# Last packet time:    2017-07-04 22:00:31.076755
# Data byte rate:      364 kBps
# Data bit rate:       2,919 kbps
# Average packet size: 923.12 bytes
# Average packet rate: 395 packets/s
# SHA256:              080c2250154c5a174c03660ed0f75a3858d41a27511ba716e780d7bcb1ec4c57
# RIPEMD160:           779e4de066e7376c714a7a63141a59ce27436fb7
# SHA1:                8dfbb2b87df7bf0bd0e09f09cfcad368775bcd70
# Strict time order:   False
# Capture oper-sys:    Linux 4.8.0-22-generic
# Capture application: mergecap
# Number of interfaces in file: 1
# Interface #0 info:
#                      Encapsulation = Ethernet (1 - ether)
#                      Capture length = 262144
#                      Time precision = microseconds (6)
#                      Time ticks per second = 1000000
#                      Number of stat entries = 0
#                      Number of packets = 11551954
# File name:           /data/surv/cic-ids2017/pcaps/Friday-WorkingHours.pcap
# File type:           Wireshark/... - pcapng
# File encapsulation:  Ethernet
# File timestamp precision:  microseconds (6)
# Packet size limit:   file hdr: (not set)
# Number of packets:   9,997 k
# File size:           8,839 MB
# Data size:           8,507 MB
# Capture duration:    28981.569980 seconds
# First packet time:   2017-07-07 13:59:39.599128
# Last packet time:    2017-07-07 22:02:41.169108
# Data byte rate:      293 kBps
# Data bit rate:       2,348 kbps
# Average packet size: 850.92 bytes
# Average packet rate: 344 packets/s
# SHA256:              beff0dcce1eebc9b2454582f4dc8ed0ba0112b2c619a710bf03af93147254cd0
# RIPEMD160:           06441b5c2af6ac21d96a83c2e329781c590961a6
# SHA1:                8b2f8cb9dd618a40f614aef197317af0d611439f
# Strict time order:   False
# Capture oper-sys:    Linux 4.8.0-22-generic
# Capture application: mergecap
# Number of interfaces in file: 1
# Interface #0 info:
#                      Encapsulation = Ethernet (1 - ether)
#                      Capture length = 262144
#                      Time precision = microseconds (6)
#                      Time ticks per second = 1000000
#                      Number of stat entries = 0
#                      Number of packets = 9997874

# %%
# Count the toal number of packets
# !/data/AAAA_SCRIPTS/countpkts.sh $FOLDER_PCAPS
# Out:
# Processing /data/surv/cic-ids2017/pcaps/Friday-WorkingHours.pcap
# Processing /data/surv/cic-ids2017/pcaps/Monday-WorkingHours.pcap
# Processing /data/surv/cic-ids2017/pcaps/Thursday-WorkingHours.pcap
# Processing /data/surv/cic-ids2017/pcaps/Tuesday-WorkingHours.pcap
# Processing /data/surv/cic-ids2017/pcaps/Wednesday-workingHours.pcap
#
# TOTAL FILES : 5
# TOTAL PACKETS: 56370702

# %% [markdown]
# Original CIC-IDS2017 dataset contains no timestamp information, so data continuity had to be verified via PCAP analysis.
