# %% [markdown]
# # AIT-LDSv2.0 Dataset Analysis
#
# * **Author:** Patrik Goldschmidt (igoldschmidt@fit.vut.cz)
# * **Project:** Network Intrusion Datasets: A Survey, Limitations, and Recommendations
# * **Date:** 2024
#
# We downloaded classical log dataset (https://zenodo.org/records/5789064) and merged it with NetFlow data (https://zenodo.org/records/13168643), placing flows of the specific scenarios under the `flow` directory.

# %%
import pandas as pd
import numpy as np
import os

pd.set_option('display.max_columns', None)

# %%
DATA_ROOT = '/data/surv/ait/scenarios/'

# %%
# !ls $DATA_ROOT
# Out:
# fox  harrison  russellmitchell	santos	shaw  wardbeck	wheeler  wilson

# %%
# Let's look at the first scenario to have an idea about its structure
SCENARIO_FOX = os.path.join(DATA_ROOT, 'fox')

# !ls $SCENARIO_FOX
# Out:
# dataset.yaml  environment  flow  fox.zip  gather  labels  processing  rules

# %%
# Logs are supposed to be under 'gather' directory
# whereas labeling in the 'label' directory
# !ls $SCENARIO_FOX/labels
# !echo ""
# !ls $SCENARIO_FOX/labels/inet-firewall
# !echo ""
# !ls $SCENARIO_FOX/labels/inet-firewall/logs
# Out:
# inet-firewall  internal_share  intranet_server	monitoring  vpn
#
# logs
#
# dnsmasq.log

# %%
# How does a typical labeling look like?
# !cat $SCENARIO_FOX/labels/inet-firewall/logs/dnsmasq.log | head -n 10
# Out:
# {"line": 1, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 2, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 3, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 4, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 5, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 6, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 7, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 8, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 9, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# {"line": 10, "labels": ["dnsteal", "attacker", "dnsteal-received"], "rules": {"dnsteal": ["dnsteal.domain.match"], "attacker": ["dnsteal.domain.match"], "dnsteal-received": ["dnsteal.domain.received"]}}
# cat: write error: Broken pipe

# %%
# How does a log look like?
# !ls $SCENARIO_FOX/gather
# !echo ""
# !ls $SCENARIO_FOX/gather/inet-firewall
# !echo ""
# !ls $SCENARIO_FOX/gather/inet-firewall/logs
# !echo ""
# !ls $SCENARIO_FOX/gather/inet-firewall/logs/dnsmasq.log
# Out:
# attacker_0   ext_user_6		  internal_share     remote_employee_2
# cloud_share  inet-dns		  intranet_server    remote_employee_3
# ext_user_0   inet-firewall	  jonesmorgan_mail   taylorcruz_mail
# ext_user_1   internal_employee_0  mail		     vpn
# ext_user_2   internal_employee_1  miller_mail	     webserver
# ext_user_3   internal_employee_2  monitoring	     whittaker_mail
# ext_user_4   internal_employee_3  remote_employee_0
# ext_user_5   internal_employee_4  remote_employee_1
#
# configs  facts.json  logs
#
# audit	    dnsmasq.log  kern.log.1	       suricata  syslog.3
# auth.log    journal	 shorewall-init.log    syslog.1  syslog.4
# auth.log.1  kern.log	 shorewall-init.log.1  syslog.2  syslog.5
#
# /data/surv/ait/scenarios/fox/gather/inet-firewall/logs/dnsmasq.log

# %%
# !cat $SCENARIO_FOX/gather/inet-firewall/logs/dnsmasq.log | head -n 10
# Out:
# Jan 15 00:00:03 dnsmasq[14522]: query[A] 3x6-.546-.2PoxC1PkS*qtk0p2kKZGSYsWe2X*u678tHnPA6vJb6cp7itF6Qlb7/ZNOUZ*-.tO4afCcp4TpC6S0KJF27aqpRaGLcHzZCkPnUWPug2PpcImBWfcLFKlm5p5r3-.Ewvg4xYu8FqM2a/lO4V8qfcNr2i1bRY/u8wZM19IvDh7deB7cBxUezv5CAKT-.customers_2018.xlsx.ycgjslfptkev.com from 10.35.33.111
# Jan 15 00:00:03 dnsmasq[14522]: forwarded 3x6-.546-.2PoxC1PkS*qtk0p2kKZGSYsWe2X*u678tHnPA6vJb6cp7itF6Qlb7/ZNOUZ*-.tO4afCcp4TpC6S0KJF27aqpRaGLcHzZCkPnUWPug2PpcImBWfcLFKlm5p5r3-.Ewvg4xYu8FqM2a/lO4V8qfcNr2i1bRY/u8wZM19IvDh7deB7cBxUezv5CAKT-.customers_2018.xlsx.ycgjslfptkev.com to 192.168.255.254
# Jan 15 00:00:03 dnsmasq[14522]: reply 3x6-.546-.2PoxC1PkS*qtk0p2kKZGSYsWe2X*u678tHnPA6vJb6cp7itF6Qlb7/ZNOUZ*-.tO4afCcp4TpC6S0KJF27aqpRaGLcHzZCkPnUWPug2PpcImBWfcLFKlm5p5r3-.Ewvg4xYu8FqM2a/lO4V8qfcNr2i1bRY/u8wZM19IvDh7deB7cBxUezv5CAKT-.customers_2018.xlsx.ycgjslfptkev.com is 195.128.194.168
# Jan 15 00:00:20 dnsmasq[14522]: query[A] 3x6-.547-.WharXpRiFOnbAvznOFBIiR4EDr2FH97sAZEw0PT77TTzCvi*vLTdNSfYJ*mB-.Mro0pNd/COkTkZFQTEVKuNZC5LIIlfsj*GoWta1/KRxUKbPNKrTmgKeKzYyL-.7d8d5cAaEvTfDy0U68UesMs7uYYesKt6eeusCf44XNbaB1URD9Df/KlCm7AV-.customers_2018.xlsx.ycgjslfptkev.com from 10.35.33.111
# Jan 15 00:00:20 dnsmasq[14522]: forwarded 3x6-.547-.WharXpRiFOnbAvznOFBIiR4EDr2FH97sAZEw0PT77TTzCvi*vLTdNSfYJ*mB-.Mro0pNd/COkTkZFQTEVKuNZC5LIIlfsj*GoWta1/KRxUKbPNKrTmgKeKzYyL-.7d8d5cAaEvTfDy0U68UesMs7uYYesKt6eeusCf44XNbaB1URD9Df/KlCm7AV-.customers_2018.xlsx.ycgjslfptkev.com to 192.168.255.254
# Jan 15 00:00:20 dnsmasq[14522]: reply 3x6-.547-.WharXpRiFOnbAvznOFBIiR4EDr2FH97sAZEw0PT77TTzCvi*vLTdNSfYJ*mB-.Mro0pNd/COkTkZFQTEVKuNZC5LIIlfsj*GoWta1/KRxUKbPNKrTmgKeKzYyL-.7d8d5cAaEvTfDy0U68UesMs7uYYesKt6eeusCf44XNbaB1URD9Df/KlCm7AV-.customers_2018.xlsx.ycgjslfptkev.com is 195.128.194.168
# Jan 15 00:00:34 dnsmasq[14522]: query[A] 3x6-.548-.rcP*T8uK0I1Pfr391gWOsJxONbNLmu/KCjdHMmIjEWHiloIrq2OOVh6w2GFA-.qCnbimx6SW5iMg0wwGsSxTr1GCc*LxSJX*OIr3UKX6dbK7xBmdX5t5M3M*jM-.ecYh8vki7szxsGwsHrYnGyS9Zt2jWanc63Sy7RXwlchlDBdmgokWkkq73FNw-.customers_2018.xlsx.ycgjslfptkev.com from 10.35.33.111
# Jan 15 00:00:34 dnsmasq[14522]: forwarded 3x6-.548-.rcP*T8uK0I1Pfr391gWOsJxONbNLmu/KCjdHMmIjEWHiloIrq2OOVh6w2GFA-.qCnbimx6SW5iMg0wwGsSxTr1GCc*LxSJX*OIr3UKX6dbK7xBmdX5t5M3M*jM-.ecYh8vki7szxsGwsHrYnGyS9Zt2jWanc63Sy7RXwlchlDBdmgokWkkq73FNw-.customers_2018.xlsx.ycgjslfptkev.com to 192.168.255.254
# Jan 15 00:00:34 dnsmasq[14522]: reply 3x6-.548-.rcP*T8uK0I1Pfr391gWOsJxONbNLmu/KCjdHMmIjEWHiloIrq2OOVh6w2GFA-.qCnbimx6SW5iMg0wwGsSxTr1GCc*LxSJX*OIr3UKX6dbK7xBmdX5t5M3M*jM-.ecYh8vki7szxsGwsHrYnGyS9Zt2jWanc63Sy7RXwlchlDBdmgokWkkq73FNw-.customers_2018.xlsx.ycgjslfptkev.com is 195.128.194.168
# Jan 15 00:00:53 dnsmasq[14522]: query[A] 3x6-.549-.OIHTNDp3gt8G53ORPNtSCWKk90JXYfTNGMvp0gqDu69d/lZLpa17Rdd5jC5s-.xgmWE1jDNDH84hWZna0bVxOot1dczDITgOVrxQZcdghuHBeExN7ElGgoELKb-.O2AnNftrb*e05sfOaJI52CXREVJSL0OVQCOlqkNA5mErHLMTTgJ5zkZlWS5*-.customers_2018.xlsx.ycgjslfptkev.com from 10.35.33.111
# cat: write error: Broken pipe

# %%
# !ls $SCENARIO_FOX/gather/inet-firewall/logs/suricata
# Out:
# certs	  files		       log.pcap.1642405636  suricata.log
# core	  log.pcap.1642159247  log.pcap.1642508536  suricata-start.log
# eve.json  log.pcap.1642162264  log.pcap.1642592664
# fast.log  log.pcap.1642238378  stats.log

# %%
# !cat $SCENARIO_FOX/gather/inet-firewall/logs/suricata/stats.log | head -n 20
# Out:
# ------------------------------------------------------------------------------------
# Date: 1/14/2022 -- 11:20:54 (uptime: 0d, 00h 00m 40s)
# ------------------------------------------------------------------------------------
# Counter                                       | TM Name                   | Value
# ------------------------------------------------------------------------------------
# capture.kernel_packets                        | Total                     | 2
# decoder.pkts                                  | Total                     | 2
# decoder.bytes                                 | Total                     | 596
# decoder.ipv4                                  | Total                     | 2
# decoder.ethernet                              | Total                     | 2
# decoder.udp                                   | Total                     | 2
# decoder.avg_pkt_size                          | Total                     | 298
# decoder.max_pkt_size                          | Total                     | 306
# flow.udp                                      | Total                     | 1
# flow.wrk.spare_sync_avg                       | Total                     | 100
# flow.wrk.spare_sync                           | Total                     | 1
# app_layer.flow.dns_udp                        | Total                     | 1
# app_layer.tx.dns_udp                          | Total                     | 2
# flow.mgr.full_hash_pass                       | Total                     | 1
# flow.spare                                    | Total                     | 9900
# cat: write error: Broken pipe

# %% [markdown]
# ### Log Counts counting

# %%
import glob

# Global counters
logs_lines_total = 0
pcaps_pkts_total = 0

# Count the amount of log files per scenario
scenarios_paths = []
for scenario in os.scandir(DATA_ROOT):
    if scenario.is_dir():
        scenarios_paths.append(scenario.path)

scenarios_paths.sort()

for scenario_path in scenarios_paths:
    scenario_logs_path = os.path.join(scenario_path, 'gather')
    logs_lines_sc = 0
    pcaps_pkts_sc = 0

    # Count the number of lines in logfiles
    for logfile in glob.iglob('*/logs/**/*log*', root_dir=scenario_logs_path, recursive=True):
        logfile_fullpath = os.path.join(scenario_logs_path, logfile)

        if not os.path.isdir(logfile_fullpath):
            current_log_lines = !cat $logfile_fullpath | wc -l
            logs_lines_sc += int(current_log_lines[0])

    # Count the number of packets in PCAPs
    for pcapfile in glob.iglob('*/logs/**/*pcap*', root_dir=scenario_logs_path, recursive=True):
        pcapfile_fullpath = os.path.join(scenario_logs_path, pcapfile)

        if not os.path.isdir(pcapfile_fullpath):
            #current_pcapfile_pkts = !tshark -r $pcapfile_fullpath 2>/dev/null | wc -l
            current_pcapfile_pkts = !capinfos -M -c "$pcapfile_fullpath" 2> /dev/null | tail -n 1 | cut -f 6 -d ' '
            pcaps_pkts_sc += int(current_pcapfile_pkts[0]) if len(current_pcapfile_pkts) == 1 else 0

    # Update the counters and print the scenario info
    logs_lines_total += logs_lines_sc
    pcaps_pkts_total += pcaps_pkts_sc

    print(scenario_path)
    print(logs_lines_sc, pcaps_pkts_sc)
    print()

logs_lines_total, pcaps_pkts_total
# Out:
# /data/surv/ait/scenarios/fox
# 114900689 27139809
#
# /data/surv/ait/scenarios/harrison
# 130883155 31307113
#
# /data/surv/ait/scenarios/russellmitchell
# 64946994 15501022
#
# /data/surv/ait/scenarios/santos
# 85476285 16349076
#
# /data/surv/ait/scenarios/shaw
# 137837285 27109300
#
# /data/surv/ait/scenarios/wardbeck
# 137717718 27047677
#
# /data/surv/ait/scenarios/wheeler
# 150133056 34622374
#
# /data/surv/ait/scenarios/wilson
# 203805076 45098276
# (1025700258, 224174647)

# %% [markdown]
# ### Timespan Analysis

# %%
# Official declaration of start and ends of individual scenarios
INFO_FILES = !find $DATA_ROOT -name 'dataset.yaml'

for file in sorted(INFO_FILES):
    # !cat $file
    # !echo ''
# Out:
# name: processed_fox_scenario
# start: '2022-01-15T00:00:00'
# end: '2022-01-20T00:00:00'
#
# name: processed_harrison_scenario
# start: '2022-02-04T00:00:00'
# end: '2022-02-09T00:00:00'
#
# name: processed_russellmitchell_scenario
# start: '2022-01-21T00:00:00'
# end: '2022-01-25T00:00:00'
#
# name: processed_santos_scenario
# start: '2022-01-14T00:00:00'
# end: '2022-01-18T00:00:00'
#
# name: processed_shaw_scenario
# start: '2022-01-25T00:00:00'
# end: '2022-01-31T00:00:00'
#
# name: processed_wardbeck_scenario
# start: '2022-01-19T00:00:00'
# end: '2022-01-24T00:00:00'
#
# name: processed_wheeler_scenario
# start: '2022-01-26T00:00:00'
# end: '2022-01-31T00:00:00'
#
# name: processed_wilson_scenario
# start: '2022-02-03T00:00:00'
# end: '2022-02-09T00:00:00'

# %% [markdown]
# ## NetFlow Data Analysis
#
# Since all scenarios are very common with different parameters, take a closer look on just one -- be it the biggest one -- `wilson`.

# %%
import glob

NETFLOW_WILSON_FOLDER_PATH = '/data/surv/ait/scenarios/wilson/flow'
NETFLOW_WILSON_FILES = glob.glob('*.csv', root_dir=NETFLOW_WILSON_FOLDER_PATH)
NETFLOW_WILSON_FILES
# Out:
# ['udp_complete.csv', 'tcp_nocomplete.csv', 'tcp_complete.csv']

# %%
wilson_flow_data_all = pd.DataFrame()

for file in NETFLOW_WILSON_FILES:
    wilson_flow_part = pd.read_csv(os.path.join(NETFLOW_WILSON_FOLDER_PATH, file))
    wilson_flow_data_all = pd.concat([wilson_flow_data_all, wilson_flow_part])

# %%
wilson_flow_data_all.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 629553 entries, 0 to 417671
# Data columns (total 157 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    #c_ip:1                181012 non-null  object
#  1    c_port:2               629553 non-null  int64
#  2    c_first_abs:3          181012 non-null  float64
#  3    c_durat:4              181012 non-null  float64
#  4    c_bytes_all:5          181012 non-null  float64
#  5    c_pkts_all:6           181012 non-null  float64
#  6    c_isint:7              181012 non-null  float64
#  7    c_iscrypto:8           181012 non-null  float64
#  8    c_type:9               181012 non-null  float64
#  9    s_ip:10                181012 non-null  object
#  10   s_port:11              181012 non-null  float64
#  11   s_first_abs:12         181012 non-null  float64
#  12   s_durat:13             181012 non-null  float64
#  13   s_bytes_all:14         181012 non-null  float64
#  14   s_pkts_all:15          181012 non-null  float64
#  15   s_isint:16             181012 non-null  float64
#  16   s_iscrypto:17          181012 non-null  float64
#  17   s_type:18              181012 non-null  float64
#  18   fqdn:19                181012 non-null  object
#  19   timestamp              629553 non-null  object
#  20   rounded_timestamp      181012 non-null  object
#  21   role_cli               629553 non-null  object
#  22   ipv4_address_cli       629553 non-null  object
#  23   network_cli            629553 non-null  object
#  24   role_serv              629553 non-null  object
#  25   ipv4_address_serv      629553 non-null  object
#  26   network_serv           629553 non-null  object
#  27   label                  629553 non-null  object
#  28   #15#c_ip:1             448541 non-null  object
#  29   c_pkts_all:3           448541 non-null  float64
#  30   c_rst_cnt:4            448541 non-null  float64
#  31   c_ack_cnt:5            448541 non-null  float64
#  32   c_ack_cnt_p:6          448541 non-null  float64
#  33   c_bytes_uniq:7         448541 non-null  float64
#  34   c_pkts_data:8          448541 non-null  float64
#  35   c_bytes_all:9          448541 non-null  float64
#  36   c_pkts_retx:10         448541 non-null  float64
#  37   c_bytes_retx:11        448541 non-null  float64
#  38   c_pkts_ooo:12          448541 non-null  float64
#  39   c_syn_cnt:13           448541 non-null  float64
#  40   c_fin_cnt:14           448541 non-null  float64
#  41   s_ip:15                448541 non-null  object
#  42   s_port:16              448541 non-null  float64
#  43   s_pkts_all:17          448541 non-null  float64
#  44   s_rst_cnt:18           448541 non-null  float64
#  45   s_ack_cnt:19           448541 non-null  float64
#  46   s_ack_cnt_p:20         448541 non-null  float64
#  47   s_bytes_uniq:21        448541 non-null  float64
#  48   s_pkts_data:22         448541 non-null  float64
#  49   s_bytes_all:23         448541 non-null  float64
#  50   s_pkts_retx:24         448541 non-null  float64
#  51   s_bytes_retx:25        448541 non-null  float64
#  52   s_pkts_ooo:26          448541 non-null  float64
#  53   s_syn_cnt:27           448541 non-null  float64
#  54   s_fin_cnt:28           448541 non-null  float64
#  55   first:29               448541 non-null  float64
#  56   last:30                448541 non-null  float64
#  57   durat:31               448541 non-null  float64
#  58   c_first:32             448541 non-null  float64
#  59   s_first:33             448541 non-null  float64
#  60   c_last:34              448541 non-null  float64
#  61   s_last:35              448541 non-null  float64
#  62   c_first_ack:36         448541 non-null  float64
#  63   s_first_ack:37         448541 non-null  float64
#  64   c_isint:38             448541 non-null  float64
#  65   s_isint:39             448541 non-null  float64
#  66   c_iscrypto:40          448541 non-null  float64
#  67   s_iscrypto:41          448541 non-null  float64
#  68   con_t:42               448541 non-null  float64
#  69   p2p_t:43               448541 non-null  float64
#  70   http_t:44              448541 non-null  float64
#  71   c_rtt_avg:45           417672 non-null  float64
#  72   c_rtt_min:46           417672 non-null  float64
#  73   c_rtt_max:47           417672 non-null  float64
#  74   c_rtt_std:48           417672 non-null  float64
#  75   c_rtt_cnt:49           417672 non-null  float64
#  76   c_ttl_min:50           417672 non-null  float64
#  77   c_ttl_max:51           417672 non-null  float64
#  78   s_rtt_avg:52           417672 non-null  float64
#  79   s_rtt_min:53           417672 non-null  float64
#  80   s_rtt_max:54           417672 non-null  float64
#  81   s_rtt_std:55           417672 non-null  float64
#  82   s_rtt_cnt:56           417672 non-null  float64
#  83   s_ttl_min:57           417672 non-null  float64
#  84   s_ttl_max:58           417672 non-null  float64
#  85   p2p_st:59              417672 non-null  float64
#  86   ed2k_data:60           417672 non-null  float64
#  87   ed2k_sig:61            417672 non-null  float64
#  88   ed2k_c2s:62            417672 non-null  float64
#  89   ed2k_c2c:63            417672 non-null  float64
#  90   ed2k_chat:64           417672 non-null  float64
#  91   c_f1323_opt:65         417672 non-null  float64
#  92   c_tm_opt:66            417672 non-null  float64
#  93   c_win_scl:67           417672 non-null  float64
#  94   c_sack_opt:68          417672 non-null  float64
#  95   c_sack_cnt:69          417672 non-null  float64
#  96   c_mss:70               417672 non-null  float64
#  97   c_mss_max:71           417672 non-null  float64
#  98   c_mss_min:72           417672 non-null  float64
#  99   c_win_max:73           417672 non-null  float64
#  100  c_win_min:74           417672 non-null  float64
#  101  c_win_0:75             417672 non-null  float64
#  102  c_cwin_max:76          417672 non-null  float64
#  103  c_cwin_min:77          417672 non-null  float64
#  104  c_cwin_ini:78          417672 non-null  float64
#  105  c_pkts_rto:79          417672 non-null  float64
#  106  c_pkts_fs:80           417672 non-null  float64
#  107  c_pkts_reor:81         417672 non-null  float64
#  108  c_pkts_dup:82          417672 non-null  float64
#  109  c_pkts_unk:83          417672 non-null  float64
#  110  c_pkts_fc:84           417672 non-null  float64
#  111  c_pkts_unrto:85        417672 non-null  float64
#  112  c_pkts_unfs:86         417672 non-null  float64
#  113  c_syn_retx:87          417672 non-null  float64
#  114  s_f1323_opt:88         417672 non-null  float64
#  115  s_tm_opt:89            417672 non-null  float64
#  116  s_win_scl:90           417672 non-null  float64
#  117  s_sack_opt:91          417672 non-null  float64
#  118  s_sack_cnt:92          417672 non-null  float64
#  119  s_mss:93               417672 non-null  float64
#  120  s_mss_max:94           417672 non-null  float64
#  121  s_mss_min:95           417672 non-null  float64
#  122  s_win_max:96           417672 non-null  float64
#  123  s_win_min:97           417672 non-null  float64
#  124  s_win_0:98             417672 non-null  float64
#  125  s_cwin_max:99          417672 non-null  float64
#  126  s_cwin_min:100         417672 non-null  float64
#  127  s_cwin_ini:101         417672 non-null  float64
#  128  s_pkts_rto:102         417672 non-null  float64
#  129  s_pkts_fs:103          417672 non-null  float64
#  130  s_pkts_reor:104        417672 non-null  float64
#  131  s_pkts_dup:105         417672 non-null  float64
#  132  s_pkts_unk:106         417672 non-null  float64
#  133  s_pkts_fc:107          417672 non-null  float64
#  134  s_pkts_unrto:108       417672 non-null  float64
#  135  s_pkts_unfs:109        417672 non-null  float64
#  136  s_syn_retx:110         417672 non-null  float64
#  137  http_req_cnt:111       417672 non-null  float64
#  138  http_res_cnt:112       417672 non-null  float64
#  139  http_res:113           417672 non-null  object
#  140  c_pkts_push:114        417672 non-null  float64
#  141  s_pkts_push:115        417672 non-null  float64
#  142  c_tls_SNI:116          417672 non-null  object
#  143  s_tls_SCN:117          417672 non-null  object
#  144  c_npnalpn:118          417672 non-null  float64
#  145  s_npnalpn:119          417672 non-null  float64
#  146  c_tls_sesid:120        417672 non-null  float64
#  147  c_last_handshakeT:121  417672 non-null  float64
#  148  s_last_handshakeT:122  417672 non-null  float64
#  149  c_appdataT:123         417672 non-null  float64
#  150  s_appdataT:124         417672 non-null  float64
#  151  c_appdataB:125         417672 non-null  float64
#  152  s_appdataB:126         417672 non-null  float64
#  153  fqdn:127               417672 non-null  object
#  154  dns_rslv:128           417672 non-null  object
#  155  req_tm:129             417672 non-null  float64
#  156  res_tm:130             417672 non-null  float64
# dtypes: float64(137), int64(1), object(19)
# memory usage: 758.9+ MB

# %%
len(wilson_flow_data_all)
# Out:
# 629553

# %%
wilson_flow_data_all.head()
# Out:
#            #c_ip:1  c_port:2  c_first_abs:3  c_durat:4  c_bytes_all:5  \
# 0  192.168.239.254     12298   1.643846e+12        0.0          228.0
# 1  192.168.239.254     31326   1.643846e+12        0.0          228.0
# 2  192.168.239.254     22595   1.643846e+12        0.0          228.0
# 3  192.168.239.254     41224   1.643846e+12        0.0          228.0
# 4  192.168.239.254     58001   1.643846e+12        0.0          228.0
#
#    c_pkts_all:6  c_isint:7  c_iscrypto:8  c_type:9         s_ip:10  s_port:11  \
# 0           1.0        1.0           0.0      19.0  192.168.226.71       53.0
# 1           1.0        1.0           0.0      19.0  192.168.226.71       53.0
# 2           1.0        1.0           0.0      19.0  192.168.226.71       53.0
# 3           1.0        1.0           0.0      19.0  192.168.226.71       53.0
# 4           1.0        1.0           0.0      19.0  192.168.226.71       53.0
#
#    s_first_abs:12  s_durat:13  s_bytes_all:14  s_pkts_all:15  s_isint:16  \
# 0    1.643846e+12         0.0           247.0            1.0         1.0
# 1    1.643846e+12         0.0           247.0            1.0         1.0
# 2    1.643846e+12         0.0           247.0            1.0         1.0
# 3    1.643846e+12         0.0           247.0            1.0         1.0
# 4    1.643846e+12         0.0           247.0            1.0         1.0
#
#    s_iscrypto:17  s_type:18 fqdn:19                      timestamp  \
# 0            0.0       19.0       -  2022-02-03 00:00:04.193519104
# 1            0.0       19.0       -  2022-02-03 00:00:20.246249984
# 2            0.0       19.0       -  2022-02-03 00:00:35.347027200
# 3            0.0       19.0       -  2022-02-03 00:00:46.414992896
# 4            0.0       19.0       -  2022-02-03 00:01:02.463830016
#
#                rounded_timestamp  role_cli ipv4_address_cli network_cli  \
# 0  2022-02-03 00:00:04.000000000  inet-dns  192.168.239.254    internet
# 1  2022-02-03 00:00:20.000000000  inet-dns  192.168.239.254    internet
# 2  2022-02-03 00:00:35.000000000  inet-dns  192.168.239.254    internet
# 3  2022-02-03 00:00:46.000000000  inet-dns  192.168.239.254    internet
# 4  2022-02-03 00:01:02.000000000  inet-dns  192.168.239.254    internet
#
#     role_serv ipv4_address_serv network_serv              label #15#c_ip:1  \
# 0  attacker_0    192.168.226.71     internet  data exfiltration        NaN
# 1  attacker_0    192.168.226.71     internet  data exfiltration        NaN
# 2  attacker_0    192.168.226.71     internet  data exfiltration        NaN
# 3  attacker_0    192.168.226.71     internet  data exfiltration        NaN
# 4  attacker_0    192.168.226.71     internet  data exfiltration        NaN
#
#    c_pkts_all:3  c_rst_cnt:4  c_ack_cnt:5  c_ack_cnt_p:6  c_bytes_uniq:7  \
# 0           NaN          NaN          NaN            NaN             NaN
# 1           NaN          NaN          NaN            NaN             NaN
# 2           NaN          NaN          NaN            NaN             NaN
# 3           NaN          NaN          NaN            NaN             NaN
# 4           NaN          NaN          NaN            NaN             NaN
#
#    c_pkts_data:8  c_bytes_all:9  c_pkts_retx:10  c_bytes_retx:11  \
# 0            NaN            NaN             NaN              NaN
# 1            NaN            NaN             NaN              NaN
# 2            NaN            NaN             NaN              NaN
# 3            NaN            NaN             NaN              NaN
# 4            NaN            NaN             NaN              NaN
#
#    c_pkts_ooo:12  c_syn_cnt:13  c_fin_cnt:14 s_ip:15  s_port:16  \
# 0            NaN           NaN           NaN     NaN        NaN
# 1            NaN           NaN           NaN     NaN        NaN
# 2            NaN           NaN           NaN     NaN        NaN
# 3            NaN           NaN           NaN     NaN        NaN
# 4            NaN           NaN           NaN     NaN        NaN
#
#    s_pkts_all:17  s_rst_cnt:18  s_ack_cnt:19  s_ack_cnt_p:20  s_bytes_uniq:21  \
# 0            NaN           NaN           NaN             NaN              NaN
# 1            NaN           NaN           NaN             NaN              NaN
# 2            NaN           NaN           NaN             NaN              NaN
# 3            NaN           NaN           NaN             NaN              NaN
# 4            NaN           NaN           NaN             NaN              NaN
#
#    s_pkts_data:22  s_bytes_all:23  s_pkts_retx:24  s_bytes_retx:25  \
# 0             NaN             NaN             NaN              NaN
# 1             NaN             NaN             NaN              NaN
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    s_pkts_ooo:26  s_syn_cnt:27  s_fin_cnt:28  first:29  last:30  durat:31  \
# 0            NaN           NaN           NaN       NaN      NaN       NaN
# 1            NaN           NaN           NaN       NaN      NaN       NaN
# 2            NaN           NaN           NaN       NaN      NaN       NaN
# 3            NaN           NaN           NaN       NaN      NaN       NaN
# 4            NaN           NaN           NaN       NaN      NaN       NaN
#
#    c_first:32  s_first:33  c_last:34  s_last:35  c_first_ack:36  \
# 0         NaN         NaN        NaN        NaN             NaN
# 1         NaN         NaN        NaN        NaN             NaN
# 2         NaN         NaN        NaN        NaN             NaN
# 3         NaN         NaN        NaN        NaN             NaN
# 4         NaN         NaN        NaN        NaN             NaN
#
#    s_first_ack:37  c_isint:38  s_isint:39  c_iscrypto:40  s_iscrypto:41  \
# 0             NaN         NaN         NaN            NaN            NaN
# 1             NaN         NaN         NaN            NaN            NaN
# 2             NaN         NaN         NaN            NaN            NaN
# 3             NaN         NaN         NaN            NaN            NaN
# 4             NaN         NaN         NaN            NaN            NaN
#
#    con_t:42  p2p_t:43  http_t:44  c_rtt_avg:45  c_rtt_min:46  c_rtt_max:47  \
# 0       NaN       NaN        NaN           NaN           NaN           NaN
# 1       NaN       NaN        NaN           NaN           NaN           NaN
# 2       NaN       NaN        NaN           NaN           NaN           NaN
# 3       NaN       NaN        NaN           NaN           NaN           NaN
# 4       NaN       NaN        NaN           NaN           NaN           NaN
#
#    c_rtt_std:48  c_rtt_cnt:49  c_ttl_min:50  c_ttl_max:51  s_rtt_avg:52  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    s_rtt_min:53  s_rtt_max:54  s_rtt_std:55  s_rtt_cnt:56  s_ttl_min:57  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    s_ttl_max:58  p2p_st:59  ed2k_data:60  ed2k_sig:61  ed2k_c2s:62  \
# 0           NaN        NaN           NaN          NaN          NaN
# 1           NaN        NaN           NaN          NaN          NaN
# 2           NaN        NaN           NaN          NaN          NaN
# 3           NaN        NaN           NaN          NaN          NaN
# 4           NaN        NaN           NaN          NaN          NaN
#
#    ed2k_c2c:63  ed2k_chat:64  c_f1323_opt:65  c_tm_opt:66  c_win_scl:67  \
# 0          NaN           NaN             NaN          NaN           NaN
# 1          NaN           NaN             NaN          NaN           NaN
# 2          NaN           NaN             NaN          NaN           NaN
# 3          NaN           NaN             NaN          NaN           NaN
# 4          NaN           NaN             NaN          NaN           NaN
#
#    c_sack_opt:68  c_sack_cnt:69  c_mss:70  c_mss_max:71  c_mss_min:72  \
# 0            NaN            NaN       NaN           NaN           NaN
# 1            NaN            NaN       NaN           NaN           NaN
# 2            NaN            NaN       NaN           NaN           NaN
# 3            NaN            NaN       NaN           NaN           NaN
# 4            NaN            NaN       NaN           NaN           NaN
#
#    c_win_max:73  c_win_min:74  c_win_0:75  c_cwin_max:76  c_cwin_min:77  \
# 0           NaN           NaN         NaN            NaN            NaN
# 1           NaN           NaN         NaN            NaN            NaN
# 2           NaN           NaN         NaN            NaN            NaN
# 3           NaN           NaN         NaN            NaN            NaN
# 4           NaN           NaN         NaN            NaN            NaN
#
#    c_cwin_ini:78  c_pkts_rto:79  c_pkts_fs:80  c_pkts_reor:81  c_pkts_dup:82  \
# 0            NaN            NaN           NaN             NaN            NaN
# 1            NaN            NaN           NaN             NaN            NaN
# 2            NaN            NaN           NaN             NaN            NaN
# 3            NaN            NaN           NaN             NaN            NaN
# 4            NaN            NaN           NaN             NaN            NaN
#
#    c_pkts_unk:83  c_pkts_fc:84  c_pkts_unrto:85  c_pkts_unfs:86  \
# 0            NaN           NaN              NaN             NaN
# 1            NaN           NaN              NaN             NaN
# 2            NaN           NaN              NaN             NaN
# 3            NaN           NaN              NaN             NaN
# 4            NaN           NaN              NaN             NaN
#
#    c_syn_retx:87  s_f1323_opt:88  s_tm_opt:89  s_win_scl:90  s_sack_opt:91  \
# 0            NaN             NaN          NaN           NaN            NaN
# 1            NaN             NaN          NaN           NaN            NaN
# 2            NaN             NaN          NaN           NaN            NaN
# 3            NaN             NaN          NaN           NaN            NaN
# 4            NaN             NaN          NaN           NaN            NaN
#
#    s_sack_cnt:92  s_mss:93  s_mss_max:94  s_mss_min:95  s_win_max:96  \
# 0            NaN       NaN           NaN           NaN           NaN
# 1            NaN       NaN           NaN           NaN           NaN
# 2            NaN       NaN           NaN           NaN           NaN
# 3            NaN       NaN           NaN           NaN           NaN
# 4            NaN       NaN           NaN           NaN           NaN
#
#    s_win_min:97  s_win_0:98  s_cwin_max:99  s_cwin_min:100  s_cwin_ini:101  \
# 0           NaN         NaN            NaN             NaN             NaN
# 1           NaN         NaN            NaN             NaN             NaN
# 2           NaN         NaN            NaN             NaN             NaN
# 3           NaN         NaN            NaN             NaN             NaN
# 4           NaN         NaN            NaN             NaN             NaN
#
#    s_pkts_rto:102  s_pkts_fs:103  s_pkts_reor:104  s_pkts_dup:105  \
# 0             NaN            NaN              NaN             NaN
# 1             NaN            NaN              NaN             NaN
# 2             NaN            NaN              NaN             NaN
# 3             NaN            NaN              NaN             NaN
# 4             NaN            NaN              NaN             NaN
#
#    s_pkts_unk:106  s_pkts_fc:107  s_pkts_unrto:108  s_pkts_unfs:109  \
# 0             NaN            NaN               NaN              NaN
# 1             NaN            NaN               NaN              NaN
# 2             NaN            NaN               NaN              NaN
# 3             NaN            NaN               NaN              NaN
# 4             NaN            NaN               NaN              NaN
#
#    s_syn_retx:110  http_req_cnt:111  http_res_cnt:112 http_res:113  \
# 0             NaN               NaN               NaN          NaN
# 1             NaN               NaN               NaN          NaN
# 2             NaN               NaN               NaN          NaN
# 3             NaN               NaN               NaN          NaN
# 4             NaN               NaN               NaN          NaN
#
#    c_pkts_push:114  s_pkts_push:115 c_tls_SNI:116 s_tls_SCN:117  \
# 0              NaN              NaN           NaN           NaN
# 1              NaN              NaN           NaN           NaN
# 2              NaN              NaN           NaN           NaN
# 3              NaN              NaN           NaN           NaN
# 4              NaN              NaN           NaN           NaN
#
#    c_npnalpn:118  s_npnalpn:119  c_tls_sesid:120  c_last_handshakeT:121  \
# 0            NaN            NaN              NaN                    NaN
# 1            NaN            NaN              NaN                    NaN
# 2            NaN            NaN              NaN                    NaN
# 3            NaN            NaN              NaN                    NaN
# 4            NaN            NaN              NaN                    NaN
#
#    s_last_handshakeT:122  c_appdataT:123  s_appdataT:124  c_appdataB:125  \
# 0                    NaN             NaN             NaN             NaN
# 1                    NaN             NaN             NaN             NaN
# 2                    NaN             NaN             NaN             NaN
# 3                    NaN             NaN             NaN             NaN
# 4                    NaN             NaN             NaN             NaN
#
#    s_appdataB:126 fqdn:127 dns_rslv:128  req_tm:129  res_tm:130
# 0             NaN      NaN          NaN         NaN         NaN
# 1             NaN      NaN          NaN         NaN         NaN
# 2             NaN      NaN          NaN         NaN         NaN
# 3             NaN      NaN          NaN         NaN         NaN
# 4             NaN      NaN          NaN         NaN         NaN

# %% [markdown]
# This is interesting, as apparently, different flow files have different features, creating many NaN values in the process.

# %%
# Only the following features seems to be the same/non-null for all 3 files
list(wilson_flow_data_all.columns[~wilson_flow_data_all.isnull().any()])
# Out:
# ['c_port:2',
#  'timestamp',
#  'role_cli',
#  'ipv4_address_cli',
#  'network_cli',
#  'role_serv',
#  'ipv4_address_serv',
#  'network_serv',
#  'label']

# %% [markdown]
# Therefore, we can still reason about capture timestamp and label, but ML with the given NetFlows needs to be done per-file type -- e.g., 1 model would not be good for all the data.

# %%
# Show the label distribution
wilson_flow_data_all['label'].value_counts()
# Out:
# label
# proxy                                       180799
# benign DNS                                  124476
# HTTPS                                        88281
# browsing/update                              56403
# HTTP(S) DMZ                                  55511
# data exfiltration                            21219
# host_discover_local                          16380
# service_scan                                 12293
# NTP                                          12039
# dirb_scan                                     8863
# benign_share                                  8696
# mail                                          7194
# HTTP(S) intra                                 6786
# mDNS                                          5611
# NetBIOS                                       5576
# QUIC                                          5547
# mDNSv6                                        4263
# HTTP                                          3010
# dns_brute_force_start                         1817
# bootp                                         1287
# online_cracking                                735
# monitoring                                     727
# broken flow - benign                           723
# OpenVPN                                        560
# systemd-resolver (local)                       362
# wpscan                                         146
# host_discover_dmz                               63
# benign DNS - attacker requesting updates        58
# DNS                                             46
# SSH                                             42
# STUN VoIP                                       14
# upload_rce_shell                                12
# vpn_connect                                      4
# list_web_dir                                     2
# check_wp_config                                  2
# check_whoami                                     2
# dump_wp_users                                    2
# update/command on unassigned port                2
# Name: count, dtype: int64

# %%
len(wilson_flow_data_all['label'].value_counts())
# Out:
# 38

# %% [markdown]
# However, not all these labels are indeed malicious, one needs to look at the docs to determine which are malicious and which are not.

# %%
# !cat /data/surv/ait/flows_info/label_info.txt
# Out:
# Benign labels in TCP:
# browsing/update
# benign_share
# broken flow - benign
# mail
# monitoring
# HTTP(S) intra
# HTTP(S) DMZ
# HTTP
# HTTPS
# DNS
# SSH
# proxy
# update/command on unassigned port
#
# Malicious labels in TCP:
# service_scan
# online_cracking
# host_discover_dmz
# host_discover_local
# wpscan
# dirb_scan
# upload_rce_shell
# check_user_id
# check_netstat_t
# read_resolv
# check_network_config
# check_ps_a
# check_release
# read_group
# read_passwd
# check_date
# list_web_dir
# check_wp_config
# dump_wp_users
# read_profile
# dns_brute_force_start
# list_www
# check_who
# clear
# check_last
# check_id
# vpn_connect
# check_whoami
# check_uname_r
# check_meminfo
# check_uname_a
# check_df
# check_netstat_nat
# list_home
# check_netstat_l
# check_cpuinfo
# check_uptime
# check_pwd
# list_l
#
# Benign labels in UDP:
# mDNSv6
# mDNS
# bootp
# NTP
# systemd-resolver (local)
# benign DNS - attacker requesting updates
# benign DNS
# OpenVPN
# QUIC
# STUN VoIP
# NetBIOS
# GoogleDNS
#
# Malicious labels in UDP:
# data exfiltration

# %% [markdown]
# Only 14 attacks were found in this scenario. Maybe, it would be sensible to merge classes from all scenarios to see if others do not offer other traffic classes as well, although, according to the docs, the scenarios should be the same.

# %% [markdown]
# ### All NetFlow Files Analysis

# %%
# Each scenario capture has 4 to 6 days. Therefore, specify a static maximum gap to be 15 minutes
def measure_real_capture_dur(data: pd.Series, gap_minutes: int = 15) -> float:
    """Computes total timespan of the capture. Expects iterable containing timestamps objects sorted in a descending manner"""
    gap_max = pd.Timedelta(minutes=gap_minutes)
    total_dur = pd.Timedelta(seconds=0)
    last_tstamp = data.iloc[0]
    contiguous = True

    # Iterate through the dataframe to find out gaps
    for cur_tstamp in data:
        dur_gap = last_tstamp - cur_tstamp

        if dur_gap < gap_max:
            total_dur += dur_gap
        elif contiguous:
            contiguous = False

        last_tstamp = cur_tstamp

    return total_dur, contiguous

# %%
# 3 things are going to be analyzed at once:
# a) traffic classes
# b) capture duration of NetFlow data
# c) amount of flows

scenarios_classes = pd.DataFrame()
scenarios_flows = pd.Series()
scenarios_durs = pd.Series()

# Count the amount of log files per scenario
scenarios_paths = []
for scenario in os.scandir(DATA_ROOT):
    if scenario.is_dir():
        scenarios_paths.append(scenario.path)

scenarios_paths
# Out:
# ['/data/surv/ait/scenarios/fox',
#  '/data/surv/ait/scenarios/wheeler',
#  '/data/surv/ait/scenarios/shaw',
#  '/data/surv/ait/scenarios/russellmitchell',
#  '/data/surv/ait/scenarios/harrison',
#  '/data/surv/ait/scenarios/santos',
#  '/data/surv/ait/scenarios/wilson',
#  '/data/surv/ait/scenarios/wardbeck']

# %%
import glob

# Go through the flow files
for scenario in scenarios_paths:
    scenario_name = scenario.split('/')[-1]
    scenario_flows_dir = os.path.join(scenario, 'flow')
    scenario_df = pd.DataFrame()

    # Get all flow files (CSVs) and load them under one DataFrame
    flow_files = glob.glob('*.csv', root_dir=scenario_flows_dir)

    for flow_file in flow_files:
        tmp_df = pd.read_csv(os.path.join(scenario_flows_dir, flow_file))
        scenario_df = pd.concat([scenario_df, tmp_df])

    # Determine the number of flow entries
    scenarios_flows[scenario_name] = len(scenario_df)

    # Measure class distribution and merge it into the final file
    scenarios_classes[scenario_name] = scenario_df['label'].value_counts()

    # Measure the total capture duration
    scenario_df['timestamp'] = pd.to_datetime(scenario_df['timestamp'], format='%Y-%m-%d %H:%M:%S.%f')
    scenario_df = scenario_df.sort_values(by='timestamp', ascending=False)
    dur, _ = measure_real_capture_dur(scenario_df['timestamp'])

    scenarios_durs[scenario_name] = dur

# Normalize the all classes df
scenarios_classes = scenarios_classes.replace(np.nan, 0).astype(np.int32)
scenarios_classes = scenarios_classes.T.sort_index().T
scenarios_flows = scenarios_flows.sort_index()
scenarios_durs = scenarios_durs.sort_index()

# %%
# The amount of flows
display(scenarios_flows)

scenarios_flows.sum()
# Out:
# fox                351908
# harrison           437659
# russellmitchell    377704
# santos             288547
# shaw               453541
# wardbeck           390224
# wheeler            536206
# wilson             629553
# dtype: int64
# 3465342

# %%
# The "real" duration of the capture based on flows
display(scenarios_durs)

scenarios_durs.sum()
# Out:
# fox               4 days 23:59:58.185704704
# wheeler           4 days 23:38:53.720544256
# shaw              5 days 23:58:28.333856768
# russellmitchell   3 days 23:59:55.115293440
# harrison          4 days 23:47:40.523327488
# santos            3 days 23:59:51.393707008
# wilson            5 days 23:59:49.704099328
# wardbeck          4 days 23:59:13.212267776
# dtype: timedelta64[ns]
# Timedelta('39 days 23:23:50.188800768')

# %% [markdown]
# Approximately corresponds to the documentation. Only `wheeler` and `harrison` are 21 and 12 minutes shorter than declared. However, it is possible that no network traffic took place during the start/end of the event, making it shorter.

# %%
# Take a look on the classes
scenarios_classes
# Out:
#                                             fox  harrison  russellmitchell  \
# label
# benign DNS                                79043    117445            69211
# proxy                                     64434     66164            48468
# HTTPS                                     34918     61948            26261
# host_discover_local                       32788     65668           131068
# browsing/update                           27876     37794            25822
# benign_share                              23074     10810             6208
# HTTP(S) DMZ                               18427      7832            12622
# data exfiltration                         14668     23457            15778
# service_scan                              13901      1309            23112
# NTP                                       10084      9538             6213
# dirb_scan                                  8259      8352               90
# NetBIOS                                    3918      4956             3508
# mDNS                                       3607      3735             1577
# QUIC                                       2992      1962              850
# mail                                       2942      3946             1112
# mDNSv6                                     2940      2645             1111
# HTTP(S) intra                              2371      3061              910
# bootp                                      1334      1512              717
# dns_brute_force_start                      1192       434              814
# HTTP                                        944      2206              785
# broken flow - benign                        692       312              256
# monitoring                                  606       604              484
# systemd-resolver (local)                    366       378              344
# host_discover_dmz                           148       214               21
# wpscan                                      128       148               76
# OpenVPN                                      77       360              137
# online_cracking                              61       738               11
# benign DNS - attacker requesting updates     55        65               44
# SSH                                          19         4               24
# STUN VoIP                                     7         4                0
# DNS                                           7        18                5
# read_group                                    2         2                2
# read_profile                                  2         0                2
# dump_wp_users                                 2         2                2
# check_wp_config                               2         2                2
# list_web_dir                                  2         2                2
# check_date                                    2         0                2
# read_passwd                                   2         2                2
# check_release                                 2         0                2
# update/command on unassigned port             2         2                2
# check_ps_a                                    2         0                2
# check_network_config                          2         0                2
# check_netstat_t                               2         0                2
# check_user_id                                 2         0                2
# upload_rce_shell                              2         2                2
# read_resolv                                   2         0                2
#
#                                           santos    shaw  wardbeck  wheeler  \
# label
# benign DNS                                 70915   80423     91748   122186
# proxy                                      84132       0     94926   107778
# HTTPS                                      15877    5181     66154    67838
# host_discover_local                         1000    1010      2027    65541
# browsing/update                            29515  273059     37687    45836
# benign_share                                3940       0      8024    15306
# HTTP(S) DMZ                                38200       0     17526    24245
# data exfiltration                          12848   60898     15076    19177
# service_scan                                4037     432      1234     9445
# NTP                                         7122   12331     10932    10977
# dirb_scan                                     90      90        90    12837
# NetBIOS                                     3301    5240      5274     4209
# mDNS                                        2984    3825      4368     5427
# QUIC                                        2994    1821      6292     3600
# mail                                        2960       0      3390     4724
# mDNSv6                                      2491    2812      3349     4136
# HTTP(S) intra                               2189       0     15581     1867
# bootp                                        802    1545      1209     1143
# dns_brute_force_start                        325     689       940     3239
# HTTP                                         692    2070      1874     2314
# broken flow - benign                         578     393       423      503
# monitoring                                   477       0       615      587
# systemd-resolver (local)                     355     347       368      370
# host_discover_dmz                            115      12        14     2040
# wpscan                                        84      30        44      263
# OpenVPN                                      159     216       191      460
# online_cracking                              228      78       676        0
# benign DNS - attacker requesting updates      51      68        64       66
# SSH                                           14       4        23       12
# STUN VoIP                                      3       7         8       10
# DNS                                            9       0        21       16
# read_group                                     2       0         2        0
# read_profile                                   0       2         2        0
# dump_wp_users                                  2       2         2        3
# check_wp_config                                2       2         2        3
# list_web_dir                                   2       2         2        7
# check_date                                     2       0         2        0
# read_passwd                                    2       0         0        0
# check_release                                  2       0         6        0
# update/command on unassigned port              2       2         2        2
# check_ps_a                                     2       0         2        0
# check_network_config                           2       0         2        0
# check_netstat_t                                2       0         2        0
# check_user_id                                  2       0        10        0
# upload_rce_shell                               2       2         2        3
# read_resolv                                    2       0         2        0
#
#                                           wilson
# label
# benign DNS                                124476
# proxy                                     180799
# HTTPS                                      88281
# host_discover_local                        16380
# browsing/update                            56403
# benign_share                                8696
# HTTP(S) DMZ                                55511
# data exfiltration                          21219
# service_scan                               12293
# NTP                                        12039
# dirb_scan                                   8863
# NetBIOS                                     5576
# mDNS                                        5611
# QUIC                                        5547
# mail                                        7194
# mDNSv6                                      4263
# HTTP(S) intra                               6786
# bootp                                       1287
# dns_brute_force_start                       1817
# HTTP                                        3010
# broken flow - benign                         723
# monitoring                                   727
# systemd-resolver (local)                     362
# host_discover_dmz                             63
# wpscan                                       146
# OpenVPN                                      560
# online_cracking                              735
# benign DNS - attacker requesting updates      58
# SSH                                           42
# STUN VoIP                                     14
# DNS                                           46
# read_group                                     0
# read_profile                                   0
# dump_wp_users                                  2
# check_wp_config                                2
# list_web_dir                                   2
# check_date                                     0
# read_passwd                                    0
# check_release                                  0
# update/command on unassigned port              2
# check_ps_a                                     0
# check_network_config                           0
# check_netstat_t                                0
# check_user_id                                  0
# upload_rce_shell                              12
# read_resolv                                    0

# %%
# See the total number of flows regardless of the scenario
scenarios_classes.sum(axis=1)
# Out:
# label
# benign DNS                                  755447
# proxy                                       646701
# HTTPS                                       366458
# host_discover_local                         315482
# browsing/update                             533992
# benign_share                                 76058
# HTTP(S) DMZ                                 174363
# data exfiltration                           183121
# service_scan                                 65763
# NTP                                          79236
# dirb_scan                                    38671
# NetBIOS                                      35982
# mDNS                                         31134
# QUIC                                         26058
# mail                                         26268
# mDNSv6                                       23747
# HTTP(S) intra                                32765
# bootp                                         9549
# dns_brute_force_start                         9450
# HTTP                                         13895
# broken flow - benign                          3880
# monitoring                                    4100
# systemd-resolver (local)                      2890
# host_discover_dmz                             2627
# wpscan                                         919
# OpenVPN                                       2160
# online_cracking                               2527
# benign DNS - attacker requesting updates       471
# SSH                                            142
# STUN VoIP                                       53
# DNS                                            122
# read_group                                      10
# read_profile                                     8
# dump_wp_users                                   17
# check_wp_config                                 17
# list_web_dir                                    21
# check_date                                       8
# read_passwd                                      8
# check_release                                   12
# update/command on unassigned port               16
# check_ps_a                                       8
# check_network_config                             8
# check_netstat_t                                  8
# check_user_id                                   16
# upload_rce_shell                                27
# read_resolv                                      8
# dtype: int64

# %%
# Determine the number of bening/malicious classes
CLASSES_MALICIOUS = [
   'service_scan',
    'online_cracking',
    'host_discover_dmz',
    'host_discover_local',
    'wpscan',
    'dirb_scan',
    'upload_rce_shell',
    'check_user_id',
    'check_netstat_t',
    'read_resolv',
    'check_network_config',
    'check_ps_a',
    'check_release',
    'read_group',
    'read_passwd',
    'check_date',
    'list_web_dir',
    'check_wp_config',
    'dump_wp_users',
    'read_profile',
    'dns_brute_force_start',
    'list_www',
    'check_who',
    'clear',
    'check_last',
    'check_id',
    'vpn_connect',
    'check_whoami',
    'check_uname_r',
    'check_meminfo',
    'check_uname_a',
    'check_df',
    'check_netstat_nat',
    'list_home',
    'check_netstat_l',
    'check_cpuinfo',
    'check_uptime',
    'check_pwd',
    'list_l ',
    'data exfiltration'
]

CLASSES_BENIGN = [
    'browsing/update',
    'benign_share',
    'broken flow - benign',
    'mail',
    'monitoring',
    'HTTP(S) intra',
    'HTTP(S) DMZ',
    'HTTP',
    'HTTPS',
    'DNS',
    'SSH',
    'proxy',
    'update/command on unassigned port',
    'mDNSv6',
    'mDNS',
    'bootp',
    'NTP',
    'systemd-resolver (local)',
    'benign DNS - attacker requesting updates',
    'benign DNS',
    'OpenVPN',
    'QUIC',
    'STUN VoIP',
    'NetBIOS',
    'GoogleDNS',
]

# %%
# Make the counts
cnt_malicious_classes = 0
cnt_malicious_flows = 0
cnt_benign_classes = 0
cnt_benign_flows = 0
cnt_uncategorized = 0

# %%
for class_name in scenarios_classes.index:
    if class_name in CLASSES_BENIGN:
        cnt_benign_classes += 1
        cnt_benign_flows += scenarios_classes.loc[class_name].sum()
    elif class_name in CLASSES_MALICIOUS:
        cnt_malicious_classes += 1
        cnt_malicious_flows += scenarios_classes.loc[class_name].sum()
    else:
        cnt_uncategorized += 1
        print(class_name)

# %%
cnt_benign_classes, cnt_benign_flows
# Out:
# (24, 2845487)

# %%
cnt_malicious_classes, cnt_malicious_flows
# Out:
# (22, 618736)

# %% [markdown]
# ### Revising Features Across Different NetFlow Files
# As shown previously, there were lot of NULL values when we loaded all three files into one dataframe. Let's load it one by one and see how the features across files differ.

# %%
# Let's take the "santos" scenario as an example
SANTOS_FLOWS_DIR = '/data/surv/ait/scenarios/santos/flow'
santos_flow_files = glob.glob('*.csv', root_dir=SANTOS_FLOWS_DIR)
santos_flow_files = [os.path.join(SANTOS_FLOWS_DIR, file) for file in santos_flow_files]
santos_flow_files.sort()

santos_flow_files
# Out:
# ['/data/surv/ait/scenarios/santos/flow/tcp_complete.csv',
#  '/data/surv/ait/scenarios/santos/flow/tcp_nocomplete.csv',
#  '/data/surv/ait/scenarios/santos/flow/udp_complete.csv']

# %%
santos_tcp_complete = pd.read_csv(santos_flow_files[0])
santos_tcp_complete.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178744 entries, 0 to 178743
# Data columns (total 138 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    #15#c_ip:1             178744 non-null  object
#  1    c_port:2               178744 non-null  int64
#  2    c_pkts_all:3           178744 non-null  int64
#  3    c_rst_cnt:4            178744 non-null  int64
#  4    c_ack_cnt:5            178744 non-null  int64
#  5    c_ack_cnt_p:6          178744 non-null  int64
#  6    c_bytes_uniq:7         178744 non-null  int64
#  7    c_pkts_data:8          178744 non-null  int64
#  8    c_bytes_all:9          178744 non-null  int64
#  9    c_pkts_retx:10         178744 non-null  int64
#  10   c_bytes_retx:11        178744 non-null  int64
#  11   c_pkts_ooo:12          178744 non-null  int64
#  12   c_syn_cnt:13           178744 non-null  int64
#  13   c_fin_cnt:14           178744 non-null  int64
#  14   s_ip:15                178744 non-null  object
#  15   s_port:16              178744 non-null  int64
#  16   s_pkts_all:17          178744 non-null  int64
#  17   s_rst_cnt:18           178744 non-null  int64
#  18   s_ack_cnt:19           178744 non-null  int64
#  19   s_ack_cnt_p:20         178744 non-null  int64
#  20   s_bytes_uniq:21        178744 non-null  int64
#  21   s_pkts_data:22         178744 non-null  int64
#  22   s_bytes_all:23         178744 non-null  int64
#  23   s_pkts_retx:24         178744 non-null  int64
#  24   s_bytes_retx:25        178744 non-null  int64
#  25   s_pkts_ooo:26          178744 non-null  int64
#  26   s_syn_cnt:27           178744 non-null  int64
#  27   s_fin_cnt:28           178744 non-null  int64
#  28   first:29               178744 non-null  float64
#  29   last:30                178744 non-null  float64
#  30   durat:31               178744 non-null  float64
#  31   c_first:32             178744 non-null  float64
#  32   s_first:33             178744 non-null  float64
#  33   c_last:34              178744 non-null  float64
#  34   s_last:35              178744 non-null  float64
#  35   c_first_ack:36         178744 non-null  float64
#  36   s_first_ack:37         178744 non-null  float64
#  37   c_isint:38             178744 non-null  int64
#  38   s_isint:39             178744 non-null  int64
#  39   c_iscrypto:40          178744 non-null  int64
#  40   s_iscrypto:41          178744 non-null  int64
#  41   con_t:42               178744 non-null  int64
#  42   p2p_t:43               178744 non-null  int64
#  43   http_t:44              178744 non-null  int64
#  44   c_rtt_avg:45           178744 non-null  float64
#  45   c_rtt_min:46           178744 non-null  float64
#  46   c_rtt_max:47           178744 non-null  float64
#  47   c_rtt_std:48           178744 non-null  float64
#  48   c_rtt_cnt:49           178744 non-null  int64
#  49   c_ttl_min:50           178744 non-null  int64
#  50   c_ttl_max:51           178744 non-null  int64
#  51   s_rtt_avg:52           178744 non-null  float64
#  52   s_rtt_min:53           178744 non-null  float64
#  53   s_rtt_max:54           178744 non-null  float64
#  54   s_rtt_std:55           178744 non-null  float64
#  55   s_rtt_cnt:56           178744 non-null  int64
#  56   s_ttl_min:57           178744 non-null  int64
#  57   s_ttl_max:58           178744 non-null  int64
#  58   p2p_st:59              178744 non-null  int64
#  59   ed2k_data:60           178744 non-null  int64
#  60   ed2k_sig:61            178744 non-null  int64
#  61   ed2k_c2s:62            178744 non-null  int64
#  62   ed2k_c2c:63            178744 non-null  int64
#  63   ed2k_chat:64           178744 non-null  int64
#  64   c_f1323_opt:65         178744 non-null  int64
#  65   c_tm_opt:66            178744 non-null  int64
#  66   c_win_scl:67           178744 non-null  int64
#  67   c_sack_opt:68          178744 non-null  int64
#  68   c_sack_cnt:69          178744 non-null  int64
#  69   c_mss:70               178744 non-null  int64
#  70   c_mss_max:71           178744 non-null  int64
#  71   c_mss_min:72           178744 non-null  int64
#  72   c_win_max:73           178744 non-null  int64
#  73   c_win_min:74           178744 non-null  int64
#  74   c_win_0:75             178744 non-null  int64
#  75   c_cwin_max:76          178744 non-null  int64
#  76   c_cwin_min:77          178744 non-null  int64
#  77   c_cwin_ini:78          178744 non-null  int64
#  78   c_pkts_rto:79          178744 non-null  int64
#  79   c_pkts_fs:80           178744 non-null  int64
#  80   c_pkts_reor:81         178744 non-null  int64
#  81   c_pkts_dup:82          178744 non-null  int64
#  82   c_pkts_unk:83          178744 non-null  int64
#  83   c_pkts_fc:84           178744 non-null  int64
#  84   c_pkts_unrto:85        178744 non-null  int64
#  85   c_pkts_unfs:86         178744 non-null  int64
#  86   c_syn_retx:87          178744 non-null  int64
#  87   s_f1323_opt:88         178744 non-null  int64
#  88   s_tm_opt:89            178744 non-null  int64
#  89   s_win_scl:90           178744 non-null  int64
#  90   s_sack_opt:91          178744 non-null  int64
#  91   s_sack_cnt:92          178744 non-null  int64
#  92   s_mss:93               178744 non-null  int64
#  93   s_mss_max:94           178744 non-null  int64
#  94   s_mss_min:95           178744 non-null  int64
#  95   s_win_max:96           178744 non-null  int64
#  96   s_win_min:97           178744 non-null  int64
#  97   s_win_0:98             178744 non-null  int64
#  98   s_cwin_max:99          178744 non-null  int64
#  99   s_cwin_min:100         178744 non-null  int64
#  100  s_cwin_ini:101         178744 non-null  int64
#  101  s_pkts_rto:102         178744 non-null  int64
#  102  s_pkts_fs:103          178744 non-null  int64
#  103  s_pkts_reor:104        178744 non-null  int64
#  104  s_pkts_dup:105         178744 non-null  int64
#  105  s_pkts_unk:106         178744 non-null  int64
#  106  s_pkts_fc:107          178744 non-null  int64
#  107  s_pkts_unrto:108       178744 non-null  int64
#  108  s_pkts_unfs:109        178744 non-null  int64
#  109  s_syn_retx:110         178744 non-null  int64
#  110  http_req_cnt:111       178744 non-null  int64
#  111  http_res_cnt:112       178744 non-null  int64
#  112  http_res:113           178744 non-null  object
#  113  c_pkts_push:114        178744 non-null  int64
#  114  s_pkts_push:115        178744 non-null  int64
#  115  c_tls_SNI:116          178744 non-null  object
#  116  s_tls_SCN:117          178744 non-null  object
#  117  c_npnalpn:118          178744 non-null  int64
#  118  s_npnalpn:119          178744 non-null  int64
#  119  c_tls_sesid:120        178744 non-null  int64
#  120  c_last_handshakeT:121  178744 non-null  float64
#  121  s_last_handshakeT:122  178744 non-null  float64
#  122  c_appdataT:123         178744 non-null  float64
#  123  s_appdataT:124         178744 non-null  float64
#  124  c_appdataB:125         178744 non-null  int64
#  125  s_appdataB:126         178744 non-null  int64
#  126  fqdn:127               178744 non-null  object
#  127  dns_rslv:128           178744 non-null  object
#  128  req_tm:129             178744 non-null  float64
#  129  res_tm:130             178744 non-null  float64
#  130  timestamp              178744 non-null  object
#  131  role_cli               178744 non-null  object
#  132  ipv4_address_cli       178744 non-null  object
#  133  network_cli            178744 non-null  object
#  134  role_serv              178744 non-null  object
#  135  ipv4_address_serv      178744 non-null  object
#  136  network_serv           178744 non-null  object
#  137  label                  178744 non-null  object
# dtypes: float64(23), int64(100), object(15)
# memory usage: 188.2+ MB

# %%
santos_tcp_nocomplete = pd.read_csv(santos_flow_files[1])
santos_tcp_nocomplete.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5778 entries, 0 to 5777
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #15#c_ip:1         5778 non-null   object
#  1   c_port:2           5778 non-null   int64
#  2   c_pkts_all:3       5778 non-null   int64
#  3   c_rst_cnt:4        5778 non-null   int64
#  4   c_ack_cnt:5        5778 non-null   int64
#  5   c_ack_cnt_p:6      5778 non-null   int64
#  6   c_bytes_uniq:7     5778 non-null   int64
#  7   c_pkts_data:8      5778 non-null   int64
#  8   c_bytes_all:9      5778 non-null   int64
#  9   c_pkts_retx:10     5778 non-null   int64
#  10  c_bytes_retx:11    5778 non-null   int64
#  11  c_pkts_ooo:12      5778 non-null   int64
#  12  c_syn_cnt:13       5778 non-null   int64
#  13  c_fin_cnt:14       5778 non-null   int64
#  14  s_ip:15            5778 non-null   object
#  15  s_port:16          5778 non-null   int64
#  16  s_pkts_all:17      5778 non-null   int64
#  17  s_rst_cnt:18       5778 non-null   int64
#  18  s_ack_cnt:19       5778 non-null   int64
#  19  s_ack_cnt_p:20     5778 non-null   int64
#  20  s_bytes_uniq:21    5778 non-null   int64
#  21  s_pkts_data:22     5778 non-null   int64
#  22  s_bytes_all:23     5778 non-null   int64
#  23  s_pkts_retx:24     5778 non-null   int64
#  24  s_bytes_retx:25    5778 non-null   int64
#  25  s_pkts_ooo:26      5778 non-null   int64
#  26  s_syn_cnt:27       5778 non-null   int64
#  27  s_fin_cnt:28       5778 non-null   int64
#  28  first:29           5778 non-null   float64
#  29  last:30            5778 non-null   float64
#  30  durat:31           5778 non-null   float64
#  31  c_first:32         5778 non-null   float64
#  32  s_first:33         5778 non-null   float64
#  33  c_last:34          5778 non-null   float64
#  34  s_last:35          5778 non-null   float64
#  35  c_first_ack:36     5778 non-null   float64
#  36  s_first_ack:37     5778 non-null   float64
#  37  c_isint:38         5778 non-null   int64
#  38  s_isint:39         5778 non-null   int64
#  39  c_iscrypto:40      5778 non-null   int64
#  40  s_iscrypto:41      5778 non-null   int64
#  41  con_t:42           5778 non-null   int64
#  42  p2p_t:43           5778 non-null   int64
#  43  http_t:44          5778 non-null   int64
#  44  timestamp          5778 non-null   object
#  45  role_cli           5778 non-null   object
#  46  ipv4_address_cli   5778 non-null   object
#  47  network_cli        5778 non-null   object
#  48  role_serv          5778 non-null   object
#  49  ipv4_address_serv  5778 non-null   object
#  50  network_serv       5778 non-null   object
#  51  label              5778 non-null   object
# dtypes: float64(9), int64(33), object(10)
# memory usage: 2.3+ MB

# %%
# Is the TCP no-complete subset of the TCP complete?
display(len(santos_tcp_complete.columns))
len(pd.concat([santos_tcp_complete, santos_tcp_nocomplete]).columns)
# Out:
# 138
# 138

# %% [markdown]
# YES! Let's see UDP features now.

# %%
santos_udp_complete = pd.read_csv(santos_flow_files[2])
santos_udp_complete.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104025 entries, 0 to 104024
# Data columns (total 28 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   #c_ip:1            104025 non-null  object
#  1   c_port:2           104025 non-null  int64
#  2   c_first_abs:3      104025 non-null  float64
#  3   c_durat:4          104025 non-null  float64
#  4   c_bytes_all:5      104025 non-null  int64
#  5   c_pkts_all:6       104025 non-null  int64
#  6   c_isint:7          104025 non-null  int64
#  7   c_iscrypto:8       104025 non-null  int64
#  8   c_type:9           104025 non-null  int64
#  9   s_ip:10            104025 non-null  object
#  10  s_port:11          104025 non-null  int64
#  11  s_first_abs:12     104025 non-null  float64
#  12  s_durat:13         104025 non-null  float64
#  13  s_bytes_all:14     104025 non-null  int64
#  14  s_pkts_all:15      104025 non-null  int64
#  15  s_isint:16         104025 non-null  int64
#  16  s_iscrypto:17      104025 non-null  int64
#  17  s_type:18          104025 non-null  int64
#  18  fqdn:19            104025 non-null  object
#  19  timestamp          104025 non-null  object
#  20  rounded_timestamp  104025 non-null  object
#  21  role_cli           104025 non-null  object
#  22  ipv4_address_cli   104025 non-null  object
#  23  network_cli        104025 non-null  object
#  24  role_serv          104025 non-null  object
#  25  ipv4_address_serv  104025 non-null  object
#  26  network_serv       104025 non-null  object
#  27  label              104025 non-null  object
# dtypes: float64(4), int64(12), object(12)
# memory usage: 22.2+ MB

# %%
# Now, see how much features differ
len(pd.concat([santos_tcp_complete, santos_udp_complete]).columns)
# Out:
# 157

# %% [markdown]
# Ok, many feature names are the same, but there is a number demarking their order. If we drop this number and merge the data afterwards, we receive the total number of **unique** features.

# %%
rename_columns = lambda name: ''.join([ch for ch in name if not ch.isdigit()]).replace('#', '').replace(':', '')

# %%
santos_tcp_complete.rename(columns=rename_columns, inplace=True)
santos_tcp_nocomplete.rename(columns=rename_columns, inplace=True)
santos_udp_complete.rename(columns=rename_columns, inplace=True)

# %%
# With the renamed columns, merge and see the number of unique ones
santos_all = pd.concat([santos_tcp_complete, santos_tcp_nocomplete, santos_udp_complete])
len(santos_all.columns)
# Out:
# 145

# %%
santos_all.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288547 entries, 0 to 104024
# Data columns (total 145 columns):
#  #    Column             Non-Null Count   Dtype
# ---   ------             --------------   -----
#  0    c_ip               288547 non-null  object
#  1    c_port             288547 non-null  int64
#  2    c_pkts_all         288547 non-null  int64
#  3    c_rst_cnt          184522 non-null  float64
#  4    c_ack_cnt          184522 non-null  float64
#  5    c_ack_cnt_p        184522 non-null  float64
#  6    c_bytes_uniq       184522 non-null  float64
#  7    c_pkts_data        184522 non-null  float64
#  8    c_bytes_all        288547 non-null  int64
#  9    c_pkts_retx        184522 non-null  float64
#  10   c_bytes_retx       184522 non-null  float64
#  11   c_pkts_ooo         184522 non-null  float64
#  12   c_syn_cnt          184522 non-null  float64
#  13   c_fin_cnt          184522 non-null  float64
#  14   s_ip               288547 non-null  object
#  15   s_port             288547 non-null  int64
#  16   s_pkts_all         288547 non-null  int64
#  17   s_rst_cnt          184522 non-null  float64
#  18   s_ack_cnt          184522 non-null  float64
#  19   s_ack_cnt_p        184522 non-null  float64
#  20   s_bytes_uniq       184522 non-null  float64
#  21   s_pkts_data        184522 non-null  float64
#  22   s_bytes_all        288547 non-null  int64
#  23   s_pkts_retx        184522 non-null  float64
#  24   s_bytes_retx       184522 non-null  float64
#  25   s_pkts_ooo         184522 non-null  float64
#  26   s_syn_cnt          184522 non-null  float64
#  27   s_fin_cnt          184522 non-null  float64
#  28   first              184522 non-null  float64
#  29   last               184522 non-null  float64
#  30   durat              184522 non-null  float64
#  31   c_first            184522 non-null  float64
#  32   s_first            184522 non-null  float64
#  33   c_last             184522 non-null  float64
#  34   s_last             184522 non-null  float64
#  35   c_first_ack        184522 non-null  float64
#  36   s_first_ack        184522 non-null  float64
#  37   c_isint            288547 non-null  int64
#  38   s_isint            288547 non-null  int64
#  39   c_iscrypto         288547 non-null  int64
#  40   s_iscrypto         288547 non-null  int64
#  41   con_t              184522 non-null  float64
#  42   pp_t               184522 non-null  float64
#  43   http_t             184522 non-null  float64
#  44   c_rtt_avg          178744 non-null  float64
#  45   c_rtt_min          178744 non-null  float64
#  46   c_rtt_max          178744 non-null  float64
#  47   c_rtt_std          178744 non-null  float64
#  48   c_rtt_cnt          178744 non-null  float64
#  49   c_ttl_min          178744 non-null  float64
#  50   c_ttl_max          178744 non-null  float64
#  51   s_rtt_avg          178744 non-null  float64
#  52   s_rtt_min          178744 non-null  float64
#  53   s_rtt_max          178744 non-null  float64
#  54   s_rtt_std          178744 non-null  float64
#  55   s_rtt_cnt          178744 non-null  float64
#  56   s_ttl_min          178744 non-null  float64
#  57   s_ttl_max          178744 non-null  float64
#  58   pp_st              178744 non-null  float64
#  59   edk_data           178744 non-null  float64
#  60   edk_sig            178744 non-null  float64
#  61   edk_cs             178744 non-null  float64
#  62   edk_cc             178744 non-null  float64
#  63   edk_chat           178744 non-null  float64
#  64   c_f_opt            178744 non-null  float64
#  65   c_tm_opt           178744 non-null  float64
#  66   c_win_scl          178744 non-null  float64
#  67   c_sack_opt         178744 non-null  float64
#  68   c_sack_cnt         178744 non-null  float64
#  69   c_mss              178744 non-null  float64
#  70   c_mss_max          178744 non-null  float64
#  71   c_mss_min          178744 non-null  float64
#  72   c_win_max          178744 non-null  float64
#  73   c_win_min          178744 non-null  float64
#  74   c_win_             178744 non-null  float64
#  75   c_cwin_max         178744 non-null  float64
#  76   c_cwin_min         178744 non-null  float64
#  77   c_cwin_ini         178744 non-null  float64
#  78   c_pkts_rto         178744 non-null  float64
#  79   c_pkts_fs          178744 non-null  float64
#  80   c_pkts_reor        178744 non-null  float64
#  81   c_pkts_dup         178744 non-null  float64
#  82   c_pkts_unk         178744 non-null  float64
#  83   c_pkts_fc          178744 non-null  float64
#  84   c_pkts_unrto       178744 non-null  float64
#  85   c_pkts_unfs        178744 non-null  float64
#  86   c_syn_retx         178744 non-null  float64
#  87   s_f_opt            178744 non-null  float64
#  88   s_tm_opt           178744 non-null  float64
#  89   s_win_scl          178744 non-null  float64
#  90   s_sack_opt         178744 non-null  float64
#  91   s_sack_cnt         178744 non-null  float64
#  92   s_mss              178744 non-null  float64
#  93   s_mss_max          178744 non-null  float64
#  94   s_mss_min          178744 non-null  float64
#  95   s_win_max          178744 non-null  float64
#  96   s_win_min          178744 non-null  float64
#  97   s_win_             178744 non-null  float64
#  98   s_cwin_max         178744 non-null  float64
#  99   s_cwin_min         178744 non-null  float64
#  100  s_cwin_ini         178744 non-null  float64
#  101  s_pkts_rto         178744 non-null  float64
#  102  s_pkts_fs          178744 non-null  float64
#  103  s_pkts_reor        178744 non-null  float64
#  104  s_pkts_dup         178744 non-null  float64
#  105  s_pkts_unk         178744 non-null  float64
#  106  s_pkts_fc          178744 non-null  float64
#  107  s_pkts_unrto       178744 non-null  float64
#  108  s_pkts_unfs        178744 non-null  float64
#  109  s_syn_retx         178744 non-null  float64
#  110  http_req_cnt       178744 non-null  float64
#  111  http_res_cnt       178744 non-null  float64
#  112  http_res           178744 non-null  object
#  113  c_pkts_push        178744 non-null  float64
#  114  s_pkts_push        178744 non-null  float64
#  115  c_tls_SNI          178744 non-null  object
#  116  s_tls_SCN          178744 non-null  object
#  117  c_npnalpn          178744 non-null  float64
#  118  s_npnalpn          178744 non-null  float64
#  119  c_tls_sesid        178744 non-null  float64
#  120  c_last_handshakeT  178744 non-null  float64
#  121  s_last_handshakeT  178744 non-null  float64
#  122  c_appdataT         178744 non-null  float64
#  123  s_appdataT         178744 non-null  float64
#  124  c_appdataB         178744 non-null  float64
#  125  s_appdataB         178744 non-null  float64
#  126  fqdn               282769 non-null  object
#  127  dns_rslv           178744 non-null  object
#  128  req_tm             178744 non-null  float64
#  129  res_tm             178744 non-null  float64
#  130  timestamp          288547 non-null  object
#  131  role_cli           288547 non-null  object
#  132  ipv_address_cli    288547 non-null  object
#  133  network_cli        288547 non-null  object
#  134  role_serv          288547 non-null  object
#  135  ipv_address_serv   288547 non-null  object
#  136  network_serv       288547 non-null  object
#  137  label              288547 non-null  object
#  138  c_first_abs        104025 non-null  float64
#  139  c_durat            104025 non-null  float64
#  140  c_type             104025 non-null  float64
#  141  s_first_abs        104025 non-null  float64
#  142  s_durat            104025 non-null  float64
#  143  s_type             104025 non-null  float64
#  144  rounded_timestamp  104025 non-null  object
# dtypes: float64(119), int64(10), object(16)
# memory usage: 321.4+ MB
